# %% [markdown]
# # 2. 프로젝트: ResNet Ablation Study

# %% [markdown]
# ## 루브릭
# |평가문항|	상세기준|
# |:-------|:-------|
# |1. ResNet-34, ResNet-50 모델 구현이 정상적으로 진행되었는가?|블록함수 구현이 제대로 진행되었으며 구현한 모델의 summary가 예상된 형태로 출력되었다.|
# |2. 구현한 ResNet 모델을 활용하여 Image Classification 모델 훈련이 가능한가?|cats_vs_dogs 데이터셋으로 학습시 몇 epoch동안 안정적으로 loss 감소가 진행 확인되었다.|
# |3. Ablation Study 결과가 바른 포맷으로 제출되었는가?|ResNet-34, ResNet-50 각각 plain모델과 residual모델을 동일한 epoch만큼 학습시켰을 때의 validation accuracy 기준으로 Ablation Study 결과표가 작성되었다.|

# %% [markdown]
# ## 0) CIFAR-10 데이터셋 준비

# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

import tensorflow_datasets as tfds

# %%
# Tensorflow가 활용할 GPU가 장착되어 있는지 확인
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### 데이터셋 로드

# %%
import urllib3
urllib3.disable_warnings()

#tfds.disable_progress_bar()   # 이 주석을 풀면 데이터셋 다운로드과정의 프로그레스바가 나타나지 않습니다.

(ds_train, ds_test), ds_info = tfds.load(
    'cifar10',
    split=['train', 'test'],
    shuffle_files=True,
    with_info=True,
)
# Out:
# Downloading and preparing dataset 162.17 MiB (download: 162.17 MiB, generated: 132.40 MiB, total: 294.58 MiB) to /aiffel/tensorflow_datasets/cifar10/3.0.2...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Shuffling cifar10-train.tfrecord...:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling cifar10-test.tfrecord...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Dataset cifar10 downloaded and prepared to /aiffel/tensorflow_datasets/cifar10/3.0.2. Subsequent calls will reuse this data.

# %% [markdown]
# * Tensorflow Datasets : https://www.tensorflow.org/datasets/catalog/overview
#   - Audio
#   - Graphs
#   - Image
#   - Image classification
#   - Object detection
#   - Question answering
#   - Structured
#   - Summarization
#   - Text
#   - Translate
#   - Video
#   - Vision language

# %% [markdown]
# ### 불러온 데이터셋의 정보 확인

# %%
# 데이터셋 종류 확인 (시간이 오래걸림)
# tfds.list_builders()[:10]

# %% [markdown]
# * **cifar10** : Tensorflow Datasets / Image classification / Cifar10 에 있음
#   - The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class.
#   - There are 50000 training images and 10000 test images.

# %%
# 데이터셋의 정보 확인
ds_info
# Out:
# tfds.core.DatasetInfo(
#     name='cifar10',
#     full_name='cifar10/3.0.2',
#     description="""
#     The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.
#     """,
#     homepage='https://www.cs.toronto.edu/~kriz/cifar.html',
#     data_path='/aiffel/tensorflow_datasets/cifar10/3.0.2',
#     download_size=162.17 MiB,
#     dataset_size=132.40 MiB,
#     features=FeaturesDict({
#         'id': Text(shape=(), dtype=tf.string),
#         'image': Image(shape=(32, 32, 3), dtype=tf.uint8),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=10),
#     }),
#     supervised_keys=('image', 'label'),
#     splits={
#         'test': <SplitInfo num_examples=10000, num_shards=1>,
#         'train': <SplitInfo num_examples=50000, num_shards=1>,
#     },
#     citation="""@TECHREPORT{Krizhevsky09learningmultiple,
#         author = {Alex Krizhevsky},
#         title = {Learning multiple layers of features from tiny images},
#         institution = {},
#         year = {2009}
#     }""",
# )

# %%
# 데이터셋의 feature 정보 확인 
print(ds_info.features)
# Out:
# FeaturesDict({
#     'id': Text(shape=(), dtype=tf.string),
#     'image': Image(shape=(32, 32, 3), dtype=tf.uint8),
#     'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=10),
# })

# %%
# 데이터셋의 class 개수 확인 
print('class의 개수 :', ds_info.features['label'].num_classes)
# Out:
# class의 개수 : 10

# %%
# 데이터셋의 클래스 이름 확인
ds_info.features["label"].names
# Out:
# ['airplane',
#  'automobile',
#  'bird',
#  'cat',
#  'deer',
#  'dog',
#  'frog',
#  'horse',
#  'ship',
#  'truck']

# %%
# 데이터셋의 train/test의 샘플 사이즈 확인
print('train 데이터 개수 :', ds_info.splits['train'].num_examples)
print('test 데이터 개수 :', ds_info.splits['test'].num_examples)
# Out:
# train 데이터 개수 : 50000
# test 데이터 개수 : 10000

# %%
# 학습 및 테스트 데이터의 갯수 확인하는 다른 방법
print('train 데이터 개수 :', tf.data.experimental.cardinality(ds_train))
print('test 데이터 개수 :', tf.data.experimental.cardinality(ds_test))
# Out:
# train 데이터 개수 : tf.Tensor(50000, shape=(), dtype=int64)
# test 데이터 개수 : tf.Tensor(10000, shape=(), dtype=int64)

# %% [markdown]
# ### CPU 코어 개수 확인

# %%
# CPU 코어 전체 개수
! grep -c processor /proc/cpuinfo
# Out:
# 6

# %% [markdown]
# * 일반적인 경우, 하이퍼스레딩에 의해 OS(윈도우, 리눅스 등)에서 코어 수가 실제 코어 수의 2배로 인식된다.
# * 예를 들어 싱글코어는 코어 2개로, 듀얼코어는 4개로 인식된다.
#
#
# * 지금 사용하는 컴퓨터의 경우 :
#   - 가상 CPU 코어 수는 12. 따라서 물리적으로는 **6 코어**
#   - [참고 : 리눅스 CPU 개수 확인](https://zetawiki.com/wiki/리눅스_CPU_개수_확인)

# %%
# 물리 CPU 개수
! grep ^processor /proc/cpuinfo | wc -l
# Out:
# 6

# %%
# CPU당 물리 코어 개수
! grep 'cpu cores' /proc/cpuinfo | tail -1
# Out:
# cpu cores	: 6

# %% [markdown]
# ### 불러온 데이터셋  이미지 확인

# %%
# 학습 데이터셋에 어떤 이미지 있는지 확인
fig = tfds.show_examples(ds_train, ds_info)

# %% [markdown]
# * **`tfds.show_examples(ds, info)`** : matplotlib.figure.Figure를 반환합니다 (현재 이미지 데이터 세트 만 지원됨) [참고](https://www.tensorflow.org/datasets/overview#tfdsshow_examples)
# * **`tfds.visualization.show_examples(ds, ds_info)`** : 이미지 분류 데이터 세트에서 이미지 (및 레이블)를 시각화합니다. [참고](https://www.tensorflow.org/datasets/api_docs/python/tfds/visualization/show_examples)

# %%
# 학습 데이터셋에 어떤 이미지 있는지 확인하는 다른 방법
fig = tfds.visualization.show_examples(ds_train, ds_info)

# %%
# 테스트 데이터셋에 어떤 이미지 있는지 확인
fig = tfds.show_examples(ds_test, ds_info)

# %% [markdown]
# ### 데이터셋 정규화

# %%
# 정규화 및 이미지 크기조절 함수 
def normalize_and_resize_img(image, label):
    """Normalizes images: `uint8` -> `float32`."""
    image = tf.image.resize(image, [IMAGE_SIZE, IMAGE_SIZE])
    return tf.cast(image, tf.float32) / 255., label

# %%
# 데이터셋에 정규화 함수를 적용하는 함수
def apply_normalize_on_dataset(ds, is_test=False, batch_size=16):
    # 위에서 만든 normalize 함수를 병렬로 map 하기
    ds = ds.map(
        normalize_and_resize_img, 
        num_parallel_calls=6      # 병렬처리할 때 가용할 CPU 코어 개수
    )
    # split dataset into batches of batch_size
    ds = ds.batch(batch_size)
    
    if not is_test:
        ds = ds.repeat()      # repeat process for number of epochs
        ds = ds.shuffle(200)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    return ds

# %% [markdown]
# * **`num_parallel_calls`** :
#   - map 변환을 병렬 처리한다.
#   - 병렬 처리 레벨을 지정하기 위해 num_parallel_calls 인수를 제공합니다.
#   - 가용한 CPU 코어 숫자보다 훨씬 더 많이 설정한다면 비효율적인 스케줄링으로 느려질 것입니다.
#   - [참고 1: tf.data API로 성능 향상하기](https://www.tensorflow.org/guide/data_performance?hl=ko)
#   - [참고 2: tf.data API로 성능 향상하기](https://colab.research.google.com/github/tensorflow/docs-l10n/blob/master/site/ko/guide/data_performance.ipynb?hl=ko)
#
#
# * **`ds.batch(batch_size)`** : 데이터 세트를 batch_size의 배치로 분할 [참고](https://wsstudynote.tistory.com/24)
# * **`ds.repeat(num_epochs)`** : num_epochs 수에 대해 프로세스를 반복  [참고](https://wsstudynote.tistory.com/24)
# * **`ds.shuffle(SHUFFLE_BUFFER_SIZE)`** : 데이터를 랜덤하게 셔플하는 기능 [참고: shuffle()에서 buffer_size의 중요성](https://helloyjam.github.io/tensorflow/buffer-size-in-shuffle/)
#   - SHUFFLE_BUFFER_SIZE=len(filenames)을 사용
#   - 이미지 읽고 프로세싱하고 배치작업등의 무거운 작업을 하기전에 tf.data.Dataset.shuffle()을 호출
# * **`ds.prefetch()`** : [참고](https://www.tensorflow.org/guide/data_performance?hl=ko)
#   - 모델이 s스텝 훈련을 실행하는 동안 입력 파이프라인은 s+1스텝의 데이터를 읽습니다
#   - 훈련을 하는 최대(합과 반대로) 스텝 시간과 데이터를 추출하는 데 걸리는 시간을 단축시킬 수 있습니다.
#   - 이 변환은 백그라운드 스레드와 내부 버퍼를 사용하여 요청된 시간 전에 입력 데이터셋에서 요소를 가져옵니다.
#   - 가져올 요소의 수는 하나의 훈련 스텝에서 소비한 배치의 수와 같거나 커야 합니다
#   - 이 값을 수동으로 조정하거나
#   - **`tf.data.experimental.AUTOTUNE`** 으로 설정하면 tf.data 런타임이 실행 시에 **동적으로 값을 조정**하도록 만듭니다.

# %% [markdown]
# ## 1) ResNet 기본 블록 구성하기
#
# ResNet 34와 50에서 사용된 블록들의 공통점과 차이점을 찾아서
# ResNet의 기본 블록, 또는 Residual 블록(residual block)을 구현해보기.
# 가급적 ResNet 논문을 통해서 구현방법에 대한 정보를 얻으시기를 권합니다.
#
# ![image.png](attachment:image.png)
# <div style='text-align:left'>Table 1. Architectures for ImageNet. Building blocks are shown in brackets (see also Fig. 5), with the numbers of blocks stacked.</div>
# <div style='text-align:left'>Down-sampling is performed by conv3_1, conv4_1, and conv5_1 with a stride of 2. </div>

# %% [markdown]
# * ResNet-34와 ResNet-50 **공통점** :
#   - conv block이라고 불리는 블록 구조를 각각 3, 4, 6, 3개씩 반복해서 쌓은 형태
#
#
# * ResNet-34와 ResNet-50 **차이점** :
#   - ResNet-34 : 3x3 kernel인 Convolution layer로만 구성
#   - ResNet-50 : 1x1 Convolution layer가 3x3 Convolution layer의 앞뒤로 붙어있음
#     - 뒤에 있는 1x1 Convolution layer의 채널 수는 앞에 있는 것의 4배

# %% [markdown]
# [참고1](https://jmyao17.github.io/Machine_Learning/Neural_Network/ResNet/ResNet.html)
# [참고2](https://jisuhan.tistory.com/entry/CNN-ResNet50-톺아보기-구조와-코드-분석)
# [참고3](https://towardsdatascience.com/understand-and-implement-resnet-50-with-tensorflow-2-0-1190b9b52691)
# [참고4](https://www.programmersought.com/article/58524297511/)
# [참고5](https://eremo2002.tistory.com/76)
# [참고6](https://pylessons.com/Keras-ResNet-tutorial/)
# [참고7](https://keras.io/api/applications/resnet/#resnet50-function)
# [참고8](https://github.com/tensorflow/tensorflow/blob/v2.4.1/tensorflow/python/keras/applications/resnet.py#L453-L472)

# %% [markdown]
# ### tf.keras.applications.ResNet50 분석

# %% [markdown]
# **ResNet models for Keras.
# Reference:**
#   - [Deep Residual Learning for Image Recognition](
#       https://arxiv.org/abs/1512.03385) (CVPR 2015)

# %% [markdown]
# ### Building blocks of ResNet-34 & ResNet-50 (Bottleneck)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Building block 구성

# %% [markdown]
# * **[3.4. Implementation](https://arxiv.org/pdf/1512.03385.pdf)**
# Our implementation for ImageNet follows the practice in [21, 41].
#   - 1) The image is **resized** with its shorter side randomly sampled in [256, 480] for **scale augmentation** [41].
#   - 2) A **224×224 crop** is randomly sampled from an image or its **horizontal flip**, with the per-pixel mean subtracted [21].
#   - 3) The **standard color augmentation** in [21] is used.
#   - 4) We adopt **batch normalization (BN)** [16] **right after each convolution** and **before activation**, following [16].
#   - 5) We **initialize the weights** as in [13] and train all plain/residual nets from scratch.
#   - 6) We use **SGD** with a **mini-batch size of 256**.
#   - 7) The **learning rate** starts from **0.1** and is **divided by 10 when the error plateaus**, and the models are trained for up to **60 × $10^4$ iterations**.
#   - 8) We use a **weight decay of 0.0001** and a **momentum of 0.9**.
#   - 9) We do **not use dropout** [14], following the practice in [16].
#
# In testing, for comparison studies we adopt the standard 10-crop testing [21].
# For best results, we adopt the fullyconvolutional form as in [41, 13], and average the scores at multiple   scales (images are resized such that the shorter side is in f224; 256; 384; 480; 640g).

# %% [markdown]
# * 그림 5로부터 : conv1x1, conv3x3 layer 필요함
# * 4) 조건으로부터 : Convolution --> Batch Normalization --> Activation

# %% [markdown]
# * **Deeper Bottleneck Architectures.**
#
# Next we describe our deeper nets for ImageNet.
# Because of concerns on the training time that we can afford,
# we modify the building block as a **bottleneck design.**
#   - For each residual function F, we use a stack of **3 layers instead of 2** (Fig. 5).
#   - The three layers are **1×1, 3×3, and 1×1 convolutions**,
#     - where the **1×1 layer**s are responsible for **reducing** and then **increasing** (restoring) dimensions,
#     - leaving the **3×3 layer** a bottleneck with smaller input/output dimensions.
#
# Fig. 5 shows an example, where both designs have similar time complexity.
# The parameter-free identity shortcuts are particularly important for the bottleneck architectures.
# If the identity shortcut in Fig. 5 (right) is replaced with projection,
#   one can show that the time complexity and model size are doubled,
#   as the shortcut is connected to the two high-dimensional ends.
# So identity shortcuts lead to more efficient models for the bottleneck designs.
#
#
#
# * **50-layer ResNet**:
#
#   - We replace each **2-layer block** in the 34-layer net with this **3-layer bottleneck block**,
#     - resulting in a 50-layer ResNet (Table 1).
#   - We use option B for increasing dimensions.
#   - This model has 3.8 billion FLOPs.

# %% [markdown]
# ### 50-layer residual

# %% [markdown]
# * [참고:Conv2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D)
# tf.keras.layers.Conv2D(
#     filters, kernel_size, strides=(1, 1), padding='valid',
#     data_format=None, dilation_rate=(1, 1), groups=1, activation=None,
#     use_bias=True, kernel_initializer='glorot_uniform',
#     bias_initializer='zeros', kernel_regularizer=None,
#     bias_regularizer=None, activity_regularizer=None, kernel_constraint=None,
#     bias_constraint=None, **kwargs
# )
#
#
# * [참고:BatchNormalization](https://www.tensorflow.org/api_docs/python/tf/keras/layers/BatchNormalization)
# tf.keras.layers.BatchNormalization(
#     axis=-1, momentum=0.99, epsilon=0.001, center=True, scale=True,
#     beta_initializer='zeros', gamma_initializer='ones',
#     moving_mean_initializer='zeros',
#     moving_variance_initializer='ones', beta_regularizer=None,
#     gamma_regularizer=None, beta_constraint=None, gamma_constraint=None,
#     renorm=False, renorm_clipping=None, renorm_momentum=0.99, fused=None,
#     trainable=True, virtual_batch_size=None, adjustment=None, name=None, **kwargs
# )
#
#
# * [참고:Activation](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Activation)
# tf.keras.layers.Activation(
#     activation, **kwargs
# )
#
#
# * [참고:ZeroPadding2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/ZeroPadding2D)
# tf.keras.layers.ZeroPadding2D(
#     padding=(1, 1), data_format=None, **kwargs
# )

# %% [markdown]
# ### ResNet50 구성

# %% [markdown]
# **identity shortcut block :**
#
# <img align='center' width='90%' src='https://pylessons.com/static/images/CNN-tutorials/Keras-ResNet-tutorial/Identity_block2.png'/>

# %% [markdown]
# **projection shortcut block:**
#
# <img align='center' width='90%' src='https://pylessons.com/static/images/CNN-tutorials/Keras-ResNet-tutorial/Identity_block3.png'/>

# %% [markdown]
# **Building the ResNet model (50 layers):**
#
# <img align='center' width='90%' src='https://pylessons.com/static/images/CNN-tutorials/Keras-ResNet-tutorial/ResNet-50.png'/>

# %% [markdown]
# [참고:Blocks with dotted line represents modules](https://www.researchgate.net/figure/Left-ResNet50-architecture-Blocks-with-dotted-line-represents-modules-that-might-be_fig3_331364877)
# [참고: modified ResNet-50](https://www.researchgate.net/figure/Transfer-learning-architecture-with-modified-ResNet-50-and-ResNet-101-model-n-6-for_fig7_335534416)
# [참고:ResNet-50 network architectures](https://www.researchgate.net/figure/ResNet-50-network-architectures-It-includes-convolution-block-and-identity-block_fig3_338986286)

# %% [markdown]
# ## 2) ResNet-34, ResNet-50 Complete Model

# %% [markdown]
# ### ResNet  구현
# [참고](https://github.com/calmisential/TensorFlow2.0_ResNet)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models, layers
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import BatchNormalization, Conv2D, Activation, Dense, GlobalAveragePooling2D, MaxPooling2D, ZeroPadding2D, Add

from tensorflow.keras import optimizers, initializers, regularizers, metrics
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, Flatten, MaxPooling2D, Dense, Input, Reshape, Concatenate, GlobalAveragePooling2D, BatchNormalization, Dropout, Activation, GlobalMaxPooling2D
from tensorflow.keras.utils import Sequence

# %% [markdown]
# * **ResNet34 와 ResNet50의 구조는 다르기 때문에 기본구조를 구분하여 작성한다.**
#   - <span style='color:red'> **ResNet34** : basic_block, skip_basic_block; basic_block_layer; resnet_type1 </span>
#   - <span style='color:red'>**ResNet50** : bottle_neck, skip_bottle_neck; bottle_neck_layer; resnet_type2 </span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# basic block for resnet type 1
def basic_block(inputs, n_filter, stride, bk):
    print('basic_block_input    :', bk, inputs.shape)
    
    shortcut = inputs
    
    x = Conv2D(filters=n_filter, kernel_size=(3, 3), strides=stride, padding="same")(inputs)
    x   = BatchNormalization()(x)
    x  = Activation("relu")(x)
    x = Conv2D(filters=n_filter, kernel_size=(3, 3), strides=(1, 1), padding="same")(x)
    x   = BatchNormalization()(x)
    print('basic_block_beforadd :', bk, x.shape)
    
    shortcut = skip_basic_block(shortcut, n_filter, stride, bk)
    print('basic_block_shortcut :', bk, shortcut.shape) 
    
    x = Add()([x, shortcut])
    output  = Activation("relu")(x)
    print('basic_block_output   :', bk, output.shape)
    
    return output

# %% [markdown]
# * `padding="same"` : # of padding = # of filters / 2
# * $output=(n - f + 2p)/s + 1$
# * $output = n/s + 1$ at "same"

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# skip connection for resnet type 1
def skip_basic_block(inputs, n_filter, stride, bk):
    print('skip_basic_block_input :', bk, inputs.shape)
    
    if stride != (1, 1):
        # projection shortcut
        shortcut = Conv2D(filters=n_filter, kernel_size=(3, 3), strides=stride, padding="same")(inputs)
        shortcut = BatchNormalization()(shortcut)
    else:
        # identity shortcut
        shortcut = inputs
        
    print('skip_basic_block_output:', bk, shortcut.shape)    
    return shortcut

# %% [markdown]
# *  <span style='color:red'> ResNet34의 첫번째 skip connection은 identity shortcut으로 구성되어 있으므로 주의해야 한다.</span>

# %%
# layers of basic block of resnet type1
def basic_block_layer(inputs, n_filter, blocks, stride=(1, 1)):
    print('basic_block_laye r_input:', inputs.shape)
    bk = 0
    resnet_block = basic_block(inputs, n_filter, stride=stride, bk=0)
    
    for _ in range(1, blocks):
        bk = bk + 1
        resnet_block = basic_block(resnet_block, n_filter, stride=(1, 1), bk=bk)
        
    return resnet_block

# %%
def resnet_type1(inputs, layer_params):
    print('resnet_type1_input:', inputs.shape)
    
    conv1 = Conv2D(filters=64, kernel_size=(7, 7), strides=(2, 2), padding="same")(inputs)
    bn1 = BatchNormalization()(conv1)
    act1  = Activation("relu")(bn1)
    pool1 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding="same")(act1)
    print('resnet_type1_pool1:', pool1.shape)
    
    layer1 = basic_block_layer(pool1,  n_filter=64,  blocks=layer_params[0], stride=(1, 1))
    layer2 = basic_block_layer(layer1, n_filter=128, blocks=layer_params[1], stride=(2, 2))
    layer3 = basic_block_layer(layer2, n_filter=256, blocks=layer_params[2], stride=(2, 2))
    layer4 = basic_block_layer(layer3, n_filter=512, blocks=layer_params[3], stride=(2, 2))
    
    avgpool = GlobalAveragePooling2D()(layer4)
    outputs = Dense(units=n_classes, activation='softmax')(avgpool)
    print('resnet_type1_output  :', outputs.shape)
    
    resnet_model = Model(inputs, outputs)
    
    return resnet_model

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# bottle neck block for resnet type 2
def bottle_neck(inputs, n_filter, stride, bk):
    print('bottle_neck_input      :', bk, inputs.shape)
    
    shortcut = inputs
    
    conv1 = Conv2D(filters=n_filter, kernel_size=(1, 1), strides=stride)(inputs)
    print('conv1 :', bk, conv1.shape)
    bn1   = BatchNormalization()(conv1)
    act1  = Activation("relu")(bn1)
    conv2 = Conv2D(filters=n_filter, kernel_size=(3, 3), strides=(1, 1), padding="same")(act1)
    print('conv2 :', bk, conv2.shape)
    bn2   = BatchNormalization()(conv2)
    act2  = Activation("relu")(bn2)
    conv3 = Conv2D(filters=n_filter*4, kernel_size=(1, 1), strides=(1, 1))(act2)
    print('conv3 :', bk, conv3.shape)
    bn3   = BatchNormalization()(conv3)
    print('bottle_neck_beforadd :', bk, bn3.shape)
    
    shortcut = skip_bottle_neck(shortcut, n_filter*4, stride, bk)
    print('bottle_neck_shortcut :', bk, shortcut.shape)    
    
    add4 = Add()([bn3, shortcut])
    outputs  = Activation("relu")(add4)
    print('bottle_neck_output     :', bk, outputs.shape)
    
    return outputs

# %% [markdown]
# * <span style='color:red'> conv3의 필터개수가 conv1의 필터개수보다 4배 많은 것에 주의해야한다. </span>
# * <span style='color:red'> skip connection의 필터 개수 또한 4배 많게 설정해야한다.</span>

# %%
# skip connection for resnet type 2
def skip_bottle_neck(inputs, n_filter, stride, bk):
    print('skip_bottle_neck_input :', bk, inputs.shape)
    
    if bk==0:
        # projection shortcut
        shortcut = Conv2D(filters=n_filter, kernel_size=(1, 1), strides=stride)(inputs)
        shortcut = BatchNormalization()(shortcut)
    else:
        # identity shortcut
        shortcut = inputs
        
    print('skip_bottle_neck_output:', bk, shortcut.shape)
    return shortcut

# %% [markdown]
# * <span style='color:red'> resnet50은 모든 레이어에서 첫번째 skip connection에 projection shortcut을 적용한다.</span>

# %%
# layers of bottle neck of resnet type 2
def bottle_neck_layer(inputs, n_filter, blocks, stride=(1, 1)):
    print('bottle_neck_layer_input:', inputs.shape)
    bk = 0
    resnet_block = bottle_neck(inputs, n_filter, stride=stride, bk=0)
    
    for _ in range(1, blocks):
        bk = bk + 1
        resnet_block = bottle_neck(resnet_block, n_filter, stride=(1, 1), bk=bk)
        
    return resnet_block

# %%
def resnet_type2(inputs, layer_params):
    print('resnet_type2_input:', inputs.shape)
    
    conv1 = Conv2D(filters=64, kernel_size=(7, 7), strides=(2, 2), padding="same")(inputs)
    bn1 = BatchNormalization()(conv1)
    act1  = Activation("relu")(bn1)
    pool1 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding="same")(act1)
    print('resnet_type2_pool1:', pool1.shape)
    
    layer1 = bottle_neck_layer(pool1,  n_filter=64,  blocks=layer_params[0], stride=(1, 1))
    layer2 = bottle_neck_layer(layer1, n_filter=128, blocks=layer_params[1], stride=(2, 2))
    layer3 = bottle_neck_layer(layer2, n_filter=256, blocks=layer_params[2], stride=(2, 2))
    layer4 = bottle_neck_layer(layer3, n_filter=512, blocks=layer_params[3], stride=(2, 2))
    
    avgpool = GlobalAveragePooling2D()(layer4)
    outputs = Dense(units=n_classes, activation='softmax')(avgpool)
    print('resnet_type2_output  :', outputs.shape)
    
    resnet_model = Model(inputs, outputs)

    return resnet_model

# %%
def resnet_18(inputs):
    return resnet_type1(inputs, layer_params=[2, 2, 2, 2])


def resnet_34(inputs):
    return resnet_type1(inputs, layer_params=[3, 4, 6, 3])


def resnet_50(inputs):
    return resnet_type2(inputs, layer_params=[3, 4, 6, 3])


def resnet_101(inputs):
    return resnet_type2(inputs, layer_params=[3, 4, 23, 3])


def resnet_152(inputs):
    return resnet_type2(inputs, layer_params=[3, 8, 36, 3])

# %%
def build_resnet(input_shape=None, is_50=True):

    input_tensor = Input(shape=input_shape, dtype='float32', name='input_layer')
    
    if not is_50:
        resnet = resnet_34(input_tensor)
    else:
        resnet = resnet_50(input_tensor)
        
    return resnet

# %% [markdown]
# ### ResNet-34
#
# VGG와 같이 블록을 만드는 함수를 사용해서 직접 전체 모델을 만들어 봅시다.
# ResNet-34와 ResNet-50의 차이에 따라 달라지는 구성(configuration)을 함수에 전달해서 같은 생성 함수 build_resnet() 를 통해서 ResNet의 여러가지 버전들을 모두 만들어 낼 수 있도록 해야 합니다.
#
# 다음의 코드를 실행하면,
#
# `resnet_34 = build_resnet(input_shape=(32, 32,3), is_50=False)
# resnet_34.summary()`

# %%
input_shape = (32, 32, 3)
n_classes = 10

resnet_34_model = build_resnet(input_shape=input_shape, is_50=False)
resnet_34_model.summary()
# Out:
# resnet_type1_input: (None, 32, 32, 3)
# resnet_type1_pool1: (None, 8, 8, 64)
# basic_block_laye r_input: (None, 8, 8, 64)
# basic_block_input    : 0 (None, 8, 8, 64)
# basic_block_beforadd : 0 (None, 8, 8, 64)
# skip_basic_block_input : 0 (None, 8, 8, 64)
# skip_basic_block_output: 0 (None, 8, 8, 64)
# basic_block_shortcut : 0 (None, 8, 8, 64)
# basic_block_output   : 0 (None, 8, 8, 64)
# basic_block_input    : 1 (None, 8, 8, 64)
# basic_block_beforadd : 1 (None, 8, 8, 64)
# skip_basic_block_input : 1 (None, 8, 8, 64)
# skip_basic_block_output: 1 (None, 8, 8, 64)
# basic_block_shortcut : 1 (None, 8, 8, 64)
# basic_block_output   : 1 (None, 8, 8, 64)
# basic_block_input    : 2 (None, 8, 8, 64)
# basic_block_beforadd : 2 (None, 8, 8, 64)
# skip_basic_block_input : 2 (None, 8, 8, 64)
# skip_basic_block_output: 2 (None, 8, 8, 64)
# basic_block_shortcut : 2 (None, 8, 8, 64)
# basic_block_output   : 2 (None, 8, 8, 64)
# basic_block_laye r_input: (None, 8, 8, 64)
# basic_block_input    : 0 (None, 8, 8, 64)
# basic_block_beforadd : 0 (None, 4, 4, 128)
# skip_basic_block_input : 0 (None, 8, 8, 64)
# skip_basic_block_output: 0 (None, 4, 4, 128)
# basic_block_shortcut : 0 (None, 4, 4, 128)
# basic_block_output   : 0 (None, 4, 4, 128)
# basic_block_input    : 1 (None, 4, 4, 128)
# basic_block_beforadd : 1 (None, 4, 4, 128)
# skip_basic_block_input : 1 (None, 4, 4, 128)
# skip_basic_block_output: 1 (None, 4, 4, 128)
# basic_block_shortcut : 1 (None, 4, 4, 128)
# basic_block_output   : 1 (None, 4, 4, 128)
# basic_block_input    : 2 (None, 4, 4, 128)
# basic_block_beforadd : 2 (None, 4, 4, 128)
# skip_basic_block_input : 2 (None, 4, 4, 128)
# skip_basic_block_output: 2 (None, 4, 4, 128)
# basic_block_shortcut : 2 (None, 4, 4, 128)
# basic_block_output   : 2 (None, 4, 4, 128)
# basic_block_input    : 3 (None, 4, 4, 128)
# basic_block_beforadd : 3 (None, 4, 4, 128)
# skip_basic_block_input : 3 (None, 4, 4, 128)
# skip_basic_block_output: 3 (None, 4, 4, 128)
# basic_block_shortcut : 3 (None, 4, 4, 128)
# basic_block_output   : 3 (None, 4, 4, 128)
# basic_block_laye r_input: (None, 4, 4, 128)
# basic_block_input    : 0 (None, 4, 4, 128)
# basic_block_beforadd : 0 (None, 2, 2, 256)
# skip_basic_block_input : 0 (None, 4, 4, 128)
# skip_basic_block_output: 0 (None, 2, 2, 256)
# basic_block_shortcut : 0 (None, 2, 2, 256)
# basic_block_output   : 0 (None, 2, 2, 256)
# basic_block_input    : 1 (None, 2, 2, 256)
# basic_block_beforadd : 1 (None, 2, 2, 256)
# skip_basic_block_input : 1 (None, 2, 2, 256)
# skip_basic_block_output: 1 (None, 2, 2, 256)
# basic_block_shortcut : 1 (None, 2, 2, 256)
# basic_block_output   : 1 (None, 2, 2, 256)
# basic_block_input    : 2 (None, 2, 2, 256)
# basic_block_beforadd : 2 (None, 2, 2, 256)
# skip_basic_block_input : 2 (None, 2, 2, 256)
# skip_basic_block_output: 2 (None, 2, 2, 256)
# basic_block_shortcut : 2 (None, 2, 2, 256)
# basic_block_output   : 2 (None, 2, 2, 256)
# basic_block_input    : 3 (None, 2, 2, 256)
# basic_block_beforadd : 3 (None, 2, 2, 256)
# skip_basic_block_input : 3 (None, 2, 2, 256)
# skip_basic_block_output: 3 (None, 2, 2, 256)
# basic_block_shortcut : 3 (None, 2, 2, 256)
# basic_block_output   : 3 (None, 2, 2, 256)
# basic_block_input    : 4 (None, 2, 2, 256)
# basic_block_beforadd : 4 (None, 2, 2, 256)
# skip_basic_block_input : 4 (None, 2, 2, 256)
# skip_basic_block_output: 4 (None, 2, 2, 256)
# basic_block_shortcut : 4 (None, 2, 2, 256)
# basic_block_output   : 4 (None, 2, 2, 256)
# basic_block_input    : 5 (None, 2, 2, 256)
# basic_block_beforadd : 5 (None, 2, 2, 256)
# skip_basic_block_input : 5 (None, 2, 2, 256)
# skip_basic_block_output: 5 (None, 2, 2, 256)
# basic_block_shortcut : 5 (None, 2, 2, 256)
# basic_block_output   : 5 (None, 2, 2, 256)
# basic_block_laye r_input: (None, 2, 2, 256)
# basic_block_input    : 0 (None, 2, 2, 256)
# basic_block_beforadd : 0 (None, 1, 1, 512)
# skip_basic_block_input : 0 (None, 2, 2, 256)
# skip_basic_block_output: 0 (None, 1, 1, 512)
# basic_block_shortcut : 0 (None, 1, 1, 512)
# basic_block_output   : 0 (None, 1, 1, 512)
# basic_block_input    : 1 (None, 1, 1, 512)
# basic_block_beforadd : 1 (None, 1, 1, 512)
# skip_basic_block_input : 1 (None, 1, 1, 512)
# skip_basic_block_output: 1 (None, 1, 1, 512)
# basic_block_shortcut : 1 (None, 1, 1, 512)
# basic_block_output   : 1 (None, 1, 1, 512)
# basic_block_input    : 2 (None, 1, 1, 512)
# basic_block_beforadd : 2 (None, 1, 1, 512)
# skip_basic_block_input : 2 (None, 1, 1, 512)
# skip_basic_block_output: 2 (None, 1, 1, 512)
# basic_block_shortcut : 2 (None, 1, 1, 512)
# basic_block_output   : 2 (None, 1, 1, 512)
# resnet_type1_output  : (None, 10)
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_layer (InputLayer)        [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 16, 16, 64)   9472        input_layer[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 16, 16, 64)   256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 16, 16, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 8, 8, 64)     0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 8, 8, 64)     36928       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 8, 8, 64)     256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 8, 8, 64)     0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 8, 8, 64)     36928       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 8, 8, 64)     256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 8, 8, 64)     0           batch_normalization_2[0][0]
#                                                                  max_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 8, 8, 64)     0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 8, 8, 64)     36928       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 8, 8, 64)     256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 8, 8, 64)     0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 8, 8, 64)     36928       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 8, 8, 64)     256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 8, 8, 64)     0           batch_normalization_4[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 8, 8, 64)     0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 8, 8, 64)     36928       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 8, 64)     256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 8, 8, 64)     0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 64)     36928       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 8, 8, 64)     256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 8, 8, 64)     0           batch_normalization_6[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 8, 8, 64)     0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 4, 4, 128)    73856       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 4, 4, 128)    512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 4, 4, 128)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 4, 4, 128)    147584      activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 4, 4, 128)    73856       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 4, 4, 128)    512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 4, 4, 128)    512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 4, 4, 128)    0           batch_normalization_8[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 4, 4, 128)    0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 4, 4, 128)    147584      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 4, 4, 128)    512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 4, 4, 128)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 4, 4, 128)    147584      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 4, 4, 128)    512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 4, 4, 128)    0           batch_normalization_11[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 4, 4, 128)    0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 4, 4, 128)    147584      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 4, 4, 128)    512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 4, 4, 128)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 4, 4, 128)    147584      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 4, 4, 128)    512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 4, 4, 128)    0           batch_normalization_13[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 4, 4, 128)    0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 4, 4, 128)    147584      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 4, 4, 128)    512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 4, 4, 128)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 4, 4, 128)    147584      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 4, 4, 128)    512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 4, 4, 128)    0           batch_normalization_15[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 4, 4, 128)    0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 2, 2, 256)    295168      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 2, 2, 256)    1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 2, 2, 256)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 2, 2, 256)    590080      activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 2, 2, 256)    295168      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 2, 2, 256)    1024        conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 2, 2, 256)    1024        conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 2, 2, 256)    0           batch_normalization_17[0][0]
#                                                                  batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 2, 2, 256)    0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 2, 2, 256)    590080      activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 2, 2, 256)    1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 2, 2, 256)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 2, 2, 256)    590080      activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 2, 2, 256)    1024        conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 2, 2, 256)    0           batch_normalization_20[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 2, 2, 256)    0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 2, 2, 256)    590080      activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 2, 2, 256)    1024        conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 2, 2, 256)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 2, 2, 256)    590080      activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 2, 2, 256)    1024        conv2d_22[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 2, 2, 256)    0           batch_normalization_22[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 2, 2, 256)    0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 2, 2, 256)    590080      activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 2, 2, 256)    1024        conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 2, 2, 256)    0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 2, 2, 256)    590080      activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 2, 2, 256)    1024        conv2d_24[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 2, 2, 256)    0           batch_normalization_24[0][0]
#                                                                  activation_20[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 2, 2, 256)    0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 2, 2, 256)    590080      activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 2, 2, 256)    1024        conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 2, 2, 256)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 2, 2, 256)    590080      activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 2, 2, 256)    1024        conv2d_26[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 2, 2, 256)    0           batch_normalization_26[0][0]
#                                                                  activation_22[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 2, 2, 256)    0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 2, 2, 256)    590080      activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 2, 2, 256)    1024        conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 2, 2, 256)    0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 2, 2, 256)    590080      activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 2, 2, 256)    1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 2, 2, 256)    0           batch_normalization_28[0][0]
#                                                                  activation_24[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 2, 2, 256)    0           add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 1, 1, 512)    1180160     activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 1, 1, 512)    2048        conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 1, 1, 512)    0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 1, 1, 512)    2359808     activation_27[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 1, 1, 512)    1180160     activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 1, 1, 512)    2048        conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 1, 1, 512)    2048        conv2d_31[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 1, 1, 512)    0           batch_normalization_30[0][0]
#                                                                  batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 1, 1, 512)    0           add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 1, 1, 512)    2359808     activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 1, 1, 512)    2048        conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 1, 1, 512)    0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 1, 1, 512)    2359808     activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 1, 1, 512)    2048        conv2d_33[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 1, 1, 512)    0           batch_normalization_33[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 1, 1, 512)    0           add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 1, 1, 512)    2359808     activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 1, 1, 512)    2048        conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 1, 1, 512)    0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 1, 1, 512)    2359808     activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 1, 1, 512)    2048        conv2d_35[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 1, 1, 512)    0           batch_normalization_35[0][0]
#                                                                  activation_30[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 1, 1, 512)    0           add_15[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 512)          0           activation_32[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           5130        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 22,691,594
# Trainable params: 22,674,570
# Non-trainable params: 17,024
# __________________________________________________________________________________________________

# %% [markdown]
# ### ResNet-50
# 위에서 만든 함수에 config를 조절해서 ResNet-50을 만들어 봅니다. 구조가 원하는 대로 만들어졌는지 확인하고 이상이 있다면 수정합니다.
#
# 다음의 코드를 실행하면, 아래의 결과가 나와야 합니다.
#
# `resnet_50 = build_resnet(input_shape=(32, 32,3), is_50=True)
# resnet_50.summary()`

# %%
input_shape = (32, 32, 3)
n_classes = 10

resnet_50_model = build_resnet(input_shape=input_shape, is_50=True)
resnet_50_model.summary()
# Out:
# resnet_type2_input: (None, 32, 32, 3)
# resnet_type2_pool1: (None, 8, 8, 64)
# bottle_neck_layer_input: (None, 8, 8, 64)
# bottle_neck_input      : 0 (None, 8, 8, 64)
# conv1 : 0 (None, 8, 8, 64)
# conv2 : 0 (None, 8, 8, 64)
# conv3 : 0 (None, 8, 8, 256)
# bottle_neck_beforadd : 0 (None, 8, 8, 256)
# skip_bottle_neck_input : 0 (None, 8, 8, 64)
# skip_bottle_neck_output: 0 (None, 8, 8, 256)
# bottle_neck_shortcut : 0 (None, 8, 8, 256)
# bottle_neck_output     : 0 (None, 8, 8, 256)
# bottle_neck_input      : 1 (None, 8, 8, 256)
# conv1 : 1 (None, 8, 8, 64)
# conv2 : 1 (None, 8, 8, 64)
# conv3 : 1 (None, 8, 8, 256)
# bottle_neck_beforadd : 1 (None, 8, 8, 256)
# skip_bottle_neck_input : 1 (None, 8, 8, 256)
# skip_bottle_neck_output: 1 (None, 8, 8, 256)
# bottle_neck_shortcut : 1 (None, 8, 8, 256)
# bottle_neck_output     : 1 (None, 8, 8, 256)
# bottle_neck_input      : 2 (None, 8, 8, 256)
# conv1 : 2 (None, 8, 8, 64)
# conv2 : 2 (None, 8, 8, 64)
# conv3 : 2 (None, 8, 8, 256)
# bottle_neck_beforadd : 2 (None, 8, 8, 256)
# skip_bottle_neck_input : 2 (None, 8, 8, 256)
# skip_bottle_neck_output: 2 (None, 8, 8, 256)
# bottle_neck_shortcut : 2 (None, 8, 8, 256)
# bottle_neck_output     : 2 (None, 8, 8, 256)
# bottle_neck_layer_input: (None, 8, 8, 256)
# bottle_neck_input      : 0 (None, 8, 8, 256)
# conv1 : 0 (None, 4, 4, 128)
# conv2 : 0 (None, 4, 4, 128)
# conv3 : 0 (None, 4, 4, 512)
# bottle_neck_beforadd : 0 (None, 4, 4, 512)
# skip_bottle_neck_input : 0 (None, 8, 8, 256)
# skip_bottle_neck_output: 0 (None, 4, 4, 512)
# bottle_neck_shortcut : 0 (None, 4, 4, 512)
# bottle_neck_output     : 0 (None, 4, 4, 512)
# bottle_neck_input      : 1 (None, 4, 4, 512)
# conv1 : 1 (None, 4, 4, 128)
# conv2 : 1 (None, 4, 4, 128)
# conv3 : 1 (None, 4, 4, 512)
# bottle_neck_beforadd : 1 (None, 4, 4, 512)
# skip_bottle_neck_input : 1 (None, 4, 4, 512)
# skip_bottle_neck_output: 1 (None, 4, 4, 512)
# bottle_neck_shortcut : 1 (None, 4, 4, 512)
# bottle_neck_output     : 1 (None, 4, 4, 512)
# bottle_neck_input      : 2 (None, 4, 4, 512)
# conv1 : 2 (None, 4, 4, 128)
# conv2 : 2 (None, 4, 4, 128)
# conv3 : 2 (None, 4, 4, 512)
# bottle_neck_beforadd : 2 (None, 4, 4, 512)
# skip_bottle_neck_input : 2 (None, 4, 4, 512)
# skip_bottle_neck_output: 2 (None, 4, 4, 512)
# bottle_neck_shortcut : 2 (None, 4, 4, 512)
# bottle_neck_output     : 2 (None, 4, 4, 512)
# bottle_neck_input      : 3 (None, 4, 4, 512)
# conv1 : 3 (None, 4, 4, 128)
# conv2 : 3 (None, 4, 4, 128)
# conv3 : 3 (None, 4, 4, 512)
# bottle_neck_beforadd : 3 (None, 4, 4, 512)
# skip_bottle_neck_input : 3 (None, 4, 4, 512)
# skip_bottle_neck_output: 3 (None, 4, 4, 512)
# bottle_neck_shortcut : 3 (None, 4, 4, 512)
# bottle_neck_output     : 3 (None, 4, 4, 512)
# bottle_neck_layer_input: (None, 4, 4, 512)
# bottle_neck_input      : 0 (None, 4, 4, 512)
# conv1 : 0 (None, 2, 2, 256)
# conv2 : 0 (None, 2, 2, 256)
# conv3 : 0 (None, 2, 2, 1024)
# bottle_neck_beforadd : 0 (None, 2, 2, 1024)
# skip_bottle_neck_input : 0 (None, 4, 4, 512)
# skip_bottle_neck_output: 0 (None, 2, 2, 1024)
# bottle_neck_shortcut : 0 (None, 2, 2, 1024)
# bottle_neck_output     : 0 (None, 2, 2, 1024)
# bottle_neck_input      : 1 (None, 2, 2, 1024)
# conv1 : 1 (None, 2, 2, 256)
# conv2 : 1 (None, 2, 2, 256)
# conv3 : 1 (None, 2, 2, 1024)
# bottle_neck_beforadd : 1 (None, 2, 2, 1024)
# skip_bottle_neck_input : 1 (None, 2, 2, 1024)
# skip_bottle_neck_output: 1 (None, 2, 2, 1024)
# bottle_neck_shortcut : 1 (None, 2, 2, 1024)
# bottle_neck_output     : 1 (None, 2, 2, 1024)
# bottle_neck_input      : 2 (None, 2, 2, 1024)
# conv1 : 2 (None, 2, 2, 256)
# conv2 : 2 (None, 2, 2, 256)
# conv3 : 2 (None, 2, 2, 1024)
# bottle_neck_beforadd : 2 (None, 2, 2, 1024)
# skip_bottle_neck_input : 2 (None, 2, 2, 1024)
# skip_bottle_neck_output: 2 (None, 2, 2, 1024)
# bottle_neck_shortcut : 2 (None, 2, 2, 1024)
# bottle_neck_output     : 2 (None, 2, 2, 1024)
# bottle_neck_input      : 3 (None, 2, 2, 1024)
# conv1 : 3 (None, 2, 2, 256)
# conv2 : 3 (None, 2, 2, 256)
# conv3 : 3 (None, 2, 2, 1024)
# bottle_neck_beforadd : 3 (None, 2, 2, 1024)
# skip_bottle_neck_input : 3 (None, 2, 2, 1024)
# skip_bottle_neck_output: 3 (None, 2, 2, 1024)
# bottle_neck_shortcut : 3 (None, 2, 2, 1024)
# bottle_neck_output     : 3 (None, 2, 2, 1024)
# bottle_neck_input      : 4 (None, 2, 2, 1024)
# conv1 : 4 (None, 2, 2, 256)
# conv2 : 4 (None, 2, 2, 256)
# conv3 : 4 (None, 2, 2, 1024)
# bottle_neck_beforadd : 4 (None, 2, 2, 1024)
# skip_bottle_neck_input : 4 (None, 2, 2, 1024)
# skip_bottle_neck_output: 4 (None, 2, 2, 1024)
# bottle_neck_shortcut : 4 (None, 2, 2, 1024)
# bottle_neck_output     : 4 (None, 2, 2, 1024)
# bottle_neck_input      : 5 (None, 2, 2, 1024)
# conv1 : 5 (None, 2, 2, 256)
# conv2 : 5 (None, 2, 2, 256)
# conv3 : 5 (None, 2, 2, 1024)
# bottle_neck_beforadd : 5 (None, 2, 2, 1024)
# skip_bottle_neck_input : 5 (None, 2, 2, 1024)
# skip_bottle_neck_output: 5 (None, 2, 2, 1024)
# bottle_neck_shortcut : 5 (None, 2, 2, 1024)
# bottle_neck_output     : 5 (None, 2, 2, 1024)
# bottle_neck_layer_input: (None, 2, 2, 1024)
# bottle_neck_input      : 0 (None, 2, 2, 1024)
# conv1 : 0 (None, 1, 1, 512)
# conv2 : 0 (None, 1, 1, 512)
# conv3 : 0 (None, 1, 1, 2048)
# bottle_neck_beforadd : 0 (None, 1, 1, 2048)
# skip_bottle_neck_input : 0 (None, 2, 2, 1024)
# skip_bottle_neck_output: 0 (None, 1, 1, 2048)
# bottle_neck_shortcut : 0 (None, 1, 1, 2048)
# bottle_neck_output     : 0 (None, 1, 1, 2048)
# bottle_neck_input      : 1 (None, 1, 1, 2048)
# conv1 : 1 (None, 1, 1, 512)
# conv2 : 1 (None, 1, 1, 512)
# conv3 : 1 (None, 1, 1, 2048)
# bottle_neck_beforadd : 1 (None, 1, 1, 2048)
# skip_bottle_neck_input : 1 (None, 1, 1, 2048)
# skip_bottle_neck_output: 1 (None, 1, 1, 2048)
# bottle_neck_shortcut : 1 (None, 1, 1, 2048)
# bottle_neck_output     : 1 (None, 1, 1, 2048)
# bottle_neck_input      : 2 (None, 1, 1, 2048)
# conv1 : 2 (None, 1, 1, 512)
# conv2 : 2 (None, 1, 1, 512)
# conv3 : 2 (None, 1, 1, 2048)
# bottle_neck_beforadd : 2 (None, 1, 1, 2048)
# skip_bottle_neck_input : 2 (None, 1, 1, 2048)
# skip_bottle_neck_output: 2 (None, 1, 1, 2048)
# bottle_neck_shortcut : 2 (None, 1, 1, 2048)
# bottle_neck_output     : 2 (None, 1, 1, 2048)
# resnet_type2_output  : (None, 10)
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_layer (InputLayer)        [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 16, 16, 64)   9472        input_layer[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 16, 16, 64)   256         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 16, 16, 64)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 64)     0           activation_33[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 8, 8, 64)     4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 8, 8, 64)     256         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 8, 8, 64)     0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 8, 8, 64)     36928       activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 8, 8, 64)     256         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 8, 8, 64)     0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 8, 8, 256)    16640       activation_35[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 8, 8, 256)    16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 8, 8, 256)    1024        conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 8, 8, 256)    1024        conv2d_40[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 8, 8, 256)    0           batch_normalization_39[0][0]
#                                                                  batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 8, 8, 256)    0           add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 8, 8, 64)     16448       activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 8, 8, 64)     256         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 8, 8, 64)     0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 8, 8, 64)     36928       activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 8, 8, 64)     256         conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 8, 8, 64)     0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 8, 8, 256)    16640       activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 8, 8, 256)    1024        conv2d_43[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 8, 8, 256)    0           batch_normalization_43[0][0]
#                                                                  activation_36[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 8, 8, 256)    0           add_17[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 8, 8, 64)     16448       activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 8, 8, 64)     256         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 8, 8, 64)     0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 8, 8, 64)     36928       activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 8, 8, 64)     256         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 8, 8, 64)     0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 8, 8, 256)    16640       activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 8, 8, 256)    1024        conv2d_46[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 8, 8, 256)    0           batch_normalization_46[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 8, 8, 256)    0           add_18[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 4, 4, 128)    32896       activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 4, 4, 128)    512         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 4, 4, 128)    0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 4, 4, 128)    147584      activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 4, 4, 128)    512         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 4, 4, 128)    0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 4, 4, 512)    66048       activation_44[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 4, 4, 512)    131584      activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 4, 4, 512)    2048        conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 4, 4, 512)    2048        conv2d_50[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 4, 4, 512)    0           batch_normalization_49[0][0]
#                                                                  batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 4, 4, 512)    0           add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 4, 4, 128)    65664       activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 4, 4, 128)    512         conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 4, 4, 128)    0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 4, 4, 128)    147584      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 4, 4, 128)    512         conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 4, 4, 128)    0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 4, 4, 512)    66048       activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 4, 4, 512)    2048        conv2d_53[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 4, 4, 512)    0           batch_normalization_53[0][0]
#                                                                  activation_45[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 4, 4, 512)    0           add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 4, 4, 128)    65664       activation_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 4, 4, 128)    512         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 4, 4, 128)    0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 4, 4, 128)    147584      activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 4, 4, 128)    512         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 4, 4, 128)    0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 4, 4, 512)    66048       activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 4, 4, 512)    2048        conv2d_56[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 4, 4, 512)    0           batch_normalization_56[0][0]
#                                                                  activation_48[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 4, 4, 512)    0           add_21[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 4, 4, 128)    65664       activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 4, 4, 128)    512         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 4, 4, 128)    0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 4, 4, 128)    147584      activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 4, 4, 128)    512         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 4, 4, 128)    0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 4, 4, 512)    66048       activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 4, 4, 512)    2048        conv2d_59[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 4, 4, 512)    0           batch_normalization_59[0][0]
#                                                                  activation_51[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 4, 4, 512)    0           add_22[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 2, 2, 256)    131328      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 2, 2, 256)    1024        conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 2, 2, 256)    0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 2, 2, 256)    590080      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 2, 2, 256)    1024        conv2d_61[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 2, 2, 256)    0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 2, 2, 1024)   263168      activation_56[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 2, 2, 1024)   525312      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 2, 2, 1024)   4096        conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 2, 2, 1024)   4096        conv2d_63[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 2, 2, 1024)   0           batch_normalization_62[0][0]
#                                                                  batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 2, 2, 1024)   0           add_23[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 2, 2, 256)    262400      activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 2, 2, 256)    1024        conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 2, 2, 256)    0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 2, 2, 256)    590080      activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 2, 2, 256)    1024        conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 2, 2, 256)    0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 2, 2, 1024)   263168      activation_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 2, 2, 1024)   4096        conv2d_66[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 2, 2, 1024)   0           batch_normalization_66[0][0]
#                                                                  activation_57[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 2, 2, 1024)   0           add_24[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 2, 2, 256)    262400      activation_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 2, 2, 256)    1024        conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 2, 2, 256)    0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 2, 2, 256)    590080      activation_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 2, 2, 256)    1024        conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 2, 2, 256)    0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 2, 2, 1024)   263168      activation_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 2, 2, 1024)   4096        conv2d_69[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 2, 2, 1024)   0           batch_normalization_69[0][0]
#                                                                  activation_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 2, 2, 1024)   0           add_25[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 2, 2, 256)    262400      activation_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 2, 2, 256)    1024        conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 2, 2, 256)    0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 2, 2, 256)    590080      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 2, 2, 256)    1024        conv2d_71[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 2, 2, 256)    0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 2, 2, 1024)   263168      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 2, 2, 1024)   4096        conv2d_72[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 2, 2, 1024)   0           batch_normalization_72[0][0]
#                                                                  activation_63[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 2, 2, 1024)   0           add_26[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 2, 2, 256)    262400      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 2, 2, 256)    1024        conv2d_73[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 2, 2, 256)    0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 2, 2, 256)    590080      activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 2, 2, 256)    1024        conv2d_74[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 2, 2, 256)    0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 2, 2, 1024)   263168      activation_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 2, 2, 1024)   4096        conv2d_75[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 2, 2, 1024)   0           batch_normalization_75[0][0]
#                                                                  activation_66[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 2, 2, 1024)   0           add_27[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 2, 2, 256)    262400      activation_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 2, 2, 256)    1024        conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 2, 2, 256)    0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 2, 2, 256)    590080      activation_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 2, 2, 256)    1024        conv2d_77[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 2, 2, 256)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 2, 2, 1024)   263168      activation_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 2, 2, 1024)   4096        conv2d_78[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 2, 2, 1024)   0           batch_normalization_78[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 2, 2, 1024)   0           add_28[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 1, 1, 512)    524800      activation_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 1, 1, 512)    2048        conv2d_79[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 1, 1, 512)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 1, 1, 512)    2359808     activation_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 1, 1, 512)    2048        conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 1, 1, 512)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 1, 1, 2048)   1050624     activation_74[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 1, 1, 2048)   2099200     activation_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 1, 1, 2048)   8192        conv2d_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 1, 1, 2048)   8192        conv2d_82[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 1, 1, 2048)   0           batch_normalization_81[0][0]
#                                                                  batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 1, 1, 2048)   0           add_29[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 1, 1, 512)    1049088     activation_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 1, 1, 512)    2048        conv2d_83[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 1, 1, 512)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 1, 1, 512)    2359808     activation_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 1, 1, 512)    2048        conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 1, 1, 512)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 1, 1, 2048)   1050624     activation_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 1, 1, 2048)   8192        conv2d_85[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 1, 1, 2048)   0           batch_normalization_85[0][0]
#                                                                  activation_75[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 1, 1, 2048)   0           add_30[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 1, 1, 512)    1049088     activation_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 1, 1, 512)    2048        conv2d_86[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 1, 1, 512)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 1, 1, 512)    2359808     activation_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 1, 1, 512)    2048        conv2d_87[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 1, 1, 512)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 1, 1, 2048)   1050624     activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 1, 1, 2048)   8192        conv2d_88[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 1, 1, 2048)   0           batch_normalization_88[0][0]
#                                                                  activation_78[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 1, 1, 2048)   0           add_31[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 2048)         0           activation_81[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           20490       global_average_pooling2d_1[0][0]
# ==================================================================================================
# Total params: 23,608,202
# Trainable params: 23,555,082
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %% [markdown]
# ## 3) 일반 네트워크(plain network) 만들기

# %% [markdown]
# ### 블록 코드 수정하기
#
# 우리는 앞에서 ResNet 모델을 구현했습니다.
# ResNet의 핵심 아이디어는 **skip connection과 residual network**기 때문에,
# ResNet의 효과를 보여주기 위해서는 skip connection이 없는 일반 네트워크(plain net)가 필요합니다.
# 위에서 ResNet 블록을 만들기 위한 함수를 그대로 활용해서 **skip connection이 없는 블록을 만들 수 있도록 기능을 추가**해 주세요!

# %% [markdown]
# ### PlainNet 구현

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models, layers
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import BatchNormalization, Conv2D, Activation, Dense, GlobalAveragePooling2D, MaxPooling2D, ZeroPadding2D, Add

from tensorflow.keras import optimizers, initializers, regularizers, metrics
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, Flatten, MaxPooling2D, Dense, Input, Reshape, Concatenate, GlobalAveragePooling2D, BatchNormalization, Dropout, Activation, GlobalMaxPooling2D
from tensorflow.keras.utils import Sequence

# %%
# basic block for plainnet type 1
def plain_basic_block(inputs, n_filter, stride, bk):
    print('basic_block_input    :', bk, inputs.shape)
    
    shortcut = inputs
    
    x = Conv2D(filters=n_filter, kernel_size=(3, 3), strides=stride, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = Conv2D(filters=n_filter, kernel_size=(3, 3), strides=(1, 1), padding="same")(x)
    x = BatchNormalization()(x)
    print('basic_block_beforadd :', bk, x.shape)
    
    output  = Activation("relu")(x)
    print('basic_block_output   :', bk, output.shape)
    
    return output


# layers of basic block of plainnet type 1
def plain_basic_block_layer(inputs, n_filter, blocks, stride=(1, 1)):
    print('basic_block_laye r_input:', inputs.shape)
    bk = 0
    resnet_block = plain_basic_block(inputs, n_filter, stride=stride, bk=0)
    
    for _ in range(1, blocks):
        bk = bk + 1
        resnet_block = plain_basic_block(resnet_block, n_filter, stride=(1, 1), bk=bk)
        
    return resnet_block


def plainnet_type1(inputs, layer_params):
    print('resnet_type1_input:', inputs.shape)
    
    conv1 = Conv2D(filters=64, kernel_size=(7, 7), strides=(2, 2), padding="same")(inputs)
    bn1 = BatchNormalization()(conv1)
    act1  = Activation("relu")(bn1)
    pool1 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding="same")(act1)
    print('resnet_type1_pool1:', pool1.shape)
    
    layer1 = plain_basic_block_layer(pool1,  n_filter=64,  blocks=layer_params[0], stride=(1, 1))
    layer2 = plain_basic_block_layer(layer1, n_filter=128, blocks=layer_params[1], stride=(2, 2))
    layer3 = plain_basic_block_layer(layer2, n_filter=256, blocks=layer_params[2], stride=(2, 2))
    layer4 = plain_basic_block_layer(layer3, n_filter=512, blocks=layer_params[3], stride=(2, 2))
    
    avgpool = GlobalAveragePooling2D()(layer4)
    outputs = Dense(units=n_classes, activation='softmax')(avgpool)
    print('resnet_type1_output  :', outputs.shape)
    
    model = Model(inputs, outputs)
    
    return model

# %%
# bottle neck block for plainnet type 2
def plain_bottle_neck(inputs, n_filter, stride, bk):
    print('bottle_neck_input      :', bk, inputs.shape)
    
    shortcut = inputs
    
    x = Conv2D(filters=n_filter, kernel_size=(1, 1), strides=stride)(inputs)
    print('conv1 :', bk, x.shape)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = Conv2D(filters=n_filter, kernel_size=(3, 3), strides=(1, 1), padding="same")(x)
    print('conv2 :', bk, x.shape)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = Conv2D(filters=n_filter*4, kernel_size=(1, 1), strides=(1, 1))(x)
    print('conv3 :', bk, x.shape)
    x = BatchNormalization()(x)
    print('bottle_neck_beforadd :', bk, x.shape)
    
    output  = Activation("relu")(x)
    print('bottle_neck_output     :', bk, output.shape)
    
    return output


# layers of bottle neck of plainnet type 2
def plain_bottle_neck_layer(inputs, n_filter, blocks, stride=(1, 1)):
    print('bottle_neck_layer_input:', inputs.shape)
    bk = 0
    resnet_block = plain_bottle_neck(inputs, n_filter, stride=stride, bk=0)
    
    for _ in range(1, blocks):
        bk = bk + 1
        resnet_block = plain_bottle_neck(resnet_block, n_filter, stride=(1, 1), bk=bk)
        
    return resnet_block


def plainnet_type2(inputs, layer_params):
    print('resnet_type2_input:', inputs.shape)
    
    conv1 = Conv2D(filters=64, kernel_size=(7, 7), strides=(2, 2), padding="same")(inputs)
    bn1 = BatchNormalization()(conv1)
    act1  = Activation("relu")(bn1)
    pool1 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding="same")(act1)
    print('resnet_type2_pool1:', pool1.shape)
    
    layer1 = plain_bottle_neck_layer(pool1,  n_filter=64,  blocks=layer_params[0], stride=(1, 1))
    layer2 = plain_bottle_neck_layer(layer1, n_filter=128, blocks=layer_params[1], stride=(2, 2))
    layer3 = plain_bottle_neck_layer(layer2, n_filter=256, blocks=layer_params[2], stride=(2, 2))
    layer4 = plain_bottle_neck_layer(layer3, n_filter=512, blocks=layer_params[3], stride=(2, 2))
    
    avgpool = GlobalAveragePooling2D()(layer4)
    outputs = Dense(units=n_classes, activation='softmax')(avgpool)
    print('resnet_type2_output  :', outputs.shape)
    
    plain_model = Model(inputs, outputs)

    return plain_model

# %%
def plainnet_18(inputs):
    return plainnet_type1(inputs, layer_params=[2, 2, 2, 2])


def plainnet_34(inputs):
    return plainnet_type1(inputs, layer_params=[3, 4, 6, 3])


def plainnet_50(inputs):
    return plainnet_type2(inputs, layer_params=[3, 4, 6, 3])


def plainnet_101(inputs):
    return plainnet_type2(inputs, layer_params=[3, 4, 23, 3])


def plainnet_152(inputs):
    return plainnet_type2(inputs, layer_params=[3, 8, 36, 3])

# %% [markdown]
# ### 전체 함수 코드 수정하기
#
# 이제 위에서 만든 블록 함수를 토대로 전체 네트워크를 만들 수 있도록 전체 네트워크 코드를 수정합시다.
# - **ResNet-50과 ResNet-34**, 그리고
# - 같은 레이어를 가지지만 skip connection이 없는 **PlainNet-50과 PlainNet-34**를
# - 만들 수 있는 함수 **build_plainnet()** 를 만들어 보세요.
# - 이때 입력 이미지의 크기는 **(224, 224, 3)** 으로 해주세요.

# %%
def build_plainnet(input_shape=None, is_50=True, is_plain=True):

    input_tensor = Input(shape=input_shape, dtype='float32', name='plain_input_layer')
    
    if not is_50 and is_plain:
        plainnet = plainnet_34(input_tensor)
    elif is_50 and is_plain:
        plainnet = plainnet_50(input_tensor)
    else:
        pass
        
    return plainnet

# %% [markdown]
# ### PlainNet-34

# %%
input_shape = (224, 224, 3)
n_classes = 10

plainnet_34_model = build_plainnet(input_shape=input_shape, is_50=False, is_plain=True)
plainnet_34_model.summary()
# Out:
# resnet_type1_input: (None, 224, 224, 3)
# resnet_type1_pool1: (None, 56, 56, 64)
# basic_block_laye r_input: (None, 56, 56, 64)
# basic_block_input    : 0 (None, 56, 56, 64)
# basic_block_beforadd : 0 (None, 56, 56, 64)
# basic_block_output   : 0 (None, 56, 56, 64)
# basic_block_input    : 1 (None, 56, 56, 64)
# basic_block_beforadd : 1 (None, 56, 56, 64)
# basic_block_output   : 1 (None, 56, 56, 64)
# basic_block_input    : 2 (None, 56, 56, 64)
# basic_block_beforadd : 2 (None, 56, 56, 64)
# basic_block_output   : 2 (None, 56, 56, 64)
# basic_block_laye r_input: (None, 56, 56, 64)
# basic_block_input    : 0 (None, 56, 56, 64)
# basic_block_beforadd : 0 (None, 28, 28, 128)
# basic_block_output   : 0 (None, 28, 28, 128)
# basic_block_input    : 1 (None, 28, 28, 128)
# basic_block_beforadd : 1 (None, 28, 28, 128)
# basic_block_output   : 1 (None, 28, 28, 128)
# basic_block_input    : 2 (None, 28, 28, 128)
# basic_block_beforadd : 2 (None, 28, 28, 128)
# basic_block_output   : 2 (None, 28, 28, 128)
# basic_block_input    : 3 (None, 28, 28, 128)
# basic_block_beforadd : 3 (None, 28, 28, 128)
# basic_block_output   : 3 (None, 28, 28, 128)
# basic_block_laye r_input: (None, 28, 28, 128)
# basic_block_input    : 0 (None, 28, 28, 128)
# basic_block_beforadd : 0 (None, 14, 14, 256)
# basic_block_output   : 0 (None, 14, 14, 256)
# basic_block_input    : 1 (None, 14, 14, 256)
# basic_block_beforadd : 1 (None, 14, 14, 256)
# basic_block_output   : 1 (None, 14, 14, 256)
# basic_block_input    : 2 (None, 14, 14, 256)
# basic_block_beforadd : 2 (None, 14, 14, 256)
# basic_block_output   : 2 (None, 14, 14, 256)
# basic_block_input    : 3 (None, 14, 14, 256)
# basic_block_beforadd : 3 (None, 14, 14, 256)
# basic_block_output   : 3 (None, 14, 14, 256)
# basic_block_input    : 4 (None, 14, 14, 256)
# basic_block_beforadd : 4 (None, 14, 14, 256)
# basic_block_output   : 4 (None, 14, 14, 256)
# basic_block_input    : 5 (None, 14, 14, 256)
# basic_block_beforadd : 5 (None, 14, 14, 256)
# basic_block_output   : 5 (None, 14, 14, 256)
# basic_block_laye r_input: (None, 14, 14, 256)
# basic_block_input    : 0 (None, 14, 14, 256)
# basic_block_beforadd : 0 (None, 7, 7, 512)
# basic_block_output   : 0 (None, 7, 7, 512)
# basic_block_input    : 1 (None, 7, 7, 512)
# basic_block_beforadd : 1 (None, 7, 7, 512)
# basic_block_output   : 1 (None, 7, 7, 512)
# basic_block_input    : 2 (None, 7, 7, 512)
# basic_block_beforadd : 2 (None, 7, 7, 512)
# basic_block_output   : 2 (None, 7, 7, 512)
# resnet_type1_output  : (None, 10)
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# plain_input_layer (InputLaye [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv2d_89 (Conv2D)           (None, 112, 112, 64)      9472
# _________________________________________________________________
# batch_normalization_89 (Batc (None, 112, 112, 64)      256
# _________________________________________________________________
# activation_82 (Activation)   (None, 112, 112, 64)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_90 (Conv2D)           (None, 56, 56, 64)        36928
# _________________________________________________________________
# batch_normalization_90 (Batc (None, 56, 56, 64)        256
# _________________________________________________________________
# activation_83 (Activation)   (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_91 (Conv2D)           (None, 56, 56, 64)        36928
# _________________________________________________________________
# batch_normalization_91 (Batc (None, 56, 56, 64)        256
# _________________________________________________________________
# activation_84 (Activation)   (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_92 (Conv2D)           (None, 56, 56, 64)        36928
# _________________________________________________________________
# batch_normalization_92 (Batc (None, 56, 56, 64)        256
# _________________________________________________________________
# activation_85 (Activation)   (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_93 (Conv2D)           (None, 56, 56, 64)        36928
# _________________________________________________________________
# batch_normalization_93 (Batc (None, 56, 56, 64)        256
# _________________________________________________________________
# activation_86 (Activation)   (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_94 (Conv2D)           (None, 56, 56, 64)        36928
# _________________________________________________________________
# batch_normalization_94 (Batc (None, 56, 56, 64)        256
# _________________________________________________________________
# activation_87 (Activation)   (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_95 (Conv2D)           (None, 56, 56, 64)        36928
# _________________________________________________________________
# batch_normalization_95 (Batc (None, 56, 56, 64)        256
# _________________________________________________________________
# activation_88 (Activation)   (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_96 (Conv2D)           (None, 28, 28, 128)       73856
# _________________________________________________________________
# batch_normalization_96 (Batc (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_89 (Activation)   (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_97 (Conv2D)           (None, 28, 28, 128)       147584
# _________________________________________________________________
# batch_normalization_97 (Batc (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_90 (Activation)   (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_98 (Conv2D)           (None, 28, 28, 128)       147584
# _________________________________________________________________
# batch_normalization_98 (Batc (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_91 (Activation)   (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_99 (Conv2D)           (None, 28, 28, 128)       147584
# _________________________________________________________________
# batch_normalization_99 (Batc (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_92 (Activation)   (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_100 (Conv2D)          (None, 28, 28, 128)       147584
# _________________________________________________________________
# batch_normalization_100 (Bat (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_93 (Activation)   (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_101 (Conv2D)          (None, 28, 28, 128)       147584
# _________________________________________________________________
# batch_normalization_101 (Bat (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_94 (Activation)   (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_102 (Conv2D)          (None, 28, 28, 128)       147584
# _________________________________________________________________
# batch_normalization_102 (Bat (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_95 (Activation)   (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_103 (Conv2D)          (None, 28, 28, 128)       147584
# _________________________________________________________________
# batch_normalization_103 (Bat (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_96 (Activation)   (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_104 (Conv2D)          (None, 14, 14, 256)       295168
# _________________________________________________________________
# batch_normalization_104 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_97 (Activation)   (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_105 (Conv2D)          (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_normalization_105 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_98 (Activation)   (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_106 (Conv2D)          (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_normalization_106 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_99 (Activation)   (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_107 (Conv2D)          (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_normalization_107 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_100 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_108 (Conv2D)          (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_normalization_108 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_101 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_109 (Conv2D)          (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_normalization_109 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_102 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_110 (Conv2D)          (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_normalization_110 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_103 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_111 (Conv2D)          (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_normalization_111 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_104 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_112 (Conv2D)          (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_normalization_112 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_105 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_113 (Conv2D)          (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_normalization_113 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_106 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_114 (Conv2D)          (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_normalization_114 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_107 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_115 (Conv2D)          (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_normalization_115 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_108 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_116 (Conv2D)          (None, 7, 7, 512)         1180160
# _________________________________________________________________
# batch_normalization_116 (Bat (None, 7, 7, 512)         2048
# _________________________________________________________________
# activation_109 (Activation)  (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_117 (Conv2D)          (None, 7, 7, 512)         2359808
# _________________________________________________________________
# batch_normalization_117 (Bat (None, 7, 7, 512)         2048
# _________________________________________________________________
# activation_110 (Activation)  (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_118 (Conv2D)          (None, 7, 7, 512)         2359808
# _________________________________________________________________
# batch_normalization_118 (Bat (None, 7, 7, 512)         2048
# _________________________________________________________________
# activation_111 (Activation)  (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_119 (Conv2D)          (None, 7, 7, 512)         2359808
# _________________________________________________________________
# batch_normalization_119 (Bat (None, 7, 7, 512)         2048
# _________________________________________________________________
# activation_112 (Activation)  (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_120 (Conv2D)          (None, 7, 7, 512)         2359808
# _________________________________________________________________
# batch_normalization_120 (Bat (None, 7, 7, 512)         2048
# _________________________________________________________________
# activation_113 (Activation)  (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_121 (Conv2D)          (None, 7, 7, 512)         2359808
# _________________________________________________________________
# batch_normalization_121 (Bat (None, 7, 7, 512)         2048
# _________________________________________________________________
# activation_114 (Activation)  (None, 7, 7, 512)         0
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 21,138,826
# Trainable params: 21,123,594
# Non-trainable params: 15,232
# _________________________________________________________________

# %% [markdown]
# ### PlainNet-50

# %%
input_shape = (224, 224, 3)
n_classes = 10

plainnet_50_model = build_plainnet(input_shape=input_shape, is_50=True, is_plain=True)
plainnet_50_model.summary()
# Out:
# resnet_type2_input: (None, 224, 224, 3)
# resnet_type2_pool1: (None, 56, 56, 64)
# bottle_neck_layer_input: (None, 56, 56, 64)
# bottle_neck_input      : 0 (None, 56, 56, 64)
# conv1 : 0 (None, 56, 56, 64)
# conv2 : 0 (None, 56, 56, 64)
# conv3 : 0 (None, 56, 56, 256)
# bottle_neck_beforadd : 0 (None, 56, 56, 256)
# bottle_neck_output     : 0 (None, 56, 56, 256)
# bottle_neck_input      : 1 (None, 56, 56, 256)
# conv1 : 1 (None, 56, 56, 64)
# conv2 : 1 (None, 56, 56, 64)
# conv3 : 1 (None, 56, 56, 256)
# bottle_neck_beforadd : 1 (None, 56, 56, 256)
# bottle_neck_output     : 1 (None, 56, 56, 256)
# bottle_neck_input      : 2 (None, 56, 56, 256)
# conv1 : 2 (None, 56, 56, 64)
# conv2 : 2 (None, 56, 56, 64)
# conv3 : 2 (None, 56, 56, 256)
# bottle_neck_beforadd : 2 (None, 56, 56, 256)
# bottle_neck_output     : 2 (None, 56, 56, 256)
# bottle_neck_layer_input: (None, 56, 56, 256)
# bottle_neck_input      : 0 (None, 56, 56, 256)
# conv1 : 0 (None, 28, 28, 128)
# conv2 : 0 (None, 28, 28, 128)
# conv3 : 0 (None, 28, 28, 512)
# bottle_neck_beforadd : 0 (None, 28, 28, 512)
# bottle_neck_output     : 0 (None, 28, 28, 512)
# bottle_neck_input      : 1 (None, 28, 28, 512)
# conv1 : 1 (None, 28, 28, 128)
# conv2 : 1 (None, 28, 28, 128)
# conv3 : 1 (None, 28, 28, 512)
# bottle_neck_beforadd : 1 (None, 28, 28, 512)
# bottle_neck_output     : 1 (None, 28, 28, 512)
# bottle_neck_input      : 2 (None, 28, 28, 512)
# conv1 : 2 (None, 28, 28, 128)
# conv2 : 2 (None, 28, 28, 128)
# conv3 : 2 (None, 28, 28, 512)
# bottle_neck_beforadd : 2 (None, 28, 28, 512)
# bottle_neck_output     : 2 (None, 28, 28, 512)
# bottle_neck_input      : 3 (None, 28, 28, 512)
# conv1 : 3 (None, 28, 28, 128)
# conv2 : 3 (None, 28, 28, 128)
# conv3 : 3 (None, 28, 28, 512)
# bottle_neck_beforadd : 3 (None, 28, 28, 512)
# bottle_neck_output     : 3 (None, 28, 28, 512)
# bottle_neck_layer_input: (None, 28, 28, 512)
# bottle_neck_input      : 0 (None, 28, 28, 512)
# conv1 : 0 (None, 14, 14, 256)
# conv2 : 0 (None, 14, 14, 256)
# conv3 : 0 (None, 14, 14, 1024)
# bottle_neck_beforadd : 0 (None, 14, 14, 1024)
# bottle_neck_output     : 0 (None, 14, 14, 1024)
# bottle_neck_input      : 1 (None, 14, 14, 1024)
# conv1 : 1 (None, 14, 14, 256)
# conv2 : 1 (None, 14, 14, 256)
# conv3 : 1 (None, 14, 14, 1024)
# bottle_neck_beforadd : 1 (None, 14, 14, 1024)
# bottle_neck_output     : 1 (None, 14, 14, 1024)
# bottle_neck_input      : 2 (None, 14, 14, 1024)
# conv1 : 2 (None, 14, 14, 256)
# conv2 : 2 (None, 14, 14, 256)
# conv3 : 2 (None, 14, 14, 1024)
# bottle_neck_beforadd : 2 (None, 14, 14, 1024)
# bottle_neck_output     : 2 (None, 14, 14, 1024)
# bottle_neck_input      : 3 (None, 14, 14, 1024)
# conv1 : 3 (None, 14, 14, 256)
# conv2 : 3 (None, 14, 14, 256)
# conv3 : 3 (None, 14, 14, 1024)
# bottle_neck_beforadd : 3 (None, 14, 14, 1024)
# bottle_neck_output     : 3 (None, 14, 14, 1024)
# bottle_neck_input      : 4 (None, 14, 14, 1024)
# conv1 : 4 (None, 14, 14, 256)
# conv2 : 4 (None, 14, 14, 256)
# conv3 : 4 (None, 14, 14, 1024)
# bottle_neck_beforadd : 4 (None, 14, 14, 1024)
# bottle_neck_output     : 4 (None, 14, 14, 1024)
# bottle_neck_input      : 5 (None, 14, 14, 1024)
# conv1 : 5 (None, 14, 14, 256)
# conv2 : 5 (None, 14, 14, 256)
# conv3 : 5 (None, 14, 14, 1024)
# bottle_neck_beforadd : 5 (None, 14, 14, 1024)
# bottle_neck_output     : 5 (None, 14, 14, 1024)
# bottle_neck_layer_input: (None, 14, 14, 1024)
# bottle_neck_input      : 0 (None, 14, 14, 1024)
# conv1 : 0 (None, 7, 7, 512)
# conv2 : 0 (None, 7, 7, 512)
# conv3 : 0 (None, 7, 7, 2048)
# bottle_neck_beforadd : 0 (None, 7, 7, 2048)
# bottle_neck_output     : 0 (None, 7, 7, 2048)
# bottle_neck_input      : 1 (None, 7, 7, 2048)
# conv1 : 1 (None, 7, 7, 512)
# conv2 : 1 (None, 7, 7, 512)
# conv3 : 1 (None, 7, 7, 2048)
# bottle_neck_beforadd : 1 (None, 7, 7, 2048)
# bottle_neck_output     : 1 (None, 7, 7, 2048)
# bottle_neck_input      : 2 (None, 7, 7, 2048)
# conv1 : 2 (None, 7, 7, 512)
# conv2 : 2 (None, 7, 7, 512)
# conv3 : 2 (None, 7, 7, 2048)
# bottle_neck_beforadd : 2 (None, 7, 7, 2048)
# bottle_neck_output     : 2 (None, 7, 7, 2048)
# resnet_type2_output  : (None, 10)
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# plain_input_layer (InputLaye [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv2d_122 (Conv2D)          (None, 112, 112, 64)      9472
# _________________________________________________________________
# batch_normalization_122 (Bat (None, 112, 112, 64)      256
# _________________________________________________________________
# activation_115 (Activation)  (None, 112, 112, 64)      0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_123 (Conv2D)          (None, 56, 56, 64)        4160
# _________________________________________________________________
# batch_normalization_123 (Bat (None, 56, 56, 64)        256
# _________________________________________________________________
# activation_116 (Activation)  (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_124 (Conv2D)          (None, 56, 56, 64)        36928
# _________________________________________________________________
# batch_normalization_124 (Bat (None, 56, 56, 64)        256
# _________________________________________________________________
# activation_117 (Activation)  (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_125 (Conv2D)          (None, 56, 56, 256)       16640
# _________________________________________________________________
# batch_normalization_125 (Bat (None, 56, 56, 256)       1024
# _________________________________________________________________
# activation_118 (Activation)  (None, 56, 56, 256)       0
# _________________________________________________________________
# conv2d_126 (Conv2D)          (None, 56, 56, 64)        16448
# _________________________________________________________________
# batch_normalization_126 (Bat (None, 56, 56, 64)        256
# _________________________________________________________________
# activation_119 (Activation)  (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_127 (Conv2D)          (None, 56, 56, 64)        36928
# _________________________________________________________________
# batch_normalization_127 (Bat (None, 56, 56, 64)        256
# _________________________________________________________________
# activation_120 (Activation)  (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_128 (Conv2D)          (None, 56, 56, 256)       16640
# _________________________________________________________________
# batch_normalization_128 (Bat (None, 56, 56, 256)       1024
# _________________________________________________________________
# activation_121 (Activation)  (None, 56, 56, 256)       0
# _________________________________________________________________
# conv2d_129 (Conv2D)          (None, 56, 56, 64)        16448
# _________________________________________________________________
# batch_normalization_129 (Bat (None, 56, 56, 64)        256
# _________________________________________________________________
# activation_122 (Activation)  (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_130 (Conv2D)          (None, 56, 56, 64)        36928
# _________________________________________________________________
# batch_normalization_130 (Bat (None, 56, 56, 64)        256
# _________________________________________________________________
# activation_123 (Activation)  (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_131 (Conv2D)          (None, 56, 56, 256)       16640
# _________________________________________________________________
# batch_normalization_131 (Bat (None, 56, 56, 256)       1024
# _________________________________________________________________
# activation_124 (Activation)  (None, 56, 56, 256)       0
# _________________________________________________________________
# conv2d_132 (Conv2D)          (None, 28, 28, 128)       32896
# _________________________________________________________________
# batch_normalization_132 (Bat (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_125 (Activation)  (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_133 (Conv2D)          (None, 28, 28, 128)       147584
# _________________________________________________________________
# batch_normalization_133 (Bat (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_126 (Activation)  (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_134 (Conv2D)          (None, 28, 28, 512)       66048
# _________________________________________________________________
# batch_normalization_134 (Bat (None, 28, 28, 512)       2048
# _________________________________________________________________
# activation_127 (Activation)  (None, 28, 28, 512)       0
# _________________________________________________________________
# conv2d_135 (Conv2D)          (None, 28, 28, 128)       65664
# _________________________________________________________________
# batch_normalization_135 (Bat (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_128 (Activation)  (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_136 (Conv2D)          (None, 28, 28, 128)       147584
# _________________________________________________________________
# batch_normalization_136 (Bat (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_129 (Activation)  (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_137 (Conv2D)          (None, 28, 28, 512)       66048
# _________________________________________________________________
# batch_normalization_137 (Bat (None, 28, 28, 512)       2048
# _________________________________________________________________
# activation_130 (Activation)  (None, 28, 28, 512)       0
# _________________________________________________________________
# conv2d_138 (Conv2D)          (None, 28, 28, 128)       65664
# _________________________________________________________________
# batch_normalization_138 (Bat (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_131 (Activation)  (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_139 (Conv2D)          (None, 28, 28, 128)       147584
# _________________________________________________________________
# batch_normalization_139 (Bat (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_132 (Activation)  (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_140 (Conv2D)          (None, 28, 28, 512)       66048
# _________________________________________________________________
# batch_normalization_140 (Bat (None, 28, 28, 512)       2048
# _________________________________________________________________
# activation_133 (Activation)  (None, 28, 28, 512)       0
# _________________________________________________________________
# conv2d_141 (Conv2D)          (None, 28, 28, 128)       65664
# _________________________________________________________________
# batch_normalization_141 (Bat (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_134 (Activation)  (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_142 (Conv2D)          (None, 28, 28, 128)       147584
# _________________________________________________________________
# batch_normalization_142 (Bat (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_135 (Activation)  (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_143 (Conv2D)          (None, 28, 28, 512)       66048
# _________________________________________________________________
# batch_normalization_143 (Bat (None, 28, 28, 512)       2048
# _________________________________________________________________
# activation_136 (Activation)  (None, 28, 28, 512)       0
# _________________________________________________________________
# conv2d_144 (Conv2D)          (None, 14, 14, 256)       131328
# _________________________________________________________________
# batch_normalization_144 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_137 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_145 (Conv2D)          (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_normalization_145 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_138 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_146 (Conv2D)          (None, 14, 14, 1024)      263168
# _________________________________________________________________
# batch_normalization_146 (Bat (None, 14, 14, 1024)      4096
# _________________________________________________________________
# activation_139 (Activation)  (None, 14, 14, 1024)      0
# _________________________________________________________________
# conv2d_147 (Conv2D)          (None, 14, 14, 256)       262400
# _________________________________________________________________
# batch_normalization_147 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_140 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_148 (Conv2D)          (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_normalization_148 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_141 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_149 (Conv2D)          (None, 14, 14, 1024)      263168
# _________________________________________________________________
# batch_normalization_149 (Bat (None, 14, 14, 1024)      4096
# _________________________________________________________________
# activation_142 (Activation)  (None, 14, 14, 1024)      0
# _________________________________________________________________
# conv2d_150 (Conv2D)          (None, 14, 14, 256)       262400
# _________________________________________________________________
# batch_normalization_150 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_143 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_151 (Conv2D)          (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_normalization_151 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_144 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_152 (Conv2D)          (None, 14, 14, 1024)      263168
# _________________________________________________________________
# batch_normalization_152 (Bat (None, 14, 14, 1024)      4096
# _________________________________________________________________
# activation_145 (Activation)  (None, 14, 14, 1024)      0
# _________________________________________________________________
# conv2d_153 (Conv2D)          (None, 14, 14, 256)       262400
# _________________________________________________________________
# batch_normalization_153 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_146 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_154 (Conv2D)          (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_normalization_154 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_147 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_155 (Conv2D)          (None, 14, 14, 1024)      263168
# _________________________________________________________________
# batch_normalization_155 (Bat (None, 14, 14, 1024)      4096
# _________________________________________________________________
# activation_148 (Activation)  (None, 14, 14, 1024)      0
# _________________________________________________________________
# conv2d_156 (Conv2D)          (None, 14, 14, 256)       262400
# _________________________________________________________________
# batch_normalization_156 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_149 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_157 (Conv2D)          (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_normalization_157 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_150 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_158 (Conv2D)          (None, 14, 14, 1024)      263168
# _________________________________________________________________
# batch_normalization_158 (Bat (None, 14, 14, 1024)      4096
# _________________________________________________________________
# activation_151 (Activation)  (None, 14, 14, 1024)      0
# _________________________________________________________________
# conv2d_159 (Conv2D)          (None, 14, 14, 256)       262400
# _________________________________________________________________
# batch_normalization_159 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_152 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_160 (Conv2D)          (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_normalization_160 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_153 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_161 (Conv2D)          (None, 14, 14, 1024)      263168
# _________________________________________________________________
# batch_normalization_161 (Bat (None, 14, 14, 1024)      4096
# _________________________________________________________________
# activation_154 (Activation)  (None, 14, 14, 1024)      0
# _________________________________________________________________
# conv2d_162 (Conv2D)          (None, 7, 7, 512)         524800
# _________________________________________________________________
# batch_normalization_162 (Bat (None, 7, 7, 512)         2048
# _________________________________________________________________
# activation_155 (Activation)  (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_163 (Conv2D)          (None, 7, 7, 512)         2359808
# _________________________________________________________________
# batch_normalization_163 (Bat (None, 7, 7, 512)         2048
# _________________________________________________________________
# activation_156 (Activation)  (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_164 (Conv2D)          (None, 7, 7, 2048)        1050624
# _________________________________________________________________
# batch_normalization_164 (Bat (None, 7, 7, 2048)        8192
# _________________________________________________________________
# activation_157 (Activation)  (None, 7, 7, 2048)        0
# _________________________________________________________________
# conv2d_165 (Conv2D)          (None, 7, 7, 512)         1049088
# _________________________________________________________________
# batch_normalization_165 (Bat (None, 7, 7, 512)         2048
# _________________________________________________________________
# activation_158 (Activation)  (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_166 (Conv2D)          (None, 7, 7, 512)         2359808
# _________________________________________________________________
# batch_normalization_166 (Bat (None, 7, 7, 512)         2048
# _________________________________________________________________
# activation_159 (Activation)  (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_167 (Conv2D)          (None, 7, 7, 2048)        1050624
# _________________________________________________________________
# batch_normalization_167 (Bat (None, 7, 7, 2048)        8192
# _________________________________________________________________
# activation_160 (Activation)  (None, 7, 7, 2048)        0
# _________________________________________________________________
# conv2d_168 (Conv2D)          (None, 7, 7, 512)         1049088
# _________________________________________________________________
# batch_normalization_168 (Bat (None, 7, 7, 512)         2048
# _________________________________________________________________
# activation_161 (Activation)  (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_169 (Conv2D)          (None, 7, 7, 512)         2359808
# _________________________________________________________________
# batch_normalization_169 (Bat (None, 7, 7, 512)         2048
# _________________________________________________________________
# activation_162 (Activation)  (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_170 (Conv2D)          (None, 7, 7, 2048)        1050624
# _________________________________________________________________
# batch_normalization_170 (Bat (None, 7, 7, 2048)        8192
# _________________________________________________________________
# activation_163 (Activation)  (None, 7, 7, 2048)        0
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 20,820,106
# Trainable params: 20,774,666
# Non-trainable params: 45,440
# _________________________________________________________________

# %% [markdown]
# ## 4) ResNet-50 vs Plain-50 또는 ResNet-34 vs Plain-34

# %% [markdown]
# ### Ablation Study

# %%
BATCH_SIZE = 256   # 이미지 크기가 작으므로
IMAGE_SIZE = 32
EPOCH = 5

# %%
#  CIFAR-10 데이터셋을 불러오기
(ds_train, ds_test), ds_info = tfds.load(
    'cifar10',
    split=['train', 'test'],
    as_supervised=True,
    shuffle_files=True,
    with_info=True,
)
ds_train = apply_normalize_on_dataset(ds_train, batch_size=BATCH_SIZE)
ds_test = apply_normalize_on_dataset(ds_test, batch_size=BATCH_SIZE)

# %% [markdown]
# ####  ResNet-50 vs Plain-50 또는 ResNet-34 vs Plain-34에 대해서 학습

# %% [markdown]
# #### ResNet-50 for cifar10

# %%
del resnet_50_model

input_shape = (32, 32, 3)  # cifar10.shape = (32, 32, 3)
n_classes = 10

resnet_50_model = build_resnet(input_shape=input_shape, is_50=True)
resnet_50_model.summary()
# Out:
# resnet_type2_input: (None, 32, 32, 3)
# resnet_type2_pool1: (None, 8, 8, 64)
# bottle_neck_layer_input: (None, 8, 8, 64)
# bottle_neck_input      : 0 (None, 8, 8, 64)
# conv1 : 0 (None, 8, 8, 64)
# conv2 : 0 (None, 8, 8, 64)
# conv3 : 0 (None, 8, 8, 256)
# bottle_neck_beforadd : 0 (None, 8, 8, 256)
# skip_bottle_neck_input : 0 (None, 8, 8, 64)
# skip_bottle_neck_output: 0 (None, 8, 8, 256)
# bottle_neck_shortcut : 0 (None, 8, 8, 256)
# bottle_neck_output     : 0 (None, 8, 8, 256)
# bottle_neck_input      : 1 (None, 8, 8, 256)
# conv1 : 1 (None, 8, 8, 64)
# conv2 : 1 (None, 8, 8, 64)
# conv3 : 1 (None, 8, 8, 256)
# bottle_neck_beforadd : 1 (None, 8, 8, 256)
# skip_bottle_neck_input : 1 (None, 8, 8, 256)
# skip_bottle_neck_output: 1 (None, 8, 8, 256)
# bottle_neck_shortcut : 1 (None, 8, 8, 256)
# bottle_neck_output     : 1 (None, 8, 8, 256)
# bottle_neck_input      : 2 (None, 8, 8, 256)
# conv1 : 2 (None, 8, 8, 64)
# conv2 : 2 (None, 8, 8, 64)
# conv3 : 2 (None, 8, 8, 256)
# bottle_neck_beforadd : 2 (None, 8, 8, 256)
# skip_bottle_neck_input : 2 (None, 8, 8, 256)
# skip_bottle_neck_output: 2 (None, 8, 8, 256)
# bottle_neck_shortcut : 2 (None, 8, 8, 256)
# bottle_neck_output     : 2 (None, 8, 8, 256)
# bottle_neck_layer_input: (None, 8, 8, 256)
# bottle_neck_input      : 0 (None, 8, 8, 256)
# conv1 : 0 (None, 4, 4, 128)
# conv2 : 0 (None, 4, 4, 128)
# conv3 : 0 (None, 4, 4, 512)
# bottle_neck_beforadd : 0 (None, 4, 4, 512)
# skip_bottle_neck_input : 0 (None, 8, 8, 256)
# skip_bottle_neck_output: 0 (None, 4, 4, 512)
# bottle_neck_shortcut : 0 (None, 4, 4, 512)
# bottle_neck_output     : 0 (None, 4, 4, 512)
# bottle_neck_input      : 1 (None, 4, 4, 512)
# conv1 : 1 (None, 4, 4, 128)
# conv2 : 1 (None, 4, 4, 128)
# conv3 : 1 (None, 4, 4, 512)
# bottle_neck_beforadd : 1 (None, 4, 4, 512)
# skip_bottle_neck_input : 1 (None, 4, 4, 512)
# skip_bottle_neck_output: 1 (None, 4, 4, 512)
# bottle_neck_shortcut : 1 (None, 4, 4, 512)
# bottle_neck_output     : 1 (None, 4, 4, 512)
# bottle_neck_input      : 2 (None, 4, 4, 512)
# conv1 : 2 (None, 4, 4, 128)
# conv2 : 2 (None, 4, 4, 128)
# conv3 : 2 (None, 4, 4, 512)
# bottle_neck_beforadd : 2 (None, 4, 4, 512)
# skip_bottle_neck_input : 2 (None, 4, 4, 512)
# skip_bottle_neck_output: 2 (None, 4, 4, 512)
# bottle_neck_shortcut : 2 (None, 4, 4, 512)
# bottle_neck_output     : 2 (None, 4, 4, 512)
# bottle_neck_input      : 3 (None, 4, 4, 512)
# conv1 : 3 (None, 4, 4, 128)
# conv2 : 3 (None, 4, 4, 128)
# conv3 : 3 (None, 4, 4, 512)
# bottle_neck_beforadd : 3 (None, 4, 4, 512)
# skip_bottle_neck_input : 3 (None, 4, 4, 512)
# skip_bottle_neck_output: 3 (None, 4, 4, 512)
# bottle_neck_shortcut : 3 (None, 4, 4, 512)
# bottle_neck_output     : 3 (None, 4, 4, 512)
# bottle_neck_layer_input: (None, 4, 4, 512)
# bottle_neck_input      : 0 (None, 4, 4, 512)
# conv1 : 0 (None, 2, 2, 256)
# conv2 : 0 (None, 2, 2, 256)
# conv3 : 0 (None, 2, 2, 1024)
# bottle_neck_beforadd : 0 (None, 2, 2, 1024)
# skip_bottle_neck_input : 0 (None, 4, 4, 512)
# skip_bottle_neck_output: 0 (None, 2, 2, 1024)
# bottle_neck_shortcut : 0 (None, 2, 2, 1024)
# bottle_neck_output     : 0 (None, 2, 2, 1024)
# bottle_neck_input      : 1 (None, 2, 2, 1024)
# conv1 : 1 (None, 2, 2, 256)
# conv2 : 1 (None, 2, 2, 256)
# conv3 : 1 (None, 2, 2, 1024)
# bottle_neck_beforadd : 1 (None, 2, 2, 1024)
# skip_bottle_neck_input : 1 (None, 2, 2, 1024)
# skip_bottle_neck_output: 1 (None, 2, 2, 1024)
# bottle_neck_shortcut : 1 (None, 2, 2, 1024)
# bottle_neck_output     : 1 (None, 2, 2, 1024)
# bottle_neck_input      : 2 (None, 2, 2, 1024)
# conv1 : 2 (None, 2, 2, 256)
# conv2 : 2 (None, 2, 2, 256)
# conv3 : 2 (None, 2, 2, 1024)
# bottle_neck_beforadd : 2 (None, 2, 2, 1024)
# skip_bottle_neck_input : 2 (None, 2, 2, 1024)
# skip_bottle_neck_output: 2 (None, 2, 2, 1024)
# bottle_neck_shortcut : 2 (None, 2, 2, 1024)
# bottle_neck_output     : 2 (None, 2, 2, 1024)
# bottle_neck_input      : 3 (None, 2, 2, 1024)
# conv1 : 3 (None, 2, 2, 256)
# conv2 : 3 (None, 2, 2, 256)
# conv3 : 3 (None, 2, 2, 1024)
# bottle_neck_beforadd : 3 (None, 2, 2, 1024)
# skip_bottle_neck_input : 3 (None, 2, 2, 1024)
# skip_bottle_neck_output: 3 (None, 2, 2, 1024)
# bottle_neck_shortcut : 3 (None, 2, 2, 1024)
# bottle_neck_output     : 3 (None, 2, 2, 1024)
# bottle_neck_input      : 4 (None, 2, 2, 1024)
# conv1 : 4 (None, 2, 2, 256)
# conv2 : 4 (None, 2, 2, 256)
# conv3 : 4 (None, 2, 2, 1024)
# bottle_neck_beforadd : 4 (None, 2, 2, 1024)
# skip_bottle_neck_input : 4 (None, 2, 2, 1024)
# skip_bottle_neck_output: 4 (None, 2, 2, 1024)
# bottle_neck_shortcut : 4 (None, 2, 2, 1024)
# bottle_neck_output     : 4 (None, 2, 2, 1024)
# bottle_neck_input      : 5 (None, 2, 2, 1024)
# conv1 : 5 (None, 2, 2, 256)
# conv2 : 5 (None, 2, 2, 256)
# conv3 : 5 (None, 2, 2, 1024)
# bottle_neck_beforadd : 5 (None, 2, 2, 1024)
# skip_bottle_neck_input : 5 (None, 2, 2, 1024)
# skip_bottle_neck_output: 5 (None, 2, 2, 1024)
# bottle_neck_shortcut : 5 (None, 2, 2, 1024)
# bottle_neck_output     : 5 (None, 2, 2, 1024)
# bottle_neck_layer_input: (None, 2, 2, 1024)
# bottle_neck_input      : 0 (None, 2, 2, 1024)
# conv1 : 0 (None, 1, 1, 512)
# conv2 : 0 (None, 1, 1, 512)
# conv3 : 0 (None, 1, 1, 2048)
# bottle_neck_beforadd : 0 (None, 1, 1, 2048)
# skip_bottle_neck_input : 0 (None, 2, 2, 1024)
# skip_bottle_neck_output: 0 (None, 1, 1, 2048)
# bottle_neck_shortcut : 0 (None, 1, 1, 2048)
# bottle_neck_output     : 0 (None, 1, 1, 2048)
# bottle_neck_input      : 1 (None, 1, 1, 2048)
# conv1 : 1 (None, 1, 1, 512)
# conv2 : 1 (None, 1, 1, 512)
# conv3 : 1 (None, 1, 1, 2048)
# bottle_neck_beforadd : 1 (None, 1, 1, 2048)
# skip_bottle_neck_input : 1 (None, 1, 1, 2048)
# skip_bottle_neck_output: 1 (None, 1, 1, 2048)
# bottle_neck_shortcut : 1 (None, 1, 1, 2048)
# bottle_neck_output     : 1 (None, 1, 1, 2048)
# bottle_neck_input      : 2 (None, 1, 1, 2048)
# conv1 : 2 (None, 1, 1, 512)
# conv2 : 2 (None, 1, 1, 512)
# conv3 : 2 (None, 1, 1, 2048)
# bottle_neck_beforadd : 2 (None, 1, 1, 2048)
# skip_bottle_neck_input : 2 (None, 1, 1, 2048)
# skip_bottle_neck_output: 2 (None, 1, 1, 2048)
# bottle_neck_shortcut : 2 (None, 1, 1, 2048)
# bottle_neck_output     : 2 (None, 1, 1, 2048)
# resnet_type2_output  : (None, 10)
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_layer (InputLayer)        [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_171 (Conv2D)             (None, 16, 16, 64)   9472        input_layer[0][0]
# __________________________________________________________________________________________________
# batch_normalization_171 (BatchN (None, 16, 16, 64)   256         conv2d_171[0][0]
# __________________________________________________________________________________________________
# activation_164 (Activation)     (None, 16, 16, 64)   0           batch_normalization_171[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 64)     0           activation_164[0][0]
# __________________________________________________________________________________________________
# conv2d_172 (Conv2D)             (None, 8, 8, 64)     4160        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_172 (BatchN (None, 8, 8, 64)     256         conv2d_172[0][0]
# __________________________________________________________________________________________________
# activation_165 (Activation)     (None, 8, 8, 64)     0           batch_normalization_172[0][0]
# __________________________________________________________________________________________________
# conv2d_173 (Conv2D)             (None, 8, 8, 64)     36928       activation_165[0][0]
# __________________________________________________________________________________________________
# batch_normalization_173 (BatchN (None, 8, 8, 64)     256         conv2d_173[0][0]
# __________________________________________________________________________________________________
# activation_166 (Activation)     (None, 8, 8, 64)     0           batch_normalization_173[0][0]
# __________________________________________________________________________________________________
# conv2d_174 (Conv2D)             (None, 8, 8, 256)    16640       activation_166[0][0]
# __________________________________________________________________________________________________
# conv2d_175 (Conv2D)             (None, 8, 8, 256)    16640       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_174 (BatchN (None, 8, 8, 256)    1024        conv2d_174[0][0]
# __________________________________________________________________________________________________
# batch_normalization_175 (BatchN (None, 8, 8, 256)    1024        conv2d_175[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 8, 8, 256)    0           batch_normalization_174[0][0]
#                                                                  batch_normalization_175[0][0]
# __________________________________________________________________________________________________
# activation_167 (Activation)     (None, 8, 8, 256)    0           add_32[0][0]
# __________________________________________________________________________________________________
# conv2d_176 (Conv2D)             (None, 8, 8, 64)     16448       activation_167[0][0]
# __________________________________________________________________________________________________
# batch_normalization_176 (BatchN (None, 8, 8, 64)     256         conv2d_176[0][0]
# __________________________________________________________________________________________________
# activation_168 (Activation)     (None, 8, 8, 64)     0           batch_normalization_176[0][0]
# __________________________________________________________________________________________________
# conv2d_177 (Conv2D)             (None, 8, 8, 64)     36928       activation_168[0][0]
# __________________________________________________________________________________________________
# batch_normalization_177 (BatchN (None, 8, 8, 64)     256         conv2d_177[0][0]
# __________________________________________________________________________________________________
# activation_169 (Activation)     (None, 8, 8, 64)     0           batch_normalization_177[0][0]
# __________________________________________________________________________________________________
# conv2d_178 (Conv2D)             (None, 8, 8, 256)    16640       activation_169[0][0]
# __________________________________________________________________________________________________
# batch_normalization_178 (BatchN (None, 8, 8, 256)    1024        conv2d_178[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 8, 8, 256)    0           batch_normalization_178[0][0]
#                                                                  activation_167[0][0]
# __________________________________________________________________________________________________
# activation_170 (Activation)     (None, 8, 8, 256)    0           add_33[0][0]
# __________________________________________________________________________________________________
# conv2d_179 (Conv2D)             (None, 8, 8, 64)     16448       activation_170[0][0]
# __________________________________________________________________________________________________
# batch_normalization_179 (BatchN (None, 8, 8, 64)     256         conv2d_179[0][0]
# __________________________________________________________________________________________________
# activation_171 (Activation)     (None, 8, 8, 64)     0           batch_normalization_179[0][0]
# __________________________________________________________________________________________________
# conv2d_180 (Conv2D)             (None, 8, 8, 64)     36928       activation_171[0][0]
# __________________________________________________________________________________________________
# batch_normalization_180 (BatchN (None, 8, 8, 64)     256         conv2d_180[0][0]
# __________________________________________________________________________________________________
# activation_172 (Activation)     (None, 8, 8, 64)     0           batch_normalization_180[0][0]
# __________________________________________________________________________________________________
# conv2d_181 (Conv2D)             (None, 8, 8, 256)    16640       activation_172[0][0]
# __________________________________________________________________________________________________
# batch_normalization_181 (BatchN (None, 8, 8, 256)    1024        conv2d_181[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 8, 8, 256)    0           batch_normalization_181[0][0]
#                                                                  activation_170[0][0]
# __________________________________________________________________________________________________
# activation_173 (Activation)     (None, 8, 8, 256)    0           add_34[0][0]
# __________________________________________________________________________________________________
# conv2d_182 (Conv2D)             (None, 4, 4, 128)    32896       activation_173[0][0]
# __________________________________________________________________________________________________
# batch_normalization_182 (BatchN (None, 4, 4, 128)    512         conv2d_182[0][0]
# __________________________________________________________________________________________________
# activation_174 (Activation)     (None, 4, 4, 128)    0           batch_normalization_182[0][0]
# __________________________________________________________________________________________________
# conv2d_183 (Conv2D)             (None, 4, 4, 128)    147584      activation_174[0][0]
# __________________________________________________________________________________________________
# batch_normalization_183 (BatchN (None, 4, 4, 128)    512         conv2d_183[0][0]
# __________________________________________________________________________________________________
# activation_175 (Activation)     (None, 4, 4, 128)    0           batch_normalization_183[0][0]
# __________________________________________________________________________________________________
# conv2d_184 (Conv2D)             (None, 4, 4, 512)    66048       activation_175[0][0]
# __________________________________________________________________________________________________
# conv2d_185 (Conv2D)             (None, 4, 4, 512)    131584      activation_173[0][0]
# __________________________________________________________________________________________________
# batch_normalization_184 (BatchN (None, 4, 4, 512)    2048        conv2d_184[0][0]
# __________________________________________________________________________________________________
# batch_normalization_185 (BatchN (None, 4, 4, 512)    2048        conv2d_185[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 4, 4, 512)    0           batch_normalization_184[0][0]
#                                                                  batch_normalization_185[0][0]
# __________________________________________________________________________________________________
# activation_176 (Activation)     (None, 4, 4, 512)    0           add_35[0][0]
# __________________________________________________________________________________________________
# conv2d_186 (Conv2D)             (None, 4, 4, 128)    65664       activation_176[0][0]
# __________________________________________________________________________________________________
# batch_normalization_186 (BatchN (None, 4, 4, 128)    512         conv2d_186[0][0]
# __________________________________________________________________________________________________
# activation_177 (Activation)     (None, 4, 4, 128)    0           batch_normalization_186[0][0]
# __________________________________________________________________________________________________
# conv2d_187 (Conv2D)             (None, 4, 4, 128)    147584      activation_177[0][0]
# __________________________________________________________________________________________________
# batch_normalization_187 (BatchN (None, 4, 4, 128)    512         conv2d_187[0][0]
# __________________________________________________________________________________________________
# activation_178 (Activation)     (None, 4, 4, 128)    0           batch_normalization_187[0][0]
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, 4, 4, 512)    66048       activation_178[0][0]
# __________________________________________________________________________________________________
# batch_normalization_188 (BatchN (None, 4, 4, 512)    2048        conv2d_188[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 4, 4, 512)    0           batch_normalization_188[0][0]
#                                                                  activation_176[0][0]
# __________________________________________________________________________________________________
# activation_179 (Activation)     (None, 4, 4, 512)    0           add_36[0][0]
# __________________________________________________________________________________________________
# conv2d_189 (Conv2D)             (None, 4, 4, 128)    65664       activation_179[0][0]
# __________________________________________________________________________________________________
# batch_normalization_189 (BatchN (None, 4, 4, 128)    512         conv2d_189[0][0]
# __________________________________________________________________________________________________
# activation_180 (Activation)     (None, 4, 4, 128)    0           batch_normalization_189[0][0]
# __________________________________________________________________________________________________
# conv2d_190 (Conv2D)             (None, 4, 4, 128)    147584      activation_180[0][0]
# __________________________________________________________________________________________________
# batch_normalization_190 (BatchN (None, 4, 4, 128)    512         conv2d_190[0][0]
# __________________________________________________________________________________________________
# activation_181 (Activation)     (None, 4, 4, 128)    0           batch_normalization_190[0][0]
# __________________________________________________________________________________________________
# conv2d_191 (Conv2D)             (None, 4, 4, 512)    66048       activation_181[0][0]
# __________________________________________________________________________________________________
# batch_normalization_191 (BatchN (None, 4, 4, 512)    2048        conv2d_191[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, 4, 4, 512)    0           batch_normalization_191[0][0]
#                                                                  activation_179[0][0]
# __________________________________________________________________________________________________
# activation_182 (Activation)     (None, 4, 4, 512)    0           add_37[0][0]
# __________________________________________________________________________________________________
# conv2d_192 (Conv2D)             (None, 4, 4, 128)    65664       activation_182[0][0]
# __________________________________________________________________________________________________
# batch_normalization_192 (BatchN (None, 4, 4, 128)    512         conv2d_192[0][0]
# __________________________________________________________________________________________________
# activation_183 (Activation)     (None, 4, 4, 128)    0           batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# conv2d_193 (Conv2D)             (None, 4, 4, 128)    147584      activation_183[0][0]
# __________________________________________________________________________________________________
# batch_normalization_193 (BatchN (None, 4, 4, 128)    512         conv2d_193[0][0]
# __________________________________________________________________________________________________
# activation_184 (Activation)     (None, 4, 4, 128)    0           batch_normalization_193[0][0]
# __________________________________________________________________________________________________
# conv2d_194 (Conv2D)             (None, 4, 4, 512)    66048       activation_184[0][0]
# __________________________________________________________________________________________________
# batch_normalization_194 (BatchN (None, 4, 4, 512)    2048        conv2d_194[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, 4, 4, 512)    0           batch_normalization_194[0][0]
#                                                                  activation_182[0][0]
# __________________________________________________________________________________________________
# activation_185 (Activation)     (None, 4, 4, 512)    0           add_38[0][0]
# __________________________________________________________________________________________________
# conv2d_195 (Conv2D)             (None, 2, 2, 256)    131328      activation_185[0][0]
# __________________________________________________________________________________________________
# batch_normalization_195 (BatchN (None, 2, 2, 256)    1024        conv2d_195[0][0]
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, 2, 2, 256)    0           batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# conv2d_196 (Conv2D)             (None, 2, 2, 256)    590080      activation_186[0][0]
# __________________________________________________________________________________________________
# batch_normalization_196 (BatchN (None, 2, 2, 256)    1024        conv2d_196[0][0]
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, 2, 2, 256)    0           batch_normalization_196[0][0]
# __________________________________________________________________________________________________
# conv2d_197 (Conv2D)             (None, 2, 2, 1024)   263168      activation_187[0][0]
# __________________________________________________________________________________________________
# conv2d_198 (Conv2D)             (None, 2, 2, 1024)   525312      activation_185[0][0]
# __________________________________________________________________________________________________
# batch_normalization_197 (BatchN (None, 2, 2, 1024)   4096        conv2d_197[0][0]
# __________________________________________________________________________________________________
# batch_normalization_198 (BatchN (None, 2, 2, 1024)   4096        conv2d_198[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, 2, 2, 1024)   0           batch_normalization_197[0][0]
#                                                                  batch_normalization_198[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, 2, 2, 1024)   0           add_39[0][0]
# __________________________________________________________________________________________________
# conv2d_199 (Conv2D)             (None, 2, 2, 256)    262400      activation_188[0][0]
# __________________________________________________________________________________________________
# batch_normalization_199 (BatchN (None, 2, 2, 256)    1024        conv2d_199[0][0]
# __________________________________________________________________________________________________
# activation_189 (Activation)     (None, 2, 2, 256)    0           batch_normalization_199[0][0]
# __________________________________________________________________________________________________
# conv2d_200 (Conv2D)             (None, 2, 2, 256)    590080      activation_189[0][0]
# __________________________________________________________________________________________________
# batch_normalization_200 (BatchN (None, 2, 2, 256)    1024        conv2d_200[0][0]
# __________________________________________________________________________________________________
# activation_190 (Activation)     (None, 2, 2, 256)    0           batch_normalization_200[0][0]
# __________________________________________________________________________________________________
# conv2d_201 (Conv2D)             (None, 2, 2, 1024)   263168      activation_190[0][0]
# __________________________________________________________________________________________________
# batch_normalization_201 (BatchN (None, 2, 2, 1024)   4096        conv2d_201[0][0]
# __________________________________________________________________________________________________
# add_40 (Add)                    (None, 2, 2, 1024)   0           batch_normalization_201[0][0]
#                                                                  activation_188[0][0]
# __________________________________________________________________________________________________
# activation_191 (Activation)     (None, 2, 2, 1024)   0           add_40[0][0]
# __________________________________________________________________________________________________
# conv2d_202 (Conv2D)             (None, 2, 2, 256)    262400      activation_191[0][0]
# __________________________________________________________________________________________________
# batch_normalization_202 (BatchN (None, 2, 2, 256)    1024        conv2d_202[0][0]
# __________________________________________________________________________________________________
# activation_192 (Activation)     (None, 2, 2, 256)    0           batch_normalization_202[0][0]
# __________________________________________________________________________________________________
# conv2d_203 (Conv2D)             (None, 2, 2, 256)    590080      activation_192[0][0]
# __________________________________________________________________________________________________
# batch_normalization_203 (BatchN (None, 2, 2, 256)    1024        conv2d_203[0][0]
# __________________________________________________________________________________________________
# activation_193 (Activation)     (None, 2, 2, 256)    0           batch_normalization_203[0][0]
# __________________________________________________________________________________________________
# conv2d_204 (Conv2D)             (None, 2, 2, 1024)   263168      activation_193[0][0]
# __________________________________________________________________________________________________
# batch_normalization_204 (BatchN (None, 2, 2, 1024)   4096        conv2d_204[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, 2, 2, 1024)   0           batch_normalization_204[0][0]
#                                                                  activation_191[0][0]
# __________________________________________________________________________________________________
# activation_194 (Activation)     (None, 2, 2, 1024)   0           add_41[0][0]
# __________________________________________________________________________________________________
# conv2d_205 (Conv2D)             (None, 2, 2, 256)    262400      activation_194[0][0]
# __________________________________________________________________________________________________
# batch_normalization_205 (BatchN (None, 2, 2, 256)    1024        conv2d_205[0][0]
# __________________________________________________________________________________________________
# activation_195 (Activation)     (None, 2, 2, 256)    0           batch_normalization_205[0][0]
# __________________________________________________________________________________________________
# conv2d_206 (Conv2D)             (None, 2, 2, 256)    590080      activation_195[0][0]
# __________________________________________________________________________________________________
# batch_normalization_206 (BatchN (None, 2, 2, 256)    1024        conv2d_206[0][0]
# __________________________________________________________________________________________________
# activation_196 (Activation)     (None, 2, 2, 256)    0           batch_normalization_206[0][0]
# __________________________________________________________________________________________________
# conv2d_207 (Conv2D)             (None, 2, 2, 1024)   263168      activation_196[0][0]
# __________________________________________________________________________________________________
# batch_normalization_207 (BatchN (None, 2, 2, 1024)   4096        conv2d_207[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, 2, 2, 1024)   0           batch_normalization_207[0][0]
#                                                                  activation_194[0][0]
# __________________________________________________________________________________________________
# activation_197 (Activation)     (None, 2, 2, 1024)   0           add_42[0][0]
# __________________________________________________________________________________________________
# conv2d_208 (Conv2D)             (None, 2, 2, 256)    262400      activation_197[0][0]
# __________________________________________________________________________________________________
# batch_normalization_208 (BatchN (None, 2, 2, 256)    1024        conv2d_208[0][0]
# __________________________________________________________________________________________________
# activation_198 (Activation)     (None, 2, 2, 256)    0           batch_normalization_208[0][0]
# __________________________________________________________________________________________________
# conv2d_209 (Conv2D)             (None, 2, 2, 256)    590080      activation_198[0][0]
# __________________________________________________________________________________________________
# batch_normalization_209 (BatchN (None, 2, 2, 256)    1024        conv2d_209[0][0]
# __________________________________________________________________________________________________
# activation_199 (Activation)     (None, 2, 2, 256)    0           batch_normalization_209[0][0]
# __________________________________________________________________________________________________
# conv2d_210 (Conv2D)             (None, 2, 2, 1024)   263168      activation_199[0][0]
# __________________________________________________________________________________________________
# batch_normalization_210 (BatchN (None, 2, 2, 1024)   4096        conv2d_210[0][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, 2, 2, 1024)   0           batch_normalization_210[0][0]
#                                                                  activation_197[0][0]
# __________________________________________________________________________________________________
# activation_200 (Activation)     (None, 2, 2, 1024)   0           add_43[0][0]
# __________________________________________________________________________________________________
# conv2d_211 (Conv2D)             (None, 2, 2, 256)    262400      activation_200[0][0]
# __________________________________________________________________________________________________
# batch_normalization_211 (BatchN (None, 2, 2, 256)    1024        conv2d_211[0][0]
# __________________________________________________________________________________________________
# activation_201 (Activation)     (None, 2, 2, 256)    0           batch_normalization_211[0][0]
# __________________________________________________________________________________________________
# conv2d_212 (Conv2D)             (None, 2, 2, 256)    590080      activation_201[0][0]
# __________________________________________________________________________________________________
# batch_normalization_212 (BatchN (None, 2, 2, 256)    1024        conv2d_212[0][0]
# __________________________________________________________________________________________________
# activation_202 (Activation)     (None, 2, 2, 256)    0           batch_normalization_212[0][0]
# __________________________________________________________________________________________________
# conv2d_213 (Conv2D)             (None, 2, 2, 1024)   263168      activation_202[0][0]
# __________________________________________________________________________________________________
# batch_normalization_213 (BatchN (None, 2, 2, 1024)   4096        conv2d_213[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, 2, 2, 1024)   0           batch_normalization_213[0][0]
#                                                                  activation_200[0][0]
# __________________________________________________________________________________________________
# activation_203 (Activation)     (None, 2, 2, 1024)   0           add_44[0][0]
# __________________________________________________________________________________________________
# conv2d_214 (Conv2D)             (None, 1, 1, 512)    524800      activation_203[0][0]
# __________________________________________________________________________________________________
# batch_normalization_214 (BatchN (None, 1, 1, 512)    2048        conv2d_214[0][0]
# __________________________________________________________________________________________________
# activation_204 (Activation)     (None, 1, 1, 512)    0           batch_normalization_214[0][0]
# __________________________________________________________________________________________________
# conv2d_215 (Conv2D)             (None, 1, 1, 512)    2359808     activation_204[0][0]
# __________________________________________________________________________________________________
# batch_normalization_215 (BatchN (None, 1, 1, 512)    2048        conv2d_215[0][0]
# __________________________________________________________________________________________________
# activation_205 (Activation)     (None, 1, 1, 512)    0           batch_normalization_215[0][0]
# __________________________________________________________________________________________________
# conv2d_216 (Conv2D)             (None, 1, 1, 2048)   1050624     activation_205[0][0]
# __________________________________________________________________________________________________
# conv2d_217 (Conv2D)             (None, 1, 1, 2048)   2099200     activation_203[0][0]
# __________________________________________________________________________________________________
# batch_normalization_216 (BatchN (None, 1, 1, 2048)   8192        conv2d_216[0][0]
# __________________________________________________________________________________________________
# batch_normalization_217 (BatchN (None, 1, 1, 2048)   8192        conv2d_217[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 1, 1, 2048)   0           batch_normalization_216[0][0]
#                                                                  batch_normalization_217[0][0]
# __________________________________________________________________________________________________
# activation_206 (Activation)     (None, 1, 1, 2048)   0           add_45[0][0]
# __________________________________________________________________________________________________
# conv2d_218 (Conv2D)             (None, 1, 1, 512)    1049088     activation_206[0][0]
# __________________________________________________________________________________________________
# batch_normalization_218 (BatchN (None, 1, 1, 512)    2048        conv2d_218[0][0]
# __________________________________________________________________________________________________
# activation_207 (Activation)     (None, 1, 1, 512)    0           batch_normalization_218[0][0]
# __________________________________________________________________________________________________
# conv2d_219 (Conv2D)             (None, 1, 1, 512)    2359808     activation_207[0][0]
# __________________________________________________________________________________________________
# batch_normalization_219 (BatchN (None, 1, 1, 512)    2048        conv2d_219[0][0]
# __________________________________________________________________________________________________
# activation_208 (Activation)     (None, 1, 1, 512)    0           batch_normalization_219[0][0]
# __________________________________________________________________________________________________
# conv2d_220 (Conv2D)             (None, 1, 1, 2048)   1050624     activation_208[0][0]
# __________________________________________________________________________________________________
# batch_normalization_220 (BatchN (None, 1, 1, 2048)   8192        conv2d_220[0][0]
# __________________________________________________________________________________________________
# add_46 (Add)                    (None, 1, 1, 2048)   0           batch_normalization_220[0][0]
#                                                                  activation_206[0][0]
# __________________________________________________________________________________________________
# activation_209 (Activation)     (None, 1, 1, 2048)   0           add_46[0][0]
# __________________________________________________________________________________________________
# conv2d_221 (Conv2D)             (None, 1, 1, 512)    1049088     activation_209[0][0]
# __________________________________________________________________________________________________
# batch_normalization_221 (BatchN (None, 1, 1, 512)    2048        conv2d_221[0][0]
# __________________________________________________________________________________________________
# activation_210 (Activation)     (None, 1, 1, 512)    0           batch_normalization_221[0][0]
# __________________________________________________________________________________________________
# conv2d_222 (Conv2D)             (None, 1, 1, 512)    2359808     activation_210[0][0]
# __________________________________________________________________________________________________
# batch_normalization_222 (BatchN (None, 1, 1, 512)    2048        conv2d_222[0][0]
# __________________________________________________________________________________________________
# activation_211 (Activation)     (None, 1, 1, 512)    0           batch_normalization_222[0][0]
# __________________________________________________________________________________________________
# conv2d_223 (Conv2D)             (None, 1, 1, 2048)   1050624     activation_211[0][0]
# __________________________________________________________________________________________________
# batch_normalization_223 (BatchN (None, 1, 1, 2048)   8192        conv2d_223[0][0]
# __________________________________________________________________________________________________
# add_47 (Add)                    (None, 1, 1, 2048)   0           batch_normalization_223[0][0]
#                                                                  activation_209[0][0]
# __________________________________________________________________________________________________
# activation_212 (Activation)     (None, 1, 1, 2048)   0           add_47[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 2048)         0           activation_212[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 10)           20490       global_average_pooling2d_4[0][0]
# ==================================================================================================
# Total params: 23,608,202
# Trainable params: 23,555,082
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
# ResNet-50 모델을 구성하기
resnet_50_model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

# ResNet-50 모델을 훈련하기
history_resnet50 = resnet_50_model.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['test'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/5
# 195/195 [==============================] - 109s 371ms/step - loss: 3.0554 - accuracy: 0.1187 - val_loss: 2.4398 - val_accuracy: 0.0971
# Epoch 2/5
# 195/195 [==============================] - 57s 294ms/step - loss: 2.5327 - accuracy: 0.1652 - val_loss: 2.5312 - val_accuracy: 0.1228
# Epoch 3/5
# 195/195 [==============================] - 49s 249ms/step - loss: 2.3160 - accuracy: 0.2026 - val_loss: 2.4890 - val_accuracy: 0.1886
# Epoch 4/5
# 195/195 [==============================] - 49s 250ms/step - loss: 2.1958 - accuracy: 0.2252 - val_loss: 3.0550 - val_accuracy: 0.2180
# Epoch 5/5
# 195/195 [==============================] - 49s 251ms/step - loss: 2.0706 - accuracy: 0.2634 - val_loss: 2.4252 - val_accuracy: 0.2374

# %% [markdown]
# #### Plain-50 for cifar10

# %%
del plainnet_50_model

input_shape = (32, 32, 3)   # cifar10.shape = (32, 32, 3)
n_classes = 10

plainnet_50_model = build_plainnet(input_shape=input_shape, is_50=True, is_plain=True)
plainnet_50_model.summary()
# Out:
# resnet_type2_input: (None, 32, 32, 3)
# resnet_type2_pool1: (None, 8, 8, 64)
# bottle_neck_layer_input: (None, 8, 8, 64)
# bottle_neck_input      : 0 (None, 8, 8, 64)
# conv1 : 0 (None, 8, 8, 64)
# conv2 : 0 (None, 8, 8, 64)
# conv3 : 0 (None, 8, 8, 256)
# bottle_neck_beforadd : 0 (None, 8, 8, 256)
# bottle_neck_output     : 0 (None, 8, 8, 256)
# bottle_neck_input      : 1 (None, 8, 8, 256)
# conv1 : 1 (None, 8, 8, 64)
# conv2 : 1 (None, 8, 8, 64)
# conv3 : 1 (None, 8, 8, 256)
# bottle_neck_beforadd : 1 (None, 8, 8, 256)
# bottle_neck_output     : 1 (None, 8, 8, 256)
# bottle_neck_input      : 2 (None, 8, 8, 256)
# conv1 : 2 (None, 8, 8, 64)
# conv2 : 2 (None, 8, 8, 64)
# conv3 : 2 (None, 8, 8, 256)
# bottle_neck_beforadd : 2 (None, 8, 8, 256)
# bottle_neck_output     : 2 (None, 8, 8, 256)
# bottle_neck_layer_input: (None, 8, 8, 256)
# bottle_neck_input      : 0 (None, 8, 8, 256)
# conv1 : 0 (None, 4, 4, 128)
# conv2 : 0 (None, 4, 4, 128)
# conv3 : 0 (None, 4, 4, 512)
# bottle_neck_beforadd : 0 (None, 4, 4, 512)
# bottle_neck_output     : 0 (None, 4, 4, 512)
# bottle_neck_input      : 1 (None, 4, 4, 512)
# conv1 : 1 (None, 4, 4, 128)
# conv2 : 1 (None, 4, 4, 128)
# conv3 : 1 (None, 4, 4, 512)
# bottle_neck_beforadd : 1 (None, 4, 4, 512)
# bottle_neck_output     : 1 (None, 4, 4, 512)
# bottle_neck_input      : 2 (None, 4, 4, 512)
# conv1 : 2 (None, 4, 4, 128)
# conv2 : 2 (None, 4, 4, 128)
# conv3 : 2 (None, 4, 4, 512)
# bottle_neck_beforadd : 2 (None, 4, 4, 512)
# bottle_neck_output     : 2 (None, 4, 4, 512)
# bottle_neck_input      : 3 (None, 4, 4, 512)
# conv1 : 3 (None, 4, 4, 128)
# conv2 : 3 (None, 4, 4, 128)
# conv3 : 3 (None, 4, 4, 512)
# bottle_neck_beforadd : 3 (None, 4, 4, 512)
# bottle_neck_output     : 3 (None, 4, 4, 512)
# bottle_neck_layer_input: (None, 4, 4, 512)
# bottle_neck_input      : 0 (None, 4, 4, 512)
# conv1 : 0 (None, 2, 2, 256)
# conv2 : 0 (None, 2, 2, 256)
# conv3 : 0 (None, 2, 2, 1024)
# bottle_neck_beforadd : 0 (None, 2, 2, 1024)
# bottle_neck_output     : 0 (None, 2, 2, 1024)
# bottle_neck_input      : 1 (None, 2, 2, 1024)
# conv1 : 1 (None, 2, 2, 256)
# conv2 : 1 (None, 2, 2, 256)
# conv3 : 1 (None, 2, 2, 1024)
# bottle_neck_beforadd : 1 (None, 2, 2, 1024)
# bottle_neck_output     : 1 (None, 2, 2, 1024)
# bottle_neck_input      : 2 (None, 2, 2, 1024)
# conv1 : 2 (None, 2, 2, 256)
# conv2 : 2 (None, 2, 2, 256)
# conv3 : 2 (None, 2, 2, 1024)
# bottle_neck_beforadd : 2 (None, 2, 2, 1024)
# bottle_neck_output     : 2 (None, 2, 2, 1024)
# bottle_neck_input      : 3 (None, 2, 2, 1024)
# conv1 : 3 (None, 2, 2, 256)
# conv2 : 3 (None, 2, 2, 256)
# conv3 : 3 (None, 2, 2, 1024)
# bottle_neck_beforadd : 3 (None, 2, 2, 1024)
# bottle_neck_output     : 3 (None, 2, 2, 1024)
# bottle_neck_input      : 4 (None, 2, 2, 1024)
# conv1 : 4 (None, 2, 2, 256)
# conv2 : 4 (None, 2, 2, 256)
# conv3 : 4 (None, 2, 2, 1024)
# bottle_neck_beforadd : 4 (None, 2, 2, 1024)
# bottle_neck_output     : 4 (None, 2, 2, 1024)
# bottle_neck_input      : 5 (None, 2, 2, 1024)
# conv1 : 5 (None, 2, 2, 256)
# conv2 : 5 (None, 2, 2, 256)
# conv3 : 5 (None, 2, 2, 1024)
# bottle_neck_beforadd : 5 (None, 2, 2, 1024)
# bottle_neck_output     : 5 (None, 2, 2, 1024)
# bottle_neck_layer_input: (None, 2, 2, 1024)
# bottle_neck_input      : 0 (None, 2, 2, 1024)
# conv1 : 0 (None, 1, 1, 512)
# conv2 : 0 (None, 1, 1, 512)
# conv3 : 0 (None, 1, 1, 2048)
# bottle_neck_beforadd : 0 (None, 1, 1, 2048)
# bottle_neck_output     : 0 (None, 1, 1, 2048)
# bottle_neck_input      : 1 (None, 1, 1, 2048)
# conv1 : 1 (None, 1, 1, 512)
# conv2 : 1 (None, 1, 1, 512)
# conv3 : 1 (None, 1, 1, 2048)
# bottle_neck_beforadd : 1 (None, 1, 1, 2048)
# bottle_neck_output     : 1 (None, 1, 1, 2048)
# bottle_neck_input      : 2 (None, 1, 1, 2048)
# conv1 : 2 (None, 1, 1, 512)
# conv2 : 2 (None, 1, 1, 512)
# conv3 : 2 (None, 1, 1, 2048)
# bottle_neck_beforadd : 2 (None, 1, 1, 2048)
# bottle_neck_output     : 2 (None, 1, 1, 2048)
# resnet_type2_output  : (None, 10)
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# plain_input_layer (InputLaye [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_224 (Conv2D)          (None, 16, 16, 64)        9472
# _________________________________________________________________
# batch_normalization_224 (Bat (None, 16, 16, 64)        256
# _________________________________________________________________
# activation_213 (Activation)  (None, 16, 16, 64)        0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_225 (Conv2D)          (None, 8, 8, 64)          4160
# _________________________________________________________________
# batch_normalization_225 (Bat (None, 8, 8, 64)          256
# _________________________________________________________________
# activation_214 (Activation)  (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_226 (Conv2D)          (None, 8, 8, 64)          36928
# _________________________________________________________________
# batch_normalization_226 (Bat (None, 8, 8, 64)          256
# _________________________________________________________________
# activation_215 (Activation)  (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_227 (Conv2D)          (None, 8, 8, 256)         16640
# _________________________________________________________________
# batch_normalization_227 (Bat (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_216 (Activation)  (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_228 (Conv2D)          (None, 8, 8, 64)          16448
# _________________________________________________________________
# batch_normalization_228 (Bat (None, 8, 8, 64)          256
# _________________________________________________________________
# activation_217 (Activation)  (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_229 (Conv2D)          (None, 8, 8, 64)          36928
# _________________________________________________________________
# batch_normalization_229 (Bat (None, 8, 8, 64)          256
# _________________________________________________________________
# activation_218 (Activation)  (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_230 (Conv2D)          (None, 8, 8, 256)         16640
# _________________________________________________________________
# batch_normalization_230 (Bat (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_219 (Activation)  (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_231 (Conv2D)          (None, 8, 8, 64)          16448
# _________________________________________________________________
# batch_normalization_231 (Bat (None, 8, 8, 64)          256
# _________________________________________________________________
# activation_220 (Activation)  (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_232 (Conv2D)          (None, 8, 8, 64)          36928
# _________________________________________________________________
# batch_normalization_232 (Bat (None, 8, 8, 64)          256
# _________________________________________________________________
# activation_221 (Activation)  (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_233 (Conv2D)          (None, 8, 8, 256)         16640
# _________________________________________________________________
# batch_normalization_233 (Bat (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_222 (Activation)  (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_234 (Conv2D)          (None, 4, 4, 128)         32896
# _________________________________________________________________
# batch_normalization_234 (Bat (None, 4, 4, 128)         512
# _________________________________________________________________
# activation_223 (Activation)  (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_235 (Conv2D)          (None, 4, 4, 128)         147584
# _________________________________________________________________
# batch_normalization_235 (Bat (None, 4, 4, 128)         512
# _________________________________________________________________
# activation_224 (Activation)  (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_236 (Conv2D)          (None, 4, 4, 512)         66048
# _________________________________________________________________
# batch_normalization_236 (Bat (None, 4, 4, 512)         2048
# _________________________________________________________________
# activation_225 (Activation)  (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_237 (Conv2D)          (None, 4, 4, 128)         65664
# _________________________________________________________________
# batch_normalization_237 (Bat (None, 4, 4, 128)         512
# _________________________________________________________________
# activation_226 (Activation)  (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_238 (Conv2D)          (None, 4, 4, 128)         147584
# _________________________________________________________________
# batch_normalization_238 (Bat (None, 4, 4, 128)         512
# _________________________________________________________________
# activation_227 (Activation)  (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_239 (Conv2D)          (None, 4, 4, 512)         66048
# _________________________________________________________________
# batch_normalization_239 (Bat (None, 4, 4, 512)         2048
# _________________________________________________________________
# activation_228 (Activation)  (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_240 (Conv2D)          (None, 4, 4, 128)         65664
# _________________________________________________________________
# batch_normalization_240 (Bat (None, 4, 4, 128)         512
# _________________________________________________________________
# activation_229 (Activation)  (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_241 (Conv2D)          (None, 4, 4, 128)         147584
# _________________________________________________________________
# batch_normalization_241 (Bat (None, 4, 4, 128)         512
# _________________________________________________________________
# activation_230 (Activation)  (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_242 (Conv2D)          (None, 4, 4, 512)         66048
# _________________________________________________________________
# batch_normalization_242 (Bat (None, 4, 4, 512)         2048
# _________________________________________________________________
# activation_231 (Activation)  (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_243 (Conv2D)          (None, 4, 4, 128)         65664
# _________________________________________________________________
# batch_normalization_243 (Bat (None, 4, 4, 128)         512
# _________________________________________________________________
# activation_232 (Activation)  (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_244 (Conv2D)          (None, 4, 4, 128)         147584
# _________________________________________________________________
# batch_normalization_244 (Bat (None, 4, 4, 128)         512
# _________________________________________________________________
# activation_233 (Activation)  (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_245 (Conv2D)          (None, 4, 4, 512)         66048
# _________________________________________________________________
# batch_normalization_245 (Bat (None, 4, 4, 512)         2048
# _________________________________________________________________
# activation_234 (Activation)  (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_246 (Conv2D)          (None, 2, 2, 256)         131328
# _________________________________________________________________
# batch_normalization_246 (Bat (None, 2, 2, 256)         1024
# _________________________________________________________________
# activation_235 (Activation)  (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_247 (Conv2D)          (None, 2, 2, 256)         590080
# _________________________________________________________________
# batch_normalization_247 (Bat (None, 2, 2, 256)         1024
# _________________________________________________________________
# activation_236 (Activation)  (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_248 (Conv2D)          (None, 2, 2, 1024)        263168
# _________________________________________________________________
# batch_normalization_248 (Bat (None, 2, 2, 1024)        4096
# _________________________________________________________________
# activation_237 (Activation)  (None, 2, 2, 1024)        0
# _________________________________________________________________
# conv2d_249 (Conv2D)          (None, 2, 2, 256)         262400
# _________________________________________________________________
# batch_normalization_249 (Bat (None, 2, 2, 256)         1024
# _________________________________________________________________
# activation_238 (Activation)  (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_250 (Conv2D)          (None, 2, 2, 256)         590080
# _________________________________________________________________
# batch_normalization_250 (Bat (None, 2, 2, 256)         1024
# _________________________________________________________________
# activation_239 (Activation)  (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_251 (Conv2D)          (None, 2, 2, 1024)        263168
# _________________________________________________________________
# batch_normalization_251 (Bat (None, 2, 2, 1024)        4096
# _________________________________________________________________
# activation_240 (Activation)  (None, 2, 2, 1024)        0
# _________________________________________________________________
# conv2d_252 (Conv2D)          (None, 2, 2, 256)         262400
# _________________________________________________________________
# batch_normalization_252 (Bat (None, 2, 2, 256)         1024
# _________________________________________________________________
# activation_241 (Activation)  (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_253 (Conv2D)          (None, 2, 2, 256)         590080
# _________________________________________________________________
# batch_normalization_253 (Bat (None, 2, 2, 256)         1024
# _________________________________________________________________
# activation_242 (Activation)  (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_254 (Conv2D)          (None, 2, 2, 1024)        263168
# _________________________________________________________________
# batch_normalization_254 (Bat (None, 2, 2, 1024)        4096
# _________________________________________________________________
# activation_243 (Activation)  (None, 2, 2, 1024)        0
# _________________________________________________________________
# conv2d_255 (Conv2D)          (None, 2, 2, 256)         262400
# _________________________________________________________________
# batch_normalization_255 (Bat (None, 2, 2, 256)         1024
# _________________________________________________________________
# activation_244 (Activation)  (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_256 (Conv2D)          (None, 2, 2, 256)         590080
# _________________________________________________________________
# batch_normalization_256 (Bat (None, 2, 2, 256)         1024
# _________________________________________________________________
# activation_245 (Activation)  (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_257 (Conv2D)          (None, 2, 2, 1024)        263168
# _________________________________________________________________
# batch_normalization_257 (Bat (None, 2, 2, 1024)        4096
# _________________________________________________________________
# activation_246 (Activation)  (None, 2, 2, 1024)        0
# _________________________________________________________________
# conv2d_258 (Conv2D)          (None, 2, 2, 256)         262400
# _________________________________________________________________
# batch_normalization_258 (Bat (None, 2, 2, 256)         1024
# _________________________________________________________________
# activation_247 (Activation)  (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_259 (Conv2D)          (None, 2, 2, 256)         590080
# _________________________________________________________________
# batch_normalization_259 (Bat (None, 2, 2, 256)         1024
# _________________________________________________________________
# activation_248 (Activation)  (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_260 (Conv2D)          (None, 2, 2, 1024)        263168
# _________________________________________________________________
# batch_normalization_260 (Bat (None, 2, 2, 1024)        4096
# _________________________________________________________________
# activation_249 (Activation)  (None, 2, 2, 1024)        0
# _________________________________________________________________
# conv2d_261 (Conv2D)          (None, 2, 2, 256)         262400
# _________________________________________________________________
# batch_normalization_261 (Bat (None, 2, 2, 256)         1024
# _________________________________________________________________
# activation_250 (Activation)  (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_262 (Conv2D)          (None, 2, 2, 256)         590080
# _________________________________________________________________
# batch_normalization_262 (Bat (None, 2, 2, 256)         1024
# _________________________________________________________________
# activation_251 (Activation)  (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_263 (Conv2D)          (None, 2, 2, 1024)        263168
# _________________________________________________________________
# batch_normalization_263 (Bat (None, 2, 2, 1024)        4096
# _________________________________________________________________
# activation_252 (Activation)  (None, 2, 2, 1024)        0
# _________________________________________________________________
# conv2d_264 (Conv2D)          (None, 1, 1, 512)         524800
# _________________________________________________________________
# batch_normalization_264 (Bat (None, 1, 1, 512)         2048
# _________________________________________________________________
# activation_253 (Activation)  (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_265 (Conv2D)          (None, 1, 1, 512)         2359808
# _________________________________________________________________
# batch_normalization_265 (Bat (None, 1, 1, 512)         2048
# _________________________________________________________________
# activation_254 (Activation)  (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_266 (Conv2D)          (None, 1, 1, 2048)        1050624
# _________________________________________________________________
# batch_normalization_266 (Bat (None, 1, 1, 2048)        8192
# _________________________________________________________________
# activation_255 (Activation)  (None, 1, 1, 2048)        0
# _________________________________________________________________
# conv2d_267 (Conv2D)          (None, 1, 1, 512)         1049088
# _________________________________________________________________
# batch_normalization_267 (Bat (None, 1, 1, 512)         2048
# _________________________________________________________________
# activation_256 (Activation)  (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_268 (Conv2D)          (None, 1, 1, 512)         2359808
# _________________________________________________________________
# batch_normalization_268 (Bat (None, 1, 1, 512)         2048
# _________________________________________________________________
# activation_257 (Activation)  (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_269 (Conv2D)          (None, 1, 1, 2048)        1050624
# _________________________________________________________________
# batch_normalization_269 (Bat (None, 1, 1, 2048)        8192
# _________________________________________________________________
# activation_258 (Activation)  (None, 1, 1, 2048)        0
# _________________________________________________________________
# conv2d_270 (Conv2D)          (None, 1, 1, 512)         1049088
# _________________________________________________________________
# batch_normalization_270 (Bat (None, 1, 1, 512)         2048
# _________________________________________________________________
# activation_259 (Activation)  (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_271 (Conv2D)          (None, 1, 1, 512)         2359808
# _________________________________________________________________
# batch_normalization_271 (Bat (None, 1, 1, 512)         2048
# _________________________________________________________________
# activation_260 (Activation)  (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_272 (Conv2D)          (None, 1, 1, 2048)        1050624
# _________________________________________________________________
# batch_normalization_272 (Bat (None, 1, 1, 2048)        8192
# _________________________________________________________________
# activation_261 (Activation)  (None, 1, 1, 2048)        0
# _________________________________________________________________
# global_average_pooling2d_5 ( (None, 2048)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 20,820,106
# Trainable params: 20,774,666
# Non-trainable params: 45,440
# _________________________________________________________________

# %%
# Plain-50 모델을 구성하기
plainnet_50_model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

# Plain-50 모델을 훈련하기
history_plainnet50 = plainnet_50_model.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['test'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/5
# 195/195 [==============================] - 53s 224ms/step - loss: 2.4921 - accuracy: 0.1037 - val_loss: 2.3149 - val_accuracy: 0.1001
# Epoch 2/5
# 195/195 [==============================] - 43s 220ms/step - loss: 2.3943 - accuracy: 0.1070 - val_loss: 2.3420 - val_accuracy: 0.1031
# Epoch 3/5
# 195/195 [==============================] - 43s 220ms/step - loss: 2.3517 - accuracy: 0.1119 - val_loss: 2.3325 - val_accuracy: 0.1029
# Epoch 4/5
# 195/195 [==============================] - 43s 221ms/step - loss: 2.3296 - accuracy: 0.1169 - val_loss: 2.8404 - val_accuracy: 0.1308
# Epoch 5/5
# 195/195 [==============================] - 43s 220ms/step - loss: 2.3270 - accuracy: 0.1128 - val_loss: 2.6026 - val_accuracy: 0.1226

# %%
# 훈련 손실(training loss)
import matplotlib.pyplot as plt

plt.plot(history_resnet50.history['loss'], 'r')
plt.plot(history_plainnet50.history['loss'], 'b')
plt.title('Model training loss for cifar10')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['resnet_50', 'plainnet_50'], loc='upper left')
plt.show()

# %%
# 검증 정확도(validation accuracy)

plt.plot(history_resnet50.history['val_accuracy'], 'r')
plt.plot(history_plainnet50.history['val_accuracy'], 'b')
plt.title('Model validation accuracy for cifar10')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['resnet_50', 'plainnet_50'], loc='upper left')
plt.show()

# %% [markdown]
# ### cats_vs_dogs 데이터셋에 적용
#
# 224x224 픽셀 크기의 데이터셋으로 실험

# %%
BATCH_SIZE = 16     # 이미지 크기가 크기때문에
IMAGE_SIZE = 224
EPOCH = 5

# %%
#  Cats and Dogs 데이터셋을 불러오기
dataset_name = 'cats_vs_dogs'

(ds_train, ds_test), ds_info = tfds.load(
    name=dataset_name,
    split=['train[:80%]', 'train[80%:]'],   # 처음 80%의 데이터만 학습 데이터로 사용 
    as_supervised=True,
    shuffle_files=True,
    with_info=True,
)
# Out:
# Downloading and preparing dataset 786.68 MiB (download: 786.68 MiB, generated: Unknown size, total: 786.68 MiB) to /aiffel/tensorflow_datasets/cats_vs_dogs/4.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/1 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/23262 [00:00<?, ? examples/s]
# WARNING:absl:1738 images were corrupted and were skipped
# Shuffling cats_vs_dogs-train.tfrecord...:   0%|          | 0/23262 [00:00<?, ? examples/s]
# Dataset cats_vs_dogs downloaded and prepared to /aiffel/tensorflow_datasets/cats_vs_dogs/4.0.0. Subsequent calls will reuse this data.

# %% [markdown]
# * [참고: cats_vs_dogs dataset](https://www.tensorflow.org/datasets/catalog/cats_vs_dogs)
# * [참고: Tensorflow 개발자 자격증 준비하기(6)](https://katie0809.github.io/2020/07/25/tf-study6/)
# * [참고: split](https://iyousys.tistory.com/47)
# * [참고: TensorFlow 튜토리얼](https://www.tensorflow.org/tutorials/images/transfer_learning)
# * [참고:Using TensorFlow to recognize Cats and Dogs](https://towardsdatascience.com/recognizing-cats-and-dogs-with-tensorflow-105eb56da35f)
# * [참고:텐서 데이터 tfds (cats and dogs)](

# %%
# 데이터셋의 정보 확인 
ds_info
# Out:
# tfds.core.DatasetInfo(
#     name='cats_vs_dogs',
#     full_name='cats_vs_dogs/4.0.0',
#     description="""
#     A large set of images of cats and dogs. There are 1738 corrupted images that are dropped.
#     """,
#     homepage='https://www.microsoft.com/en-us/download/details.aspx?id=54765',
#     data_path='/aiffel/tensorflow_datasets/cats_vs_dogs/4.0.0',
#     download_size=786.68 MiB,
#     dataset_size=689.64 MiB,
#     features=FeaturesDict({
#         'image': Image(shape=(None, None, 3), dtype=tf.uint8),
#         'image/filename': Text(shape=(), dtype=tf.string),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=2),
#     }),
#     supervised_keys=('image', 'label'),
#     splits={
#         'train': <SplitInfo num_examples=23262, num_shards=8>,
#     },
#     citation="""@Inproceedings (Conference){asirra-a-captcha-that-exploits-interest-aligned-manual-image-categorization,
#     author = {Elson, Jeremy and Douceur, John (JD) and Howell, Jon and Saul, Jared},
#     title = {Asirra: A CAPTCHA that Exploits Interest-Aligned Manual Image Categorization},
#     booktitle = {Proceedings of 14th ACM Conference on Computer and Communications Security (CCS)},
#     year = {2007},
#     month = {October},
#     publisher = {Association for Computing Machinery, Inc.},
#     url = {https://www.microsoft.com/en-us/research/publication/asirra-a-captcha-that-exploits-interest-aligned-manual-image-categorization/},
#     edition = {Proceedings of 14th ACM Conference on Computer and Communications Security (CCS)},
#     }""",
# )

# %%
# 데이터셋의 feature 정보 확인 
print(ds_info.features)
# Out:
# FeaturesDict({
#     'image': Image(shape=(None, None, 3), dtype=tf.uint8),
#     'image/filename': Text(shape=(), dtype=tf.string),
#     'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=2),
# })

# %% [markdown]
# * <span style='color:red'>이미지의 shape=(None, None, 3)으로 크기가 일정하지 않다</span>

# %%
# 데이터셋의 class 개수 확인 
print('class의 개수 :', ds_info.features['label'].num_classes)
# Out:
# class의 개수 : 2

# %%
# 데이터셋의 클래스 이름 확인
ds_info.features["label"].names
# Out:
# ['cat', 'dog']

# %%
# 데이터셋의 train/test의 샘플 사이즈 확인
print('train 데이터 개수 :', ds_info.splits['train'].num_examples)
# Out:
# train 데이터 개수 : 23262

# %%
# 분할된 데이터셋의 사이즈 확인
print(tf.data.experimental.cardinality(ds_train))
print(tf.data.experimental.cardinality(ds_test))
# Out:
# tf.Tensor(18610, shape=(), dtype=int64)
# tf.Tensor(4652, shape=(), dtype=int64)

# %%
# 학습 데이터셋에 어떤 이미지 있는지 확인
fig = tfds.show_examples(ds_train, ds_info)

# %%
# 데이터 전처리
ds_train = apply_normalize_on_dataset(ds_train, batch_size=BATCH_SIZE)
ds_test  = apply_normalize_on_dataset(ds_test,  batch_size=BATCH_SIZE)

# %%
del resnet_50_model

input_shape = (224, 224, 3)  # cats_vs_dogs.shape = (224, 224, 3)
n_classes = 2

resnet_50_model = build_resnet(input_shape=input_shape, is_50=True)
resnet_50_model.summary()
# Out:
# resnet_type2_input: (None, 224, 224, 3)
# resnet_type2_pool1: (None, 56, 56, 64)
# bottle_neck_layer_input: (None, 56, 56, 64)
# bottle_neck_input      : 0 (None, 56, 56, 64)
# conv1 : 0 (None, 56, 56, 64)
# conv2 : 0 (None, 56, 56, 64)
# conv3 : 0 (None, 56, 56, 256)
# bottle_neck_beforadd : 0 (None, 56, 56, 256)
# skip_bottle_neck_input : 0 (None, 56, 56, 64)
# skip_bottle_neck_output: 0 (None, 56, 56, 256)
# bottle_neck_shortcut : 0 (None, 56, 56, 256)
# bottle_neck_output     : 0 (None, 56, 56, 256)
# bottle_neck_input      : 1 (None, 56, 56, 256)
# conv1 : 1 (None, 56, 56, 64)
# conv2 : 1 (None, 56, 56, 64)
# conv3 : 1 (None, 56, 56, 256)
# bottle_neck_beforadd : 1 (None, 56, 56, 256)
# skip_bottle_neck_input : 1 (None, 56, 56, 256)
# skip_bottle_neck_output: 1 (None, 56, 56, 256)
# bottle_neck_shortcut : 1 (None, 56, 56, 256)
# bottle_neck_output     : 1 (None, 56, 56, 256)
# bottle_neck_input      : 2 (None, 56, 56, 256)
# conv1 : 2 (None, 56, 56, 64)
# conv2 : 2 (None, 56, 56, 64)
# conv3 : 2 (None, 56, 56, 256)
# bottle_neck_beforadd : 2 (None, 56, 56, 256)
# skip_bottle_neck_input : 2 (None, 56, 56, 256)
# skip_bottle_neck_output: 2 (None, 56, 56, 256)
# bottle_neck_shortcut : 2 (None, 56, 56, 256)
# bottle_neck_output     : 2 (None, 56, 56, 256)
# bottle_neck_layer_input: (None, 56, 56, 256)
# bottle_neck_input      : 0 (None, 56, 56, 256)
# conv1 : 0 (None, 28, 28, 128)
# conv2 : 0 (None, 28, 28, 128)
# conv3 : 0 (None, 28, 28, 512)
# bottle_neck_beforadd : 0 (None, 28, 28, 512)
# skip_bottle_neck_input : 0 (None, 56, 56, 256)
# skip_bottle_neck_output: 0 (None, 28, 28, 512)
# bottle_neck_shortcut : 0 (None, 28, 28, 512)
# bottle_neck_output     : 0 (None, 28, 28, 512)
# bottle_neck_input      : 1 (None, 28, 28, 512)
# conv1 : 1 (None, 28, 28, 128)
# conv2 : 1 (None, 28, 28, 128)
# conv3 : 1 (None, 28, 28, 512)
# bottle_neck_beforadd : 1 (None, 28, 28, 512)
# skip_bottle_neck_input : 1 (None, 28, 28, 512)
# skip_bottle_neck_output: 1 (None, 28, 28, 512)
# bottle_neck_shortcut : 1 (None, 28, 28, 512)
# bottle_neck_output     : 1 (None, 28, 28, 512)
# bottle_neck_input      : 2 (None, 28, 28, 512)
# conv1 : 2 (None, 28, 28, 128)
# conv2 : 2 (None, 28, 28, 128)
# conv3 : 2 (None, 28, 28, 512)
# bottle_neck_beforadd : 2 (None, 28, 28, 512)
# skip_bottle_neck_input : 2 (None, 28, 28, 512)
# skip_bottle_neck_output: 2 (None, 28, 28, 512)
# bottle_neck_shortcut : 2 (None, 28, 28, 512)
# bottle_neck_output     : 2 (None, 28, 28, 512)
# bottle_neck_input      : 3 (None, 28, 28, 512)
# conv1 : 3 (None, 28, 28, 128)
# conv2 : 3 (None, 28, 28, 128)
# conv3 : 3 (None, 28, 28, 512)
# bottle_neck_beforadd : 3 (None, 28, 28, 512)
# skip_bottle_neck_input : 3 (None, 28, 28, 512)
# skip_bottle_neck_output: 3 (None, 28, 28, 512)
# bottle_neck_shortcut : 3 (None, 28, 28, 512)
# bottle_neck_output     : 3 (None, 28, 28, 512)
# bottle_neck_layer_input: (None, 28, 28, 512)
# bottle_neck_input      : 0 (None, 28, 28, 512)
# conv1 : 0 (None, 14, 14, 256)
# conv2 : 0 (None, 14, 14, 256)
# conv3 : 0 (None, 14, 14, 1024)
# bottle_neck_beforadd : 0 (None, 14, 14, 1024)
# skip_bottle_neck_input : 0 (None, 28, 28, 512)
# skip_bottle_neck_output: 0 (None, 14, 14, 1024)
# bottle_neck_shortcut : 0 (None, 14, 14, 1024)
# bottle_neck_output     : 0 (None, 14, 14, 1024)
# bottle_neck_input      : 1 (None, 14, 14, 1024)
# conv1 : 1 (None, 14, 14, 256)
# conv2 : 1 (None, 14, 14, 256)
# conv3 : 1 (None, 14, 14, 1024)
# bottle_neck_beforadd : 1 (None, 14, 14, 1024)
# skip_bottle_neck_input : 1 (None, 14, 14, 1024)
# skip_bottle_neck_output: 1 (None, 14, 14, 1024)
# bottle_neck_shortcut : 1 (None, 14, 14, 1024)
# bottle_neck_output     : 1 (None, 14, 14, 1024)
# bottle_neck_input      : 2 (None, 14, 14, 1024)
# conv1 : 2 (None, 14, 14, 256)
# conv2 : 2 (None, 14, 14, 256)
# conv3 : 2 (None, 14, 14, 1024)
# bottle_neck_beforadd : 2 (None, 14, 14, 1024)
# skip_bottle_neck_input : 2 (None, 14, 14, 1024)
# skip_bottle_neck_output: 2 (None, 14, 14, 1024)
# bottle_neck_shortcut : 2 (None, 14, 14, 1024)
# bottle_neck_output     : 2 (None, 14, 14, 1024)
# bottle_neck_input      : 3 (None, 14, 14, 1024)
# conv1 : 3 (None, 14, 14, 256)
# conv2 : 3 (None, 14, 14, 256)
# conv3 : 3 (None, 14, 14, 1024)
# bottle_neck_beforadd : 3 (None, 14, 14, 1024)
# skip_bottle_neck_input : 3 (None, 14, 14, 1024)
# skip_bottle_neck_output: 3 (None, 14, 14, 1024)
# bottle_neck_shortcut : 3 (None, 14, 14, 1024)
# bottle_neck_output     : 3 (None, 14, 14, 1024)
# bottle_neck_input      : 4 (None, 14, 14, 1024)
# conv1 : 4 (None, 14, 14, 256)
# conv2 : 4 (None, 14, 14, 256)
# conv3 : 4 (None, 14, 14, 1024)
# bottle_neck_beforadd : 4 (None, 14, 14, 1024)
# skip_bottle_neck_input : 4 (None, 14, 14, 1024)
# skip_bottle_neck_output: 4 (None, 14, 14, 1024)
# bottle_neck_shortcut : 4 (None, 14, 14, 1024)
# bottle_neck_output     : 4 (None, 14, 14, 1024)
# bottle_neck_input      : 5 (None, 14, 14, 1024)
# conv1 : 5 (None, 14, 14, 256)
# conv2 : 5 (None, 14, 14, 256)
# conv3 : 5 (None, 14, 14, 1024)
# bottle_neck_beforadd : 5 (None, 14, 14, 1024)
# skip_bottle_neck_input : 5 (None, 14, 14, 1024)
# skip_bottle_neck_output: 5 (None, 14, 14, 1024)
# bottle_neck_shortcut : 5 (None, 14, 14, 1024)
# bottle_neck_output     : 5 (None, 14, 14, 1024)
# bottle_neck_layer_input: (None, 14, 14, 1024)
# bottle_neck_input      : 0 (None, 14, 14, 1024)
# conv1 : 0 (None, 7, 7, 512)
# conv2 : 0 (None, 7, 7, 512)
# conv3 : 0 (None, 7, 7, 2048)
# bottle_neck_beforadd : 0 (None, 7, 7, 2048)
# skip_bottle_neck_input : 0 (None, 14, 14, 1024)
# skip_bottle_neck_output: 0 (None, 7, 7, 2048)
# bottle_neck_shortcut : 0 (None, 7, 7, 2048)
# bottle_neck_output     : 0 (None, 7, 7, 2048)
# bottle_neck_input      : 1 (None, 7, 7, 2048)
# conv1 : 1 (None, 7, 7, 512)
# conv2 : 1 (None, 7, 7, 512)
# conv3 : 1 (None, 7, 7, 2048)
# bottle_neck_beforadd : 1 (None, 7, 7, 2048)
# skip_bottle_neck_input : 1 (None, 7, 7, 2048)
# skip_bottle_neck_output: 1 (None, 7, 7, 2048)
# bottle_neck_shortcut : 1 (None, 7, 7, 2048)
# bottle_neck_output     : 1 (None, 7, 7, 2048)
# bottle_neck_input      : 2 (None, 7, 7, 2048)
# conv1 : 2 (None, 7, 7, 512)
# conv2 : 2 (None, 7, 7, 512)
# conv3 : 2 (None, 7, 7, 2048)
# bottle_neck_beforadd : 2 (None, 7, 7, 2048)
# skip_bottle_neck_input : 2 (None, 7, 7, 2048)
# skip_bottle_neck_output: 2 (None, 7, 7, 2048)
# bottle_neck_shortcut : 2 (None, 7, 7, 2048)
# bottle_neck_output     : 2 (None, 7, 7, 2048)
# resnet_type2_output  : (None, 2)
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_layer (InputLayer)        [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d_273 (Conv2D)             (None, 112, 112, 64) 9472        input_layer[0][0]
# __________________________________________________________________________________________________
# batch_normalization_273 (BatchN (None, 112, 112, 64) 256         conv2d_273[0][0]
# __________________________________________________________________________________________________
# activation_262 (Activation)     (None, 112, 112, 64) 0           batch_normalization_273[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 56, 56, 64)   0           activation_262[0][0]
# __________________________________________________________________________________________________
# conv2d_274 (Conv2D)             (None, 56, 56, 64)   4160        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_274 (BatchN (None, 56, 56, 64)   256         conv2d_274[0][0]
# __________________________________________________________________________________________________
# activation_263 (Activation)     (None, 56, 56, 64)   0           batch_normalization_274[0][0]
# __________________________________________________________________________________________________
# conv2d_275 (Conv2D)             (None, 56, 56, 64)   36928       activation_263[0][0]
# __________________________________________________________________________________________________
# batch_normalization_275 (BatchN (None, 56, 56, 64)   256         conv2d_275[0][0]
# __________________________________________________________________________________________________
# activation_264 (Activation)     (None, 56, 56, 64)   0           batch_normalization_275[0][0]
# __________________________________________________________________________________________________
# conv2d_276 (Conv2D)             (None, 56, 56, 256)  16640       activation_264[0][0]
# __________________________________________________________________________________________________
# conv2d_277 (Conv2D)             (None, 56, 56, 256)  16640       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_276 (BatchN (None, 56, 56, 256)  1024        conv2d_276[0][0]
# __________________________________________________________________________________________________
# batch_normalization_277 (BatchN (None, 56, 56, 256)  1024        conv2d_277[0][0]
# __________________________________________________________________________________________________
# add_48 (Add)                    (None, 56, 56, 256)  0           batch_normalization_276[0][0]
#                                                                  batch_normalization_277[0][0]
# __________________________________________________________________________________________________
# activation_265 (Activation)     (None, 56, 56, 256)  0           add_48[0][0]
# __________________________________________________________________________________________________
# conv2d_278 (Conv2D)             (None, 56, 56, 64)   16448       activation_265[0][0]
# __________________________________________________________________________________________________
# batch_normalization_278 (BatchN (None, 56, 56, 64)   256         conv2d_278[0][0]
# __________________________________________________________________________________________________
# activation_266 (Activation)     (None, 56, 56, 64)   0           batch_normalization_278[0][0]
# __________________________________________________________________________________________________
# conv2d_279 (Conv2D)             (None, 56, 56, 64)   36928       activation_266[0][0]
# __________________________________________________________________________________________________
# batch_normalization_279 (BatchN (None, 56, 56, 64)   256         conv2d_279[0][0]
# __________________________________________________________________________________________________
# activation_267 (Activation)     (None, 56, 56, 64)   0           batch_normalization_279[0][0]
# __________________________________________________________________________________________________
# conv2d_280 (Conv2D)             (None, 56, 56, 256)  16640       activation_267[0][0]
# __________________________________________________________________________________________________
# batch_normalization_280 (BatchN (None, 56, 56, 256)  1024        conv2d_280[0][0]
# __________________________________________________________________________________________________
# add_49 (Add)                    (None, 56, 56, 256)  0           batch_normalization_280[0][0]
#                                                                  activation_265[0][0]
# __________________________________________________________________________________________________
# activation_268 (Activation)     (None, 56, 56, 256)  0           add_49[0][0]
# __________________________________________________________________________________________________
# conv2d_281 (Conv2D)             (None, 56, 56, 64)   16448       activation_268[0][0]
# __________________________________________________________________________________________________
# batch_normalization_281 (BatchN (None, 56, 56, 64)   256         conv2d_281[0][0]
# __________________________________________________________________________________________________
# activation_269 (Activation)     (None, 56, 56, 64)   0           batch_normalization_281[0][0]
# __________________________________________________________________________________________________
# conv2d_282 (Conv2D)             (None, 56, 56, 64)   36928       activation_269[0][0]
# __________________________________________________________________________________________________
# batch_normalization_282 (BatchN (None, 56, 56, 64)   256         conv2d_282[0][0]
# __________________________________________________________________________________________________
# activation_270 (Activation)     (None, 56, 56, 64)   0           batch_normalization_282[0][0]
# __________________________________________________________________________________________________
# conv2d_283 (Conv2D)             (None, 56, 56, 256)  16640       activation_270[0][0]
# __________________________________________________________________________________________________
# batch_normalization_283 (BatchN (None, 56, 56, 256)  1024        conv2d_283[0][0]
# __________________________________________________________________________________________________
# add_50 (Add)                    (None, 56, 56, 256)  0           batch_normalization_283[0][0]
#                                                                  activation_268[0][0]
# __________________________________________________________________________________________________
# activation_271 (Activation)     (None, 56, 56, 256)  0           add_50[0][0]
# __________________________________________________________________________________________________
# conv2d_284 (Conv2D)             (None, 28, 28, 128)  32896       activation_271[0][0]
# __________________________________________________________________________________________________
# batch_normalization_284 (BatchN (None, 28, 28, 128)  512         conv2d_284[0][0]
# __________________________________________________________________________________________________
# activation_272 (Activation)     (None, 28, 28, 128)  0           batch_normalization_284[0][0]
# __________________________________________________________________________________________________
# conv2d_285 (Conv2D)             (None, 28, 28, 128)  147584      activation_272[0][0]
# __________________________________________________________________________________________________
# batch_normalization_285 (BatchN (None, 28, 28, 128)  512         conv2d_285[0][0]
# __________________________________________________________________________________________________
# activation_273 (Activation)     (None, 28, 28, 128)  0           batch_normalization_285[0][0]
# __________________________________________________________________________________________________
# conv2d_286 (Conv2D)             (None, 28, 28, 512)  66048       activation_273[0][0]
# __________________________________________________________________________________________________
# conv2d_287 (Conv2D)             (None, 28, 28, 512)  131584      activation_271[0][0]
# __________________________________________________________________________________________________
# batch_normalization_286 (BatchN (None, 28, 28, 512)  2048        conv2d_286[0][0]
# __________________________________________________________________________________________________
# batch_normalization_287 (BatchN (None, 28, 28, 512)  2048        conv2d_287[0][0]
# __________________________________________________________________________________________________
# add_51 (Add)                    (None, 28, 28, 512)  0           batch_normalization_286[0][0]
#                                                                  batch_normalization_287[0][0]
# __________________________________________________________________________________________________
# activation_274 (Activation)     (None, 28, 28, 512)  0           add_51[0][0]
# __________________________________________________________________________________________________
# conv2d_288 (Conv2D)             (None, 28, 28, 128)  65664       activation_274[0][0]
# __________________________________________________________________________________________________
# batch_normalization_288 (BatchN (None, 28, 28, 128)  512         conv2d_288[0][0]
# __________________________________________________________________________________________________
# activation_275 (Activation)     (None, 28, 28, 128)  0           batch_normalization_288[0][0]
# __________________________________________________________________________________________________
# conv2d_289 (Conv2D)             (None, 28, 28, 128)  147584      activation_275[0][0]
# __________________________________________________________________________________________________
# batch_normalization_289 (BatchN (None, 28, 28, 128)  512         conv2d_289[0][0]
# __________________________________________________________________________________________________
# activation_276 (Activation)     (None, 28, 28, 128)  0           batch_normalization_289[0][0]
# __________________________________________________________________________________________________
# conv2d_290 (Conv2D)             (None, 28, 28, 512)  66048       activation_276[0][0]
# __________________________________________________________________________________________________
# batch_normalization_290 (BatchN (None, 28, 28, 512)  2048        conv2d_290[0][0]
# __________________________________________________________________________________________________
# add_52 (Add)                    (None, 28, 28, 512)  0           batch_normalization_290[0][0]
#                                                                  activation_274[0][0]
# __________________________________________________________________________________________________
# activation_277 (Activation)     (None, 28, 28, 512)  0           add_52[0][0]
# __________________________________________________________________________________________________
# conv2d_291 (Conv2D)             (None, 28, 28, 128)  65664       activation_277[0][0]
# __________________________________________________________________________________________________
# batch_normalization_291 (BatchN (None, 28, 28, 128)  512         conv2d_291[0][0]
# __________________________________________________________________________________________________
# activation_278 (Activation)     (None, 28, 28, 128)  0           batch_normalization_291[0][0]
# __________________________________________________________________________________________________
# conv2d_292 (Conv2D)             (None, 28, 28, 128)  147584      activation_278[0][0]
# __________________________________________________________________________________________________
# batch_normalization_292 (BatchN (None, 28, 28, 128)  512         conv2d_292[0][0]
# __________________________________________________________________________________________________
# activation_279 (Activation)     (None, 28, 28, 128)  0           batch_normalization_292[0][0]
# __________________________________________________________________________________________________
# conv2d_293 (Conv2D)             (None, 28, 28, 512)  66048       activation_279[0][0]
# __________________________________________________________________________________________________
# batch_normalization_293 (BatchN (None, 28, 28, 512)  2048        conv2d_293[0][0]
# __________________________________________________________________________________________________
# add_53 (Add)                    (None, 28, 28, 512)  0           batch_normalization_293[0][0]
#                                                                  activation_277[0][0]
# __________________________________________________________________________________________________
# activation_280 (Activation)     (None, 28, 28, 512)  0           add_53[0][0]
# __________________________________________________________________________________________________
# conv2d_294 (Conv2D)             (None, 28, 28, 128)  65664       activation_280[0][0]
# __________________________________________________________________________________________________
# batch_normalization_294 (BatchN (None, 28, 28, 128)  512         conv2d_294[0][0]
# __________________________________________________________________________________________________
# activation_281 (Activation)     (None, 28, 28, 128)  0           batch_normalization_294[0][0]
# __________________________________________________________________________________________________
# conv2d_295 (Conv2D)             (None, 28, 28, 128)  147584      activation_281[0][0]
# __________________________________________________________________________________________________
# batch_normalization_295 (BatchN (None, 28, 28, 128)  512         conv2d_295[0][0]
# __________________________________________________________________________________________________
# activation_282 (Activation)     (None, 28, 28, 128)  0           batch_normalization_295[0][0]
# __________________________________________________________________________________________________
# conv2d_296 (Conv2D)             (None, 28, 28, 512)  66048       activation_282[0][0]
# __________________________________________________________________________________________________
# batch_normalization_296 (BatchN (None, 28, 28, 512)  2048        conv2d_296[0][0]
# __________________________________________________________________________________________________
# add_54 (Add)                    (None, 28, 28, 512)  0           batch_normalization_296[0][0]
#                                                                  activation_280[0][0]
# __________________________________________________________________________________________________
# activation_283 (Activation)     (None, 28, 28, 512)  0           add_54[0][0]
# __________________________________________________________________________________________________
# conv2d_297 (Conv2D)             (None, 14, 14, 256)  131328      activation_283[0][0]
# __________________________________________________________________________________________________
# batch_normalization_297 (BatchN (None, 14, 14, 256)  1024        conv2d_297[0][0]
# __________________________________________________________________________________________________
# activation_284 (Activation)     (None, 14, 14, 256)  0           batch_normalization_297[0][0]
# __________________________________________________________________________________________________
# conv2d_298 (Conv2D)             (None, 14, 14, 256)  590080      activation_284[0][0]
# __________________________________________________________________________________________________
# batch_normalization_298 (BatchN (None, 14, 14, 256)  1024        conv2d_298[0][0]
# __________________________________________________________________________________________________
# activation_285 (Activation)     (None, 14, 14, 256)  0           batch_normalization_298[0][0]
# __________________________________________________________________________________________________
# conv2d_299 (Conv2D)             (None, 14, 14, 1024) 263168      activation_285[0][0]
# __________________________________________________________________________________________________
# conv2d_300 (Conv2D)             (None, 14, 14, 1024) 525312      activation_283[0][0]
# __________________________________________________________________________________________________
# batch_normalization_299 (BatchN (None, 14, 14, 1024) 4096        conv2d_299[0][0]
# __________________________________________________________________________________________________
# batch_normalization_300 (BatchN (None, 14, 14, 1024) 4096        conv2d_300[0][0]
# __________________________________________________________________________________________________
# add_55 (Add)                    (None, 14, 14, 1024) 0           batch_normalization_299[0][0]
#                                                                  batch_normalization_300[0][0]
# __________________________________________________________________________________________________
# activation_286 (Activation)     (None, 14, 14, 1024) 0           add_55[0][0]
# __________________________________________________________________________________________________
# conv2d_301 (Conv2D)             (None, 14, 14, 256)  262400      activation_286[0][0]
# __________________________________________________________________________________________________
# batch_normalization_301 (BatchN (None, 14, 14, 256)  1024        conv2d_301[0][0]
# __________________________________________________________________________________________________
# activation_287 (Activation)     (None, 14, 14, 256)  0           batch_normalization_301[0][0]
# __________________________________________________________________________________________________
# conv2d_302 (Conv2D)             (None, 14, 14, 256)  590080      activation_287[0][0]
# __________________________________________________________________________________________________
# batch_normalization_302 (BatchN (None, 14, 14, 256)  1024        conv2d_302[0][0]
# __________________________________________________________________________________________________
# activation_288 (Activation)     (None, 14, 14, 256)  0           batch_normalization_302[0][0]
# __________________________________________________________________________________________________
# conv2d_303 (Conv2D)             (None, 14, 14, 1024) 263168      activation_288[0][0]
# __________________________________________________________________________________________________
# batch_normalization_303 (BatchN (None, 14, 14, 1024) 4096        conv2d_303[0][0]
# __________________________________________________________________________________________________
# add_56 (Add)                    (None, 14, 14, 1024) 0           batch_normalization_303[0][0]
#                                                                  activation_286[0][0]
# __________________________________________________________________________________________________
# activation_289 (Activation)     (None, 14, 14, 1024) 0           add_56[0][0]
# __________________________________________________________________________________________________
# conv2d_304 (Conv2D)             (None, 14, 14, 256)  262400      activation_289[0][0]
# __________________________________________________________________________________________________
# batch_normalization_304 (BatchN (None, 14, 14, 256)  1024        conv2d_304[0][0]
# __________________________________________________________________________________________________
# activation_290 (Activation)     (None, 14, 14, 256)  0           batch_normalization_304[0][0]
# __________________________________________________________________________________________________
# conv2d_305 (Conv2D)             (None, 14, 14, 256)  590080      activation_290[0][0]
# __________________________________________________________________________________________________
# batch_normalization_305 (BatchN (None, 14, 14, 256)  1024        conv2d_305[0][0]
# __________________________________________________________________________________________________
# activation_291 (Activation)     (None, 14, 14, 256)  0           batch_normalization_305[0][0]
# __________________________________________________________________________________________________
# conv2d_306 (Conv2D)             (None, 14, 14, 1024) 263168      activation_291[0][0]
# __________________________________________________________________________________________________
# batch_normalization_306 (BatchN (None, 14, 14, 1024) 4096        conv2d_306[0][0]
# __________________________________________________________________________________________________
# add_57 (Add)                    (None, 14, 14, 1024) 0           batch_normalization_306[0][0]
#                                                                  activation_289[0][0]
# __________________________________________________________________________________________________
# activation_292 (Activation)     (None, 14, 14, 1024) 0           add_57[0][0]
# __________________________________________________________________________________________________
# conv2d_307 (Conv2D)             (None, 14, 14, 256)  262400      activation_292[0][0]
# __________________________________________________________________________________________________
# batch_normalization_307 (BatchN (None, 14, 14, 256)  1024        conv2d_307[0][0]
# __________________________________________________________________________________________________
# activation_293 (Activation)     (None, 14, 14, 256)  0           batch_normalization_307[0][0]
# __________________________________________________________________________________________________
# conv2d_308 (Conv2D)             (None, 14, 14, 256)  590080      activation_293[0][0]
# __________________________________________________________________________________________________
# batch_normalization_308 (BatchN (None, 14, 14, 256)  1024        conv2d_308[0][0]
# __________________________________________________________________________________________________
# activation_294 (Activation)     (None, 14, 14, 256)  0           batch_normalization_308[0][0]
# __________________________________________________________________________________________________
# conv2d_309 (Conv2D)             (None, 14, 14, 1024) 263168      activation_294[0][0]
# __________________________________________________________________________________________________
# batch_normalization_309 (BatchN (None, 14, 14, 1024) 4096        conv2d_309[0][0]
# __________________________________________________________________________________________________
# add_58 (Add)                    (None, 14, 14, 1024) 0           batch_normalization_309[0][0]
#                                                                  activation_292[0][0]
# __________________________________________________________________________________________________
# activation_295 (Activation)     (None, 14, 14, 1024) 0           add_58[0][0]
# __________________________________________________________________________________________________
# conv2d_310 (Conv2D)             (None, 14, 14, 256)  262400      activation_295[0][0]
# __________________________________________________________________________________________________
# batch_normalization_310 (BatchN (None, 14, 14, 256)  1024        conv2d_310[0][0]
# __________________________________________________________________________________________________
# activation_296 (Activation)     (None, 14, 14, 256)  0           batch_normalization_310[0][0]
# __________________________________________________________________________________________________
# conv2d_311 (Conv2D)             (None, 14, 14, 256)  590080      activation_296[0][0]
# __________________________________________________________________________________________________
# batch_normalization_311 (BatchN (None, 14, 14, 256)  1024        conv2d_311[0][0]
# __________________________________________________________________________________________________
# activation_297 (Activation)     (None, 14, 14, 256)  0           batch_normalization_311[0][0]
# __________________________________________________________________________________________________
# conv2d_312 (Conv2D)             (None, 14, 14, 1024) 263168      activation_297[0][0]
# __________________________________________________________________________________________________
# batch_normalization_312 (BatchN (None, 14, 14, 1024) 4096        conv2d_312[0][0]
# __________________________________________________________________________________________________
# add_59 (Add)                    (None, 14, 14, 1024) 0           batch_normalization_312[0][0]
#                                                                  activation_295[0][0]
# __________________________________________________________________________________________________
# activation_298 (Activation)     (None, 14, 14, 1024) 0           add_59[0][0]
# __________________________________________________________________________________________________
# conv2d_313 (Conv2D)             (None, 14, 14, 256)  262400      activation_298[0][0]
# __________________________________________________________________________________________________
# batch_normalization_313 (BatchN (None, 14, 14, 256)  1024        conv2d_313[0][0]
# __________________________________________________________________________________________________
# activation_299 (Activation)     (None, 14, 14, 256)  0           batch_normalization_313[0][0]
# __________________________________________________________________________________________________
# conv2d_314 (Conv2D)             (None, 14, 14, 256)  590080      activation_299[0][0]
# __________________________________________________________________________________________________
# batch_normalization_314 (BatchN (None, 14, 14, 256)  1024        conv2d_314[0][0]
# __________________________________________________________________________________________________
# activation_300 (Activation)     (None, 14, 14, 256)  0           batch_normalization_314[0][0]
# __________________________________________________________________________________________________
# conv2d_315 (Conv2D)             (None, 14, 14, 1024) 263168      activation_300[0][0]
# __________________________________________________________________________________________________
# batch_normalization_315 (BatchN (None, 14, 14, 1024) 4096        conv2d_315[0][0]
# __________________________________________________________________________________________________
# add_60 (Add)                    (None, 14, 14, 1024) 0           batch_normalization_315[0][0]
#                                                                  activation_298[0][0]
# __________________________________________________________________________________________________
# activation_301 (Activation)     (None, 14, 14, 1024) 0           add_60[0][0]
# __________________________________________________________________________________________________
# conv2d_316 (Conv2D)             (None, 7, 7, 512)    524800      activation_301[0][0]
# __________________________________________________________________________________________________
# batch_normalization_316 (BatchN (None, 7, 7, 512)    2048        conv2d_316[0][0]
# __________________________________________________________________________________________________
# activation_302 (Activation)     (None, 7, 7, 512)    0           batch_normalization_316[0][0]
# __________________________________________________________________________________________________
# conv2d_317 (Conv2D)             (None, 7, 7, 512)    2359808     activation_302[0][0]
# __________________________________________________________________________________________________
# batch_normalization_317 (BatchN (None, 7, 7, 512)    2048        conv2d_317[0][0]
# __________________________________________________________________________________________________
# activation_303 (Activation)     (None, 7, 7, 512)    0           batch_normalization_317[0][0]
# __________________________________________________________________________________________________
# conv2d_318 (Conv2D)             (None, 7, 7, 2048)   1050624     activation_303[0][0]
# __________________________________________________________________________________________________
# conv2d_319 (Conv2D)             (None, 7, 7, 2048)   2099200     activation_301[0][0]
# __________________________________________________________________________________________________
# batch_normalization_318 (BatchN (None, 7, 7, 2048)   8192        conv2d_318[0][0]
# __________________________________________________________________________________________________
# batch_normalization_319 (BatchN (None, 7, 7, 2048)   8192        conv2d_319[0][0]
# __________________________________________________________________________________________________
# add_61 (Add)                    (None, 7, 7, 2048)   0           batch_normalization_318[0][0]
#                                                                  batch_normalization_319[0][0]
# __________________________________________________________________________________________________
# activation_304 (Activation)     (None, 7, 7, 2048)   0           add_61[0][0]
# __________________________________________________________________________________________________
# conv2d_320 (Conv2D)             (None, 7, 7, 512)    1049088     activation_304[0][0]
# __________________________________________________________________________________________________
# batch_normalization_320 (BatchN (None, 7, 7, 512)    2048        conv2d_320[0][0]
# __________________________________________________________________________________________________
# activation_305 (Activation)     (None, 7, 7, 512)    0           batch_normalization_320[0][0]
# __________________________________________________________________________________________________
# conv2d_321 (Conv2D)             (None, 7, 7, 512)    2359808     activation_305[0][0]
# __________________________________________________________________________________________________
# batch_normalization_321 (BatchN (None, 7, 7, 512)    2048        conv2d_321[0][0]
# __________________________________________________________________________________________________
# activation_306 (Activation)     (None, 7, 7, 512)    0           batch_normalization_321[0][0]
# __________________________________________________________________________________________________
# conv2d_322 (Conv2D)             (None, 7, 7, 2048)   1050624     activation_306[0][0]
# __________________________________________________________________________________________________
# batch_normalization_322 (BatchN (None, 7, 7, 2048)   8192        conv2d_322[0][0]
# __________________________________________________________________________________________________
# add_62 (Add)                    (None, 7, 7, 2048)   0           batch_normalization_322[0][0]
#                                                                  activation_304[0][0]
# __________________________________________________________________________________________________
# activation_307 (Activation)     (None, 7, 7, 2048)   0           add_62[0][0]
# __________________________________________________________________________________________________
# conv2d_323 (Conv2D)             (None, 7, 7, 512)    1049088     activation_307[0][0]
# __________________________________________________________________________________________________
# batch_normalization_323 (BatchN (None, 7, 7, 512)    2048        conv2d_323[0][0]
# __________________________________________________________________________________________________
# activation_308 (Activation)     (None, 7, 7, 512)    0           batch_normalization_323[0][0]
# __________________________________________________________________________________________________
# conv2d_324 (Conv2D)             (None, 7, 7, 512)    2359808     activation_308[0][0]
# __________________________________________________________________________________________________
# batch_normalization_324 (BatchN (None, 7, 7, 512)    2048        conv2d_324[0][0]
# __________________________________________________________________________________________________
# activation_309 (Activation)     (None, 7, 7, 512)    0           batch_normalization_324[0][0]
# __________________________________________________________________________________________________
# conv2d_325 (Conv2D)             (None, 7, 7, 2048)   1050624     activation_309[0][0]
# __________________________________________________________________________________________________
# batch_normalization_325 (BatchN (None, 7, 7, 2048)   8192        conv2d_325[0][0]
# __________________________________________________________________________________________________
# add_63 (Add)                    (None, 7, 7, 2048)   0           batch_normalization_325[0][0]
#                                                                  activation_307[0][0]
# __________________________________________________________________________________________________
# activation_310 (Activation)     (None, 7, 7, 2048)   0           add_63[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 2048)         0           activation_310[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 2)            4098        global_average_pooling2d_6[0][0]
# ==================================================================================================
# Total params: 23,591,810
# Trainable params: 23,538,690
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
# ResNet-50 모델을 구성하기
resnet_50_model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

# ResNet-50 모델을 훈련하기
history_resnet50 = resnet_50_model.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:80%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[80%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/5
# 1163/1163 [==============================] - 574s 463ms/step - loss: 0.7266 - accuracy: 0.5547 - val_loss: 0.7032 - val_accuracy: 0.5688
# Epoch 2/5
# 1163/1163 [==============================] - 505s 434ms/step - loss: 0.6898 - accuracy: 0.5989 - val_loss: 0.8045 - val_accuracy: 0.5390
# Epoch 3/5
# 1163/1163 [==============================] - 506s 435ms/step - loss: 0.6691 - accuracy: 0.6191 - val_loss: 0.9626 - val_accuracy: 0.5119
# Epoch 4/5
# 1163/1163 [==============================] - 505s 434ms/step - loss: 0.6665 - accuracy: 0.6165 - val_loss: 0.7119 - val_accuracy: 0.6056
# Epoch 5/5
# 1163/1163 [==============================] - 506s 435ms/step - loss: 0.6562 - accuracy: 0.6309 - val_loss: 1.1258 - val_accuracy: 0.5183

# %%
del plainnet_50_model

input_shape = (224, 224, 3)  # cats_vs_dogs.shape = (224, 224, 3)
n_classes = 2

plainnet_50_model = build_plainnet(input_shape=input_shape, is_50=True, is_plain=True)
plainnet_50_model.summary()
# Out:
# resnet_type2_input: (None, 224, 224, 3)
# resnet_type2_pool1: (None, 56, 56, 64)
# bottle_neck_layer_input: (None, 56, 56, 64)
# bottle_neck_input      : 0 (None, 56, 56, 64)
# conv1 : 0 (None, 56, 56, 64)
# conv2 : 0 (None, 56, 56, 64)
# conv3 : 0 (None, 56, 56, 256)
# bottle_neck_beforadd : 0 (None, 56, 56, 256)
# bottle_neck_output     : 0 (None, 56, 56, 256)
# bottle_neck_input      : 1 (None, 56, 56, 256)
# conv1 : 1 (None, 56, 56, 64)
# conv2 : 1 (None, 56, 56, 64)
# conv3 : 1 (None, 56, 56, 256)
# bottle_neck_beforadd : 1 (None, 56, 56, 256)
# bottle_neck_output     : 1 (None, 56, 56, 256)
# bottle_neck_input      : 2 (None, 56, 56, 256)
# conv1 : 2 (None, 56, 56, 64)
# conv2 : 2 (None, 56, 56, 64)
# conv3 : 2 (None, 56, 56, 256)
# bottle_neck_beforadd : 2 (None, 56, 56, 256)
# bottle_neck_output     : 2 (None, 56, 56, 256)
# bottle_neck_layer_input: (None, 56, 56, 256)
# bottle_neck_input      : 0 (None, 56, 56, 256)
# conv1 : 0 (None, 28, 28, 128)
# conv2 : 0 (None, 28, 28, 128)
# conv3 : 0 (None, 28, 28, 512)
# bottle_neck_beforadd : 0 (None, 28, 28, 512)
# bottle_neck_output     : 0 (None, 28, 28, 512)
# bottle_neck_input      : 1 (None, 28, 28, 512)
# conv1 : 1 (None, 28, 28, 128)
# conv2 : 1 (None, 28, 28, 128)
# conv3 : 1 (None, 28, 28, 512)
# bottle_neck_beforadd : 1 (None, 28, 28, 512)
# bottle_neck_output     : 1 (None, 28, 28, 512)
# bottle_neck_input      : 2 (None, 28, 28, 512)
# conv1 : 2 (None, 28, 28, 128)
# conv2 : 2 (None, 28, 28, 128)
# conv3 : 2 (None, 28, 28, 512)
# bottle_neck_beforadd : 2 (None, 28, 28, 512)
# bottle_neck_output     : 2 (None, 28, 28, 512)
# bottle_neck_input      : 3 (None, 28, 28, 512)
# conv1 : 3 (None, 28, 28, 128)
# conv2 : 3 (None, 28, 28, 128)
# conv3 : 3 (None, 28, 28, 512)
# bottle_neck_beforadd : 3 (None, 28, 28, 512)
# bottle_neck_output     : 3 (None, 28, 28, 512)
# bottle_neck_layer_input: (None, 28, 28, 512)
# bottle_neck_input      : 0 (None, 28, 28, 512)
# conv1 : 0 (None, 14, 14, 256)
# conv2 : 0 (None, 14, 14, 256)
# conv3 : 0 (None, 14, 14, 1024)
# bottle_neck_beforadd : 0 (None, 14, 14, 1024)
# bottle_neck_output     : 0 (None, 14, 14, 1024)
# bottle_neck_input      : 1 (None, 14, 14, 1024)
# conv1 : 1 (None, 14, 14, 256)
# conv2 : 1 (None, 14, 14, 256)
# conv3 : 1 (None, 14, 14, 1024)
# bottle_neck_beforadd : 1 (None, 14, 14, 1024)
# bottle_neck_output     : 1 (None, 14, 14, 1024)
# bottle_neck_input      : 2 (None, 14, 14, 1024)
# conv1 : 2 (None, 14, 14, 256)
# conv2 : 2 (None, 14, 14, 256)
# conv3 : 2 (None, 14, 14, 1024)
# bottle_neck_beforadd : 2 (None, 14, 14, 1024)
# bottle_neck_output     : 2 (None, 14, 14, 1024)
# bottle_neck_input      : 3 (None, 14, 14, 1024)
# conv1 : 3 (None, 14, 14, 256)
# conv2 : 3 (None, 14, 14, 256)
# conv3 : 3 (None, 14, 14, 1024)
# bottle_neck_beforadd : 3 (None, 14, 14, 1024)
# bottle_neck_output     : 3 (None, 14, 14, 1024)
# bottle_neck_input      : 4 (None, 14, 14, 1024)
# conv1 : 4 (None, 14, 14, 256)
# conv2 : 4 (None, 14, 14, 256)
# conv3 : 4 (None, 14, 14, 1024)
# bottle_neck_beforadd : 4 (None, 14, 14, 1024)
# bottle_neck_output     : 4 (None, 14, 14, 1024)
# bottle_neck_input      : 5 (None, 14, 14, 1024)
# conv1 : 5 (None, 14, 14, 256)
# conv2 : 5 (None, 14, 14, 256)
# conv3 : 5 (None, 14, 14, 1024)
# bottle_neck_beforadd : 5 (None, 14, 14, 1024)
# bottle_neck_output     : 5 (None, 14, 14, 1024)
# bottle_neck_layer_input: (None, 14, 14, 1024)
# bottle_neck_input      : 0 (None, 14, 14, 1024)
# conv1 : 0 (None, 7, 7, 512)
# conv2 : 0 (None, 7, 7, 512)
# conv3 : 0 (None, 7, 7, 2048)
# bottle_neck_beforadd : 0 (None, 7, 7, 2048)
# bottle_neck_output     : 0 (None, 7, 7, 2048)
# bottle_neck_input      : 1 (None, 7, 7, 2048)
# conv1 : 1 (None, 7, 7, 512)
# conv2 : 1 (None, 7, 7, 512)
# conv3 : 1 (None, 7, 7, 2048)
# bottle_neck_beforadd : 1 (None, 7, 7, 2048)
# bottle_neck_output     : 1 (None, 7, 7, 2048)
# bottle_neck_input      : 2 (None, 7, 7, 2048)
# conv1 : 2 (None, 7, 7, 512)
# conv2 : 2 (None, 7, 7, 512)
# conv3 : 2 (None, 7, 7, 2048)
# bottle_neck_beforadd : 2 (None, 7, 7, 2048)
# bottle_neck_output     : 2 (None, 7, 7, 2048)
# resnet_type2_output  : (None, 2)
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# plain_input_layer (InputLaye [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv2d_326 (Conv2D)          (None, 112, 112, 64)      9472
# _________________________________________________________________
# batch_normalization_326 (Bat (None, 112, 112, 64)      256
# _________________________________________________________________
# activation_311 (Activation)  (None, 112, 112, 64)      0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_327 (Conv2D)          (None, 56, 56, 64)        4160
# _________________________________________________________________
# batch_normalization_327 (Bat (None, 56, 56, 64)        256
# _________________________________________________________________
# activation_312 (Activation)  (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_328 (Conv2D)          (None, 56, 56, 64)        36928
# _________________________________________________________________
# batch_normalization_328 (Bat (None, 56, 56, 64)        256
# _________________________________________________________________
# activation_313 (Activation)  (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_329 (Conv2D)          (None, 56, 56, 256)       16640
# _________________________________________________________________
# batch_normalization_329 (Bat (None, 56, 56, 256)       1024
# _________________________________________________________________
# activation_314 (Activation)  (None, 56, 56, 256)       0
# _________________________________________________________________
# conv2d_330 (Conv2D)          (None, 56, 56, 64)        16448
# _________________________________________________________________
# batch_normalization_330 (Bat (None, 56, 56, 64)        256
# _________________________________________________________________
# activation_315 (Activation)  (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_331 (Conv2D)          (None, 56, 56, 64)        36928
# _________________________________________________________________
# batch_normalization_331 (Bat (None, 56, 56, 64)        256
# _________________________________________________________________
# activation_316 (Activation)  (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_332 (Conv2D)          (None, 56, 56, 256)       16640
# _________________________________________________________________
# batch_normalization_332 (Bat (None, 56, 56, 256)       1024
# _________________________________________________________________
# activation_317 (Activation)  (None, 56, 56, 256)       0
# _________________________________________________________________
# conv2d_333 (Conv2D)          (None, 56, 56, 64)        16448
# _________________________________________________________________
# batch_normalization_333 (Bat (None, 56, 56, 64)        256
# _________________________________________________________________
# activation_318 (Activation)  (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_334 (Conv2D)          (None, 56, 56, 64)        36928
# _________________________________________________________________
# batch_normalization_334 (Bat (None, 56, 56, 64)        256
# _________________________________________________________________
# activation_319 (Activation)  (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_335 (Conv2D)          (None, 56, 56, 256)       16640
# _________________________________________________________________
# batch_normalization_335 (Bat (None, 56, 56, 256)       1024
# _________________________________________________________________
# activation_320 (Activation)  (None, 56, 56, 256)       0
# _________________________________________________________________
# conv2d_336 (Conv2D)          (None, 28, 28, 128)       32896
# _________________________________________________________________
# batch_normalization_336 (Bat (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_321 (Activation)  (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_337 (Conv2D)          (None, 28, 28, 128)       147584
# _________________________________________________________________
# batch_normalization_337 (Bat (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_322 (Activation)  (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_338 (Conv2D)          (None, 28, 28, 512)       66048
# _________________________________________________________________
# batch_normalization_338 (Bat (None, 28, 28, 512)       2048
# _________________________________________________________________
# activation_323 (Activation)  (None, 28, 28, 512)       0
# _________________________________________________________________
# conv2d_339 (Conv2D)          (None, 28, 28, 128)       65664
# _________________________________________________________________
# batch_normalization_339 (Bat (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_324 (Activation)  (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_340 (Conv2D)          (None, 28, 28, 128)       147584
# _________________________________________________________________
# batch_normalization_340 (Bat (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_325 (Activation)  (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_341 (Conv2D)          (None, 28, 28, 512)       66048
# _________________________________________________________________
# batch_normalization_341 (Bat (None, 28, 28, 512)       2048
# _________________________________________________________________
# activation_326 (Activation)  (None, 28, 28, 512)       0
# _________________________________________________________________
# conv2d_342 (Conv2D)          (None, 28, 28, 128)       65664
# _________________________________________________________________
# batch_normalization_342 (Bat (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_327 (Activation)  (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_343 (Conv2D)          (None, 28, 28, 128)       147584
# _________________________________________________________________
# batch_normalization_343 (Bat (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_328 (Activation)  (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_344 (Conv2D)          (None, 28, 28, 512)       66048
# _________________________________________________________________
# batch_normalization_344 (Bat (None, 28, 28, 512)       2048
# _________________________________________________________________
# activation_329 (Activation)  (None, 28, 28, 512)       0
# _________________________________________________________________
# conv2d_345 (Conv2D)          (None, 28, 28, 128)       65664
# _________________________________________________________________
# batch_normalization_345 (Bat (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_330 (Activation)  (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_346 (Conv2D)          (None, 28, 28, 128)       147584
# _________________________________________________________________
# batch_normalization_346 (Bat (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_331 (Activation)  (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_347 (Conv2D)          (None, 28, 28, 512)       66048
# _________________________________________________________________
# batch_normalization_347 (Bat (None, 28, 28, 512)       2048
# _________________________________________________________________
# activation_332 (Activation)  (None, 28, 28, 512)       0
# _________________________________________________________________
# conv2d_348 (Conv2D)          (None, 14, 14, 256)       131328
# _________________________________________________________________
# batch_normalization_348 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_333 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_349 (Conv2D)          (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_normalization_349 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_334 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_350 (Conv2D)          (None, 14, 14, 1024)      263168
# _________________________________________________________________
# batch_normalization_350 (Bat (None, 14, 14, 1024)      4096
# _________________________________________________________________
# activation_335 (Activation)  (None, 14, 14, 1024)      0
# _________________________________________________________________
# conv2d_351 (Conv2D)          (None, 14, 14, 256)       262400
# _________________________________________________________________
# batch_normalization_351 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_336 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_352 (Conv2D)          (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_normalization_352 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_337 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_353 (Conv2D)          (None, 14, 14, 1024)      263168
# _________________________________________________________________
# batch_normalization_353 (Bat (None, 14, 14, 1024)      4096
# _________________________________________________________________
# activation_338 (Activation)  (None, 14, 14, 1024)      0
# _________________________________________________________________
# conv2d_354 (Conv2D)          (None, 14, 14, 256)       262400
# _________________________________________________________________
# batch_normalization_354 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_339 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_355 (Conv2D)          (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_normalization_355 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_340 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_356 (Conv2D)          (None, 14, 14, 1024)      263168
# _________________________________________________________________
# batch_normalization_356 (Bat (None, 14, 14, 1024)      4096
# _________________________________________________________________
# activation_341 (Activation)  (None, 14, 14, 1024)      0
# _________________________________________________________________
# conv2d_357 (Conv2D)          (None, 14, 14, 256)       262400
# _________________________________________________________________
# batch_normalization_357 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_342 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_358 (Conv2D)          (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_normalization_358 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_343 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_359 (Conv2D)          (None, 14, 14, 1024)      263168
# _________________________________________________________________
# batch_normalization_359 (Bat (None, 14, 14, 1024)      4096
# _________________________________________________________________
# activation_344 (Activation)  (None, 14, 14, 1024)      0
# _________________________________________________________________
# conv2d_360 (Conv2D)          (None, 14, 14, 256)       262400
# _________________________________________________________________
# batch_normalization_360 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_345 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_361 (Conv2D)          (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_normalization_361 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_346 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_362 (Conv2D)          (None, 14, 14, 1024)      263168
# _________________________________________________________________
# batch_normalization_362 (Bat (None, 14, 14, 1024)      4096
# _________________________________________________________________
# activation_347 (Activation)  (None, 14, 14, 1024)      0
# _________________________________________________________________
# conv2d_363 (Conv2D)          (None, 14, 14, 256)       262400
# _________________________________________________________________
# batch_normalization_363 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_348 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_364 (Conv2D)          (None, 14, 14, 256)       590080
# _________________________________________________________________
# batch_normalization_364 (Bat (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_349 (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_365 (Conv2D)          (None, 14, 14, 1024)      263168
# _________________________________________________________________
# batch_normalization_365 (Bat (None, 14, 14, 1024)      4096
# _________________________________________________________________
# activation_350 (Activation)  (None, 14, 14, 1024)      0
# _________________________________________________________________
# conv2d_366 (Conv2D)          (None, 7, 7, 512)         524800
# _________________________________________________________________
# batch_normalization_366 (Bat (None, 7, 7, 512)         2048
# _________________________________________________________________
# activation_351 (Activation)  (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_367 (Conv2D)          (None, 7, 7, 512)         2359808
# _________________________________________________________________
# batch_normalization_367 (Bat (None, 7, 7, 512)         2048
# _________________________________________________________________
# activation_352 (Activation)  (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_368 (Conv2D)          (None, 7, 7, 2048)        1050624
# _________________________________________________________________
# batch_normalization_368 (Bat (None, 7, 7, 2048)        8192
# _________________________________________________________________
# activation_353 (Activation)  (None, 7, 7, 2048)        0
# _________________________________________________________________
# conv2d_369 (Conv2D)          (None, 7, 7, 512)         1049088
# _________________________________________________________________
# batch_normalization_369 (Bat (None, 7, 7, 512)         2048
# _________________________________________________________________
# activation_354 (Activation)  (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_370 (Conv2D)          (None, 7, 7, 512)         2359808
# _________________________________________________________________
# batch_normalization_370 (Bat (None, 7, 7, 512)         2048
# _________________________________________________________________
# activation_355 (Activation)  (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_371 (Conv2D)          (None, 7, 7, 2048)        1050624
# _________________________________________________________________
# batch_normalization_371 (Bat (None, 7, 7, 2048)        8192
# _________________________________________________________________
# activation_356 (Activation)  (None, 7, 7, 2048)        0
# _________________________________________________________________
# conv2d_372 (Conv2D)          (None, 7, 7, 512)         1049088
# _________________________________________________________________
# batch_normalization_372 (Bat (None, 7, 7, 512)         2048
# _________________________________________________________________
# activation_357 (Activation)  (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_373 (Conv2D)          (None, 7, 7, 512)         2359808
# _________________________________________________________________
# batch_normalization_373 (Bat (None, 7, 7, 512)         2048
# _________________________________________________________________
# activation_358 (Activation)  (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_374 (Conv2D)          (None, 7, 7, 2048)        1050624
# _________________________________________________________________
# batch_normalization_374 (Bat (None, 7, 7, 2048)        8192
# _________________________________________________________________
# activation_359 (Activation)  (None, 7, 7, 2048)        0
# _________________________________________________________________
# global_average_pooling2d_7 ( (None, 2048)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 2)                 4098
# =================================================================
# Total params: 20,803,714
# Trainable params: 20,758,274
# Non-trainable params: 45,440
# _________________________________________________________________

# %%
# ResNet-50 모델을 구성하기
plainnet_50_model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

# ResNet-50 모델을 훈련하기
history_plainnet50 = plainnet_50_model.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:80%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[80%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/5
# 1163/1163 [==============================] - 449s 378ms/step - loss: 0.7109 - accuracy: 0.5411 - val_loss: 0.8187 - val_accuracy: 0.4894
# Epoch 2/5
# 1163/1163 [==============================] - 437s 376ms/step - loss: 0.7083 - accuracy: 0.5312 - val_loss: 0.9562 - val_accuracy: 0.4877
# Epoch 3/5
# 1163/1163 [==============================] - 436s 375ms/step - loss: 0.7115 - accuracy: 0.5149 - val_loss: 1.1897 - val_accuracy: 0.5067
# Epoch 4/5
# 1163/1163 [==============================] - 436s 375ms/step - loss: 0.7072 - accuracy: 0.5201 - val_loss: 2.4308 - val_accuracy: 0.5300
# Epoch 5/5
# 1163/1163 [==============================] - 436s 375ms/step - loss: 0.7031 - accuracy: 0.5348 - val_loss: 0.7515 - val_accuracy: 0.5302

# %% [markdown]
# ### 시각화
#
# 두 모델의 검증 정확도(validation accuracy)와 검증 손실(validation loss)

# %%
# 훈련 손실(training loss)
import matplotlib.pyplot as plt

plt.plot(history_resnet50.history['loss'], 'r')
plt.plot(history_plainnet50.history['loss'], 'b')
plt.title('Model training loss for cats_vs_dogs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['resnet_50', 'plainnet_50'], loc='upper left')
plt.show()

# %%
# 검증 정확도(validation accuracy)

plt.plot(history_resnet50.history['val_accuracy'], 'r')
plt.plot(history_plainnet50.history['val_accuracy'], 'b')
plt.title('Model validation accuracy for cats_vs_dogs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['resnet_50', 'plainnet_50'], loc='upper left')
plt.show()

# %% [markdown]
# ### 추가 실험
#
# tensorflow-datasets의 지원하는 다른 데이터셋으로 실험

# %% [markdown]
# ## 회고

# %% [markdown]
# * ResNet을 직접 구현하기 위해서 논문을 탐독하고 관련 자료를 찾으면서 많은 것을 배울수 있었다.
#   - ResNet34의 첫번째 층에서 shortcut이 identity 또는 projection 인지를 확인하는데 오래걸렸다.
#     - ResNet34와 ResNet50의 첫번째 shortcut이 동일할 것으로 예상하면서 혼란에 빠졌다.
#   - PlainNet과 ResNet을 만들면서 정의된 함수를 재사용하는 것은 함수를 만들면서 많이 배웠다.
#
#
# * ResNet34의 경우 파라미터의 개수가 노드에 있는 것과 상이하게 나오고 있다.
#   - 원인은 아직 찾지 못하고 있음
#
#
# * cats_vs_dogs 데이터셋을 불러오면서 데이터의 split 상태를 확인하지 않아 에러 원인을 찾는 과정에서
#   - 텐서플로우 데이터셋 웹페이지(https://www.tensorflow.org/datasets/catalog/cats_vs_dogs)를 다시 확인면서 원인을 찾았다.
#     - 데이터셋 분리가 'train' 하나로 되어 있었다.
#   - 데이터셋이 하나로 되어 있는 것을 분리하는 과정에서도 에러를 찾으면서 많을 것을 알게 되었다.
#     - `train[:80%]`와 `train[80%:]`같이 퍼센트로 분할할 수 있다는 것을 알게 되었다.
#     - 분할된 데이터셋 갯수확인은 `tf.data.experimental.cardinality(ds_train)` 으로 가능하다.
#
#
# * cats_vs_dogs 데이터셋을 학습하는데 커널이 자꾸 죽는 현상이 나타났다.
#   - 원인은 이미지의 크기가 큰 상태인데 배치크기 또한 크게 설정하였기 때문에 메모리가 버티질 못한 것이었다.
#     - 이미지가 큰 경우에는 반드시 적절한 배치크기를 찾는 과정을 먼저 해야만 한다.
#
#
# * 클라우드 환경에서 작업하면서 좋은 점은 연산할때 조용하다는 것이고,
#   단점은 장시간 연사는 경우에 커널연결이 불안하여 끊기는 경우가 발생한다는 것이다.
#   이번의 경우에도 거의 마지막에서 커널이 끊겨서 마지막 그래프를 그릴 수 없게 되었다.
